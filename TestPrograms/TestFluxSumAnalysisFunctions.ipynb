# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
gparentdir = os.path.dirname(os.path.dirname(currentdir))
sys.path.insert(0, gparentdir)
import scobra
import get_all_functions as gaf
import re
new = scobra.Model("sample/Diel_Leaf_Model_cleaned.xls")
#new = scobra.model(n)

#new=scobra.Model('models/Diel_Leaf_Model_cleaned.xls')

#Maximize Sucrose output (objective)
#vary light (scan)
#allow CO2 and O2, even Proton and Water
#Output maintenance ATP and NADPHox
tx_and_biomass = []
for i in new.Reactions(): 
    if '_tx' in i:
        tx_and_biomass.append(re.search('(.*)_tx', i).group())
    elif '_biomass' in i: 
        tx_and_biomass.append(re.search('(.*)_biomass', i).group())
#tx_and_biomass.append(re.search('(.*)_tx', 'slkdfjd_tx').group())
tx_and_biomass

necessary_rxn= ['ATPase_tx', 'CO2_tx', 'Photon_tx', 'O2_tx','H2O_tx', 'H_tx','NADPHoxc_tx','NADPHoxm_tx','NADPHoxp_tx','Sucrose_tx']
unecessary_rxn= list(set(tx_and_biomass) - set(necessary_rxn))

#blocking _tx and _biomass reactions that are not considered
for i in unecessary_rxn: 
    new.GetReaction(i).lower_bound = 0.0
    new.GetReaction(i).upper_bound = 0.0

#freeing _tx and _biomass reactions that are considered
for i in necessary_rxn: 
    if new.GetReaction(i).lower_bound == 0.0:
        new.GetReaction(i).upper_bound == 1000.0
    else: 
        new.GetReaction(i).lower_bound == 1000.0
        new.GetReaction(i).upper_bound == 1000.0

#setting constraints
new.SetConstraint('ATPase_tx', 90, 90)
new.SetConstraint('NADPHoxc_tx', 10, 10)
new.SetConstraint('NADPHoxm_tx', 10, 10)
new.SetConstraint('NADPHoxp_tx', 10, 10)
#setting constraints for sucrose entering and exiting cytoplasm
new.SetConstraint('Sucrose_ec', -1000, 1000)

#setting objectives
new.SetObjective('Sucrose_tx')
new.SetObjDirec('Min')

#setting constraint and running scan
#result = {}
#for i in range(0,1000,20):
#    new.SetConstraint('Photon_tx', i, i)
#    new.Solve()
#    x = new.GetSol()['Sucrose_tx']
#    result[i] = x

#new.Solve() 
#new.MinFluxSolve()

new.Solve()
# Out:
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(  )' for <Reaction HEXOKINASE_RXN_MANNOSE_c at 0x7f98eb396bd0>
# optimal

# %%
import scobra.analysis.FluxSum as fs
fs.FluxSum()

# %%
new.Metabolites()
# Out:
# ['10_FORMYL_THF_c',
#  '10_FORMYL_THF_p',
#  'D_SEDOHEPTULOSE_7_P_p',
#  'GAP_p',
#  'RIBOSE_5P_p',
#  'XYLULOSE_5_PHOSPHATE_p',
#  'UBIQUINONE_mc',
#  'PROTON_c',
#  'UBIQUINOL_mc',
#  'Cytochromes_C_Oxidized_mc',
#  'Cytochromes_C_Reduced_mc',
#  'PROTON_m',
#  'Cytochromes_C_Oxidized_mi',
#  'Cytochromes_C_Reduced_mi',
#  'UBIQUINOL_mi',
#  'UBIQUINONE_mi',
#  'PROTON_i',
#  'Oxidized_ferredoxins_p',
#  'Reduced_ferredoxins_p',
#  'NADPH_p',
#  'NADP_p',
#  'PROTON_p',
#  'MANNITOL_c',
#  'NADH_c',
#  'MANNOSE_c',
#  'NAD_c',
#  'DPG_p',
#  'Pi_p',
#  'NADH_m',
#  'NAD_m',
#  'FORMATE_m',
#  'CARBON_DIOXIDE_m',
#  'FORMATE_p',
#  'CARBON_DIOXIDE_p',
#  'NAD_p',
#  'NADH_p',
#  'G3P_c',
#  'NADP_c',
#  'WATER_c',
#  'GAP_c',
#  'NADPH_c',
#  'METHYLENE_THF_c',
#  '5_METHYL_THF_c',
#  'APS_p',
#  'aSO3_p',
#  'SO3_p',
#  'GLUTATHIONE_p',
#  'OXIDIZED_GLUTATHIONE_p',
#  'AMP_p',
#  'ASCORBATE_p',
#  'L_DEHYDRO_ASCORBATE_p',
#  '2_KETOGLUTARATE_m',
#  '2_KETOGLUTARATE_c',
#  'CIS_ACONITATE_c',
#  'CIS_ACONITATE_m',
#  'CIT_c',
#  'CIT_m',
#  'THREO_DS_ISO_CITRATE_c',
#  'THREO_DS_ISO_CITRATE_m',
#  'MAL_m',
#  'MAL_c',
#  'MAL_p',
#  '2_KETOGLUTARATE_p',
#  'OXALACETIC_ACID_c',
#  'OXALACETIC_ACID_m',
#  'SUC_m',
#  'SUC_c',
#  'SUC_COA_m',
#  'CO_A_m',
#  'PHOSPHO_ENOL_PYRUVATE_c',
#  '2_PG_c',
#  '2_PG_p',
#  'PHOSPHO_ENOL_PYRUVATE_p',
#  'WATER_p',
#  'FRUCTOSE_6P_p',
#  'ERYTHROSE_4P_p',
#  '2_KETO_ISOVALERATE_p',
#  '3_CARBOXY_3_HYDROXY_ISOCAPROATE_p',
#  'ACETYL_COA_p',
#  'CO_A_p',
#  '2_KETOGLUTARATE_x',
#  'MALONYL_ACP_p',
#  'Acetoacetyl_ACPs_p',
#  'UDP_GLUCOSE_c',
#  'CPD_1777_c',
#  'UDP_c',
#  'CONIFERYL_ALCOHOL_c',
#  'aUDP_c',
#  'SHIKIMATE_5P_p',
#  '3_ENOLPYRUVYL_SHIKIMATE_5P_p',
#  'aPPI_c',
#  'aPi_c',
#  'Pi_c',
#  'PPI_c',
#  'FRUCTOSE_16_DIPHOSPHATE_c',
#  'FRUCTOSE_6P_c',
#  'aGTP_c',
#  'MANNOSE_1P_c',
#  'GTP_c',
#  'GDP_MANNOSE_c',
#  'GDP_D_GLUCOSE_c',
#  'GLC_1_P_c',
#  'aUTP_c',
#  'UDP_GLUCURONATE_c',
#  'UTP_c',
#  'CPD_510_c',
#  'G3P_p',
#  '3_DEHYDRO_SHIKIMATE_p',
#  'DEHYDROQUINATE_p',
#  '3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_p',
#  '2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_p',
#  'CPD_7100_p',
#  'CPD_9451_p',
#  '4_AMINO_BUTYRATE_v',
#  'PROTON_v',
#  '4_AMINO_BUTYRATE_c',
#  '4_AMINO_BUTYRATE_m',
#  'Beta_3_hydroxybutyryl_ACPs_p',
#  'Crotonyl_ACPs_p',
#  '3_Hydroxy_octanoyl_ACPs_p',
#  '2_Octenoyl_ACPs_p',
#  'R_3_Hydroxypalmitoyl_ACPs_p',
#  '2_Hexadecenoyl_ACPs_p',
#  '5_METHYL_THF_p',
#  'ADP_c',
#  'ATP_c',
#  'aADP_c',
#  'aATP_c',
#  'ATP_p',
#  'FRUCTOSE_16_DIPHOSPHATE_p',
#  'aADP_p',
#  'ADP_p',
#  'aATP_p',
#  'CARBON_DIOXIDE_c',
#  'RIBULOSE_5P_c',
#  'CPD_2961_c',
#  'RIBULOSE_5P_p',
#  'CPD_2961_p',
#  'D_6_P_GLUCONO_DELTA_LACTONE_c',
#  'D_6_P_GLUCONO_DELTA_LACTONE_p',
#  'AMMONIUM_p',
#  'CARBAMOYL_P_p',
#  'ACETALD_c',
#  'ACETALD_m',
#  'PPI_p',
#  'ACET_p',
#  'bPPI_p',
#  'CO_A_x',
#  'AMP_x',
#  'aATP_x',
#  'aPPI_x',
#  'PPI_x',
#  'ACET_x',
#  'ACETYL_COA_x',
#  'ATP_x',
#  'DIOH_ISOVALERATE_p',
#  '2_ACETO_LACTATE_p',
#  'PYRUVATE_p',
#  '2_ACETO_2_HYDROXY_BUTYRATE_p',
#  '1_KETO_2_METHYLVALERATE_p',
#  '2_OXOBUTANOATE_p',
#  'ACETYL_GLU_p',
#  'N_ACETYL_GLUTAMYL_P_p',
#  'CPD_469_p',
#  'N_ALPHA_ACETYLORNITHINE_p',
#  'GLT_p',
#  'MALONYL_COA_p',
#  'HCO3_p',
#  'ACET_m',
#  'ACET_c',
#  'WATER_m',
#  'HS_c',
#  'CYS_c',
#  'aHS_c',
#  'ACETYLSERINE_c',
#  'CYS_p',
#  'HS_p',
#  'ACETYLSERINE_p',
#  'L_ASPARTATE_p',
#  'IMP_p',
#  'aGDP_p',
#  'GDP_p',
#  'aGTP_p',
#  'ADENYLOSUCC_p',
#  'GTP_p',
#  'AMP_c',
#  'aADP_m',
#  'ADP_m',
#  'aATP_m',
#  'AMP_m',
#  'ATP_m',
#  'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_p',
#  'AICAR_p',
#  'THF_p',
#  'GLT_c',
#  'PYRUVATE_c',
#  'L_ALPHA_ALANINE_c',
#  'GLT_m',
#  'PYRUVATE_m',
#  'L_ALPHA_ALANINE_m',
#  'PYRUVATE_x',
#  'L_ALPHA_ALANINE_x',
#  'GLT_x',
#  'GLYOX_x',
#  'GLY_x',
#  'ALA_tRNAs_c',
#  'Charged_ALA_tRNAs_c',
#  'ETOH_c',
#  'FUM_p',
#  'PROTON_x',
#  'CHORISMATE_p',
#  'GLN_p',
#  'ANTHRANILATE_p',
#  'Charged_ARG_tRNAs_c',
#  'ARG_c',
#  'ARG_tRNAs_c',
#  'L_ARGININO_SUCCINATE_c',
#  'FUM_c',
#  'L_CITRULLINE_c',
#  'L_ASPARTATE_c',
#  'ARG_m',
#  'L_CITRULLINE_m',
#  'HIS_m',
#  'HIS_c',
#  'LYS_m',
#  'LYS_c',
#  'L_ORNITHINE_m',
#  'L_ORNITHINE_c',
#  'ARG_v',
#  'ASN_c',
#  'AMMONIUM_c',
#  'ASN_v',
#  'L_ASPARTATE_m',
#  'OXALACETIC_ACID_p',
#  'L_ASPARTATE_x',
#  'OXALACETIC_ACID_x',
#  'Charged_ASN_tRNAs_c',
#  'ASN_tRNAs_c',
#  'L_BETA_ASPARTYL_P_p',
#  'L_ASPARTATE_SEMIALDEHYDE_p',
#  'Charged_ASP_tRNAs_c',
#  'ASP_tRNAs_c',
#  'PHOSPHORIBOSYL_ATP_p',
#  'aPRPP_p',
#  'PRPP_p',
#  'ACETYL_COA_c',
#  'CO_A_c',
#  '2_KETO_3_METHYL_VALERATE_p',
#  'ILE_p',
#  '2K_4CH3_PENTANOATE_p',
#  'LEU_p',
#  'VAL_p',
#  'pPHE_b',
#  'pSER_b',
#  'pTHR_b',
#  'pTYR_b',
#  'pALA_b',
#  'pVAL_b',
#  'pARG_b',
#  'pASN_b',
#  'pASP_b',
#  'K_b',
#  'pGLN_b',
#  'pGLU_b',
#  'Ca_b',
#  'pGLY_b',
#  'pHIS_b',
#  'pMET_b',
#  'pILE_b',
#  'pLEU_b',
#  'pLYS_b',
#  'Mg_b',
#  'CAII_v',
#  'CAII_c',
#  'CPD_659_p',
#  'PHE_p',
#  'HYDROGEN_PEROXIDE_x',
#  'OXYGEN_MOLECULE_x',
#  'WATER_x',
#  'aGDP_c',
#  'CELLULOSE_c',
#  'GDP_c',
#  'PREPHENATE_p',
#  'ACETYL_COA_m',
#  'CIT_x',
#  'CIT_v',
#  'aCIT_v',
#  'CARBON_DIOXIDE_e',
#  'GLC_c',
#  'O_PHOSPHO_L_HOMOSERINE_p',
#  'L_CYSTATHIONINE_p',
#  'HOMO_CYS_p',
#  'CYS_v',
#  'OXYGEN_MOLECULE_m',
#  'CAII_e',
#  'PROTON_e',
#  'Cellulose_b',
#  'DIHYDROXY_ACETONE_PHOSPHATE_p',
#  'DIHYDROXY_ACETONE_PHOSPHATE_c',
#  'MESO_DIAMINOPIMELATE_p',
#  'LYS_p',
#  'LL_DIAMINOPIMELATE_p',
#  '2_3_DIHYDRODIPICOLINATE_p',
#  'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_p',
#  'NITRITE_p',
#  'FeIII_c',
#  'FeII_c',
#  'FORMATE_c',
#  'FRU_c',
#  'FRU_v',
#  'FUM_m',
#  'FUM_v',
#  'aFUM_v',
#  'FattyAcid_b',
#  'PALMITATE_c',
#  'PLASTOQUINONE_p',
#  'PLASTOQUINOL_1_p',
#  'GLC_6_P_p',
#  'GLC_6_P_c',
#  'SUCC_S_ALD_m',
#  'DPG_c',
#  'GLY_m',
#  'THF_m',
#  'AMMONIUM_m',
#  'METHYLENE_THF_m',
#  'aGDP_m',
#  'GDP_m',
#  'aGTP_m',
#  'GTP_m',
#  'GLC_v',
#  'GLC_e',
#  'GLC_p',
#  'GLN_m',
#  'GLN_c',
#  'GLN_v',
#  'GLT_v',
#  'GLC_1_P_p',
#  'ADP_D_GLUCOSE_p',
#  'GLUCURONATE_c',
#  'GLT_tRNAs_c',
#  'Charged_GLT_tRNAs_c',
#  'L_ORNITHINE_p',
#  'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_p',
#  'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_p',
#  'Pi_m',
#  'Charged_GLN_tRNAs_c',
#  'GLN_tRNAs_c',
#  'HYDROGEN_PEROXIDE_p',
#  'L_GLUTAMATE_5_P_c1_p',
#  'L_GLUTAMATE_GAMMA_SEMIALDEHYDE_c1_p',
#  'GLYCERATE_p',
#  'GLYCEROL_3P_c',
#  'GLYCOLLATE_p',
#  'GLYCERATE_c',
#  'GLYCOLLATE_c',
#  'GLY_tRNAs_c',
#  'Charged_GLY_tRNAs_c',
#  'GLY_c',
#  'STARCH_p',
#  'SER_c',
#  'THF_c',
#  'SER_m',
#  'SER_p',
#  'METHYLENE_THF_p',
#  'GLY_p',
#  'GLY_v',
#  'CPD_67_p',
#  'GLYCERATE_x',
#  'Glycerol_b',
#  'GLYCOLLATE_x',
#  'WATER_e',
#  'MANNOSE_6P_c',
#  'bHISTIDINAL_p',
#  'HIS_p',
#  'HISTIDINAL_p',
#  'L_HISTIDINOL_P_p',
#  'IMIDAZOLE_ACETOL_P_p',
#  'PHOSPHORIBOSYL_FORMIMINO_AICAR_P_p',
#  'PHOSPHORIBOSYL_AMP_p',
#  'HIS_tRNAs_c',
#  'Charged_HIS_tRNAs_c',
#  'HISTIDINOL_p',
#  'bHIS_v',
#  'MET_c',
#  'HOMO_CYS_c',
#  'MET_p',
#  'HOMO_SER_p',
#  'NAD_x',
#  'NADH_x',
#  'OH_PYR_x',
#  'INDOLE_3_GLYCEROL_P_p',
#  'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_p',
#  'ILE_v',
#  'ILE_c',
#  'aPi_x',
#  'Pi_x',
#  'NADP_m',
#  'NADPH_m',
#  'THREO_DS_ISO_CITRATE_x',
#  'SUC_x',
#  'Charged_ILE_tRNAs_c',
#  'ILE_tRNAs_c',
#  'KI_v',
#  'KI_e',
#  'KI_c',
#  'LEU_c',
#  'LEU_tRNAs_c',
#  'Charged_LEU_tRNAs_c',
#  'LEU_v',
#  'Charged_LYS_tRNAs_c',
#  'LYS_tRNAs_c',
#  'LYS_v',
#  'L_ALPHA_ALANINE_v',
#  'L_ASPARTATE_v',
#  'L_CITRULLINE_p',
#  'MAL_x',
#  'ACP_p',
#  'MALTOSE_c',
#  'Heteroglycans_c',
#  'MAL_v',
#  'aMAL_v',
#  'SULFATE_c',
#  'SULFATE_m',
#  'MANNITOL_1P_c',
#  'CPD_318_p',
#  '5_10_METHENYL_THF_c',
#  'Charged_MET_tRNAs_c',
#  'MET_tRNAs_c',
#  'MET_v',
#  'MGII_v',
#  'MGII_c',
#  'MYO_INOSITOL_c',
#  '1_L_MYO_INOSITOL_1_P_c',
#  'OXYGEN_MOLECULE_c',
#  'OXYGEN_MOLECULE_p',
#  'SUPER_OXIDE_p',
#  'MGII_e',
#  'PROTON_l',
#  'AMMONIUM_e',
#  'NITRATE_c',
#  'NITRATE_v',
#  'NITRITE_c',
#  'NITRATE_e',
#  'OXYGEN_MOLECULE_e',
#  'L_GLUTAMATE_GAMMA_SEMIALDEHYDE_m',
#  'PALMITATE_p',
#  'HCO3_c',
#  '3_P_HYDROXYPYRUVATE_p',
#  'Charged_PHE_tRNAs_c',
#  'PHE_tRNAs_c',
#  'PHE_c',
#  'PHE_v',
#  'D_RIBULOSE_15_P2_p',
#  'Oxidized_Plastocyanins_p',
#  'Plastocyanin_Reduced_p',
#  'N_5_PHOSPHORIBOSYL_ANTHRANILATE_p',
#  'P_HYDROXY_PHENYLPYRUVATE_p',
#  'PRO_c',
#  'PRO_m',
#  'PRO_v',
#  '3_P_SERINE_p',
#  'Photon_p',
#  'L_DELTA1_PYRROLINE_5_CARBOXYLATE_c1_p',
#  'TRP_c',
#  'X_Phloem_contribution_t1_',
#  'sSUCROSE_b',
#  'TYR_c',
#  'VAL_c',
#  'THR_c',
#  'Photon_e',
#  'Pi_e',
#  'Protein_polymerisation_cost_c',
#  'Protein_processing_cost_c',
#  'Protein_tranlocation_cost_c',
#  'XYLULOSE_5_PHOSPHATE_c',
#  'INDOLE_p',
#  'TRP_p',
#  'aPHYTYL_PYROPHOSPHATE_p',
#  'CHLOROPHYLLIDE_A_p',
#  'PHYTYL_PYROPHOSPHATE_p',
#  'CHLOROPHYLL_A_p',
#  'HYDROGEN_PEROXIDE_c',
#  'SUPER_OXIDE_c',
#  'MALTOSE_p',
#  'SUCROSE_c',
#  'TYR_p',
#  'Reduced_Ferroproteins_m',
#  'Oxidized_Ferroproteins_m',
#  'L_DELTA1_PYRROLINE_5_CARBOXYLATE_m',
#  'CPD_7014_p',
#  'CHLOROPHYLL_B_p',
#  'CPD_7015_p',
#  'CPD_7016_p',
#  'CPD1F_130_p',
#  'CPD1F_131_p',
#  'CPD1F_133_p',
#  'XYLAN_c',
#  'UDP_D_XYLOSE_c',
#  '3_oxo_hexanoyl_ACPs_p',
#  'Butanoyl_ACPs_p',
#  'R_3_hydroxyhexanoyl_ACPs_p',
#  'Hex_2_enoyl_ACPs_p',
#  '3_Oxo_octanoyl_ACPs_p',
#  'Hexanoyl_ACPs_p',
#  '3_oxo_decanoyl_ACPs_p',
#  'Octanoyl_ACPs_p',
#  'Beta_hydroxydecanoyl_ACPs_p',
#  '3_oxo_dodecanoyl_ACPs_p',
#  'Decanoyl_ACPs_p',
#  'R_3_hydroxydodecanoyl_ACPs_p',
#  'Dodec_2_enoyl_ACPs_p',
#  'Dodecanoyl_ACPs_p',
#  '3_oxo_myristoyl_ACPs_p',
#  'R_3_hydroxymyristoyl_ACPs_p',
#  'Tetradec_2_enoyl_ACPs_p',
#  'Myristoyl_ACPs_p',
#  '3_oxo_palmitoyl_ACPs_p',
#  'Palmitoyl_ACPs_p',
#  'Trans_D2_decenoyl_ACPs_p',
#  'D_SEDOHEPTULOSE_1_7_P2_p',
#  'SER_x',
#  'SER_tRNAs_c',
#  'Charged_SER_tRNAs_c',
#  'SER_v',
#  'SHIKIMATE_p',
#  'SULFATE_e',
#  'SULFATE_p',
#  'SUCROSE_6P_c',
#  'SUCROSE_v',
#  'Starch_b',
#  'SUCROSE_e',
#  'THR_p',
#  'Charged_THR_tRNAs_c',
#  'THR_tRNAs_c',
#  'THR_v',
#  'TRP_v',
#  'Charged_TYR_tRNAs_c',
#  'TYR_tRNAs_c',
#  'TYR_v',
#  'VAL_tRNAs_c',
#  'Charged_VAL_tRNAs_c',
#  'VAL_v',
#  'Xylan_b',
#  'sALA_b',
#  'sASP_b',
#  'sCIT_b',
#  'sFUM_b',
#  'sGABA_b',
#  'sGLN_b',
#  'sGLU_b',
#  'sMAL_b',
#  'sSUC_b']

# %%
print('Test Completed')

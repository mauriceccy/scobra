# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
gparentdir = os.path.dirname(os.path.dirname(currentdir))
sys.path.insert(0, gparentdir)
import scobra
import get_all_functions as gaf
import re
n = scobra.Model("sample/Diel_Leaf_Model_cleaned.xls")
m = scobra.model(n)
# Out:
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(  )' for <Reaction HEXOKINASE_RXN_MANNOSE_c at 0x7f9fecc57d10>

# %%
m.SingleDeletion()
m.EssentialGenes() 
m.EssentialReactions() 
m.DoubleDeletion()
# Out:
#                                       growth   status
# ids
# (SOLYC03G112320.2, SOLYC07G052350.2)     0.0  optimal
# (SOLYC01G105390.2, SOLYC03G117480.2)     0.0  optimal
# (SOLYC12G006930.1, SOLYC03G120990.2)     0.0  optimal
# (SOLYC08G041870.2, SOLYC01G017200.1)     0.0  optimal
# (SOLYC03G019720.2, SOLYC05G045850.1)     0.0  optimal
# (SOLYC09G005460.1, SOLYC02G094420.2)     0.0  optimal
# (SOLYC02G086610.2, SOLYC07G019620.1)     0.0  optimal
# (SOLYC04G076870.2, SOLYC06G069530.2)     0.0  optimal
# (SOLYC01G097460.2, SOLYC04G007150.2)     0.0  optimal
# (SOLYC08G082810.2, SOLYC02G091750.2)     0.0  optimal
# (SOLYC01G091190.2, SOLYC05G056250.2)     0.0  optimal
# (SOLYC01G104000.2, SOLYC06G051270.2)     0.0  optimal
# (SOLYC06G060790.1, SOLYC03G043950.2)     0.0  optimal
# (SOLYC07G006270.2, SOLYC04G011510.2)     0.0  optimal
# (SOLYC01G111100.2, SOLYC11G056370.1)     0.0  optimal
# (SOLYC12G049370.1, SOLYC10G054340.1)     0.0  optimal
# (SOLYC01G099420.1, SOLYC06G075050.1)     0.0  optimal
# (SOLYC02G088500.1, SOLYC01G111510.2)     0.0  optimal
# (SOLYC09G015870.2, SOLYC04G074550.2)     0.0  optimal
# (SOLYC01G097920.2, SOLYC04G053120.2)     0.0  optimal
# (SOLYC12G008650.1, SOLYC11G045110.1)     0.0  optimal
# (SOLYC06G050400.1, SOLYC11G056370.1)     0.0  optimal
# (SOLYC03G097390.2, SOLYC01G008310.2)     0.0  optimal
# (SOLYC02G091770.1, SOLYC02G079270.2)     0.0  optimal
# (SOLYC10G083550.1, SOLYC07G053280.2)     0.0  optimal
# (SOLYC01G079420.2, SOLYC10G076610.1)     0.0  optimal
# (SOLYC08G082810.2, SOLYC01G098580.2)     0.0  optimal
# (SOLYC10G005510.2, SOLYC04G039820.1)     0.0  optimal
# (SOLYC02G091970.2, SOLYC10G049890.1)     0.0  optimal
# (SOLYC08G083280.2, SOLYC06G076330.2)     0.0  optimal
# ...                                      ...      ...
# (SOLYC02G067750.2, SOLYC03G111200.2)     0.0  optimal
# (SOLYC08G005280.1, SOLYC12G099930.1)     0.0  optimal
# (SOLYC09G011220.2, SOLYC01G097920.2)     0.0  optimal
# (SOLYC01G101040.2, SOLYC03G007810.2)     0.0  optimal
# (SOLYC04G082180.2, SOLYC05G032660.2)     0.0  optimal
# (SOLYC04G025530.2, SOLYC07G021630.2)     0.0  optimal
# (SOLYC01G007290.1, SOLYC01G007910.2)     0.0  optimal
# (SOLYC08G014610.2, SOLYC02G085950.2)     0.0  optimal
# (SOLYC06G071000.2, SOLYC09G091700.2)     0.0  optimal
# (SOLYC06G051080.2, SOLYC10G045050.1)     0.0  optimal
# (SOLYC04G050420.1, SOLYC03G013390.1)     0.0  optimal
# (SOLYC04G025530.2, SOLYC12G006450.1)     0.0  optimal
# (SOLYC03G115990.1, SOLYC12G040570.1)     0.0  optimal
# (SOLYC03G063780.1, SOLYC02G005350.2)     0.0  optimal
# (SOLYC05G055730.2, SOLYC02G088680.1)     0.0  optimal
# (SOLYC08G077410.2, SOLYC10G008200.2)     0.0  optimal
# (SOLYC12G096190.1, SOLYC01G108630.2)     0.0  optimal
# (SOLYC10G017620.2, SOLYC04G039820.1)     0.0  optimal
# (SOLYC06G068320.2, SOLYC02G069550.1)     0.0  optimal
# (SOLYC01G008540.2, SOLYC12G094620.1)     0.0  optimal
# (SOLYC03G006870.2, SOLYC01G058020.2)     0.0  optimal
# (SOLYC07G005390.2, SOLYC08G080370.2)     0.0  optimal
# (SOLYC08G023380.1, SOLYC03G043850.2)     0.0  optimal
# (SOLYC01G097460.2, SOLYC02G093830.2)     0.0  optimal
# (SOLYC08G006560.2, SOLYC08G077300.2)     0.0  optimal
# (SOLYC09G082780.2, SOLYC02G086710.2)     0.0  optimal
# (SOLYC02G068530.2, SOLYC09G009390.2)     0.0  optimal
# (SOLYC12G035830.1, SOLYC04G011400.2)     0.0  optimal
# (SOLYC03G097170.2, SOLYC08G075530.2)     0.0  optimal
# (SOLYC05G005490.2, SOLYC02G086090.2)     0.0  optimal
#
# [522753 rows x 2 columns]

# %%
print('Test Completed')

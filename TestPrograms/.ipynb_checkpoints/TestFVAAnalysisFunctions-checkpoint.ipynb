# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
gparentdir = os.path.dirname(os.path.dirname(currentdir))
sys.path.insert(0, gparentdir)
import scobra
import get_all_functions as gaf
import re
n = scobra.Model("sample/Diel_Leaf_Model_cleaned.xls")
new = scobra.model(n)
# Out:
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(  )' for <Reaction HEXOKINASE_RXN_MANNOSE_c at 0x7f25e3831350>

# %%
tx_and_biomass = []
for i in new.Reactions(): 
    if '_tx' in i:
        tx_and_biomass.append(re.search('(.*)_tx', i).group())
    elif '_biomass' in i: 
        tx_and_biomass.append(re.search('(.*)_biomass', i).group())
#tx_and_biomass.append(re.search('(.*)_tx', 'slkdfjd_tx').group())
tx_and_biomass

necessary_rxn= ['ATPase_tx', 'CO2_tx', 'Photon_tx', 'O2_tx','H2O_tx', 'H_tx','NADPHoxc_tx','NADPHoxm_tx','NADPHoxp_tx','Sucrose_tx']
unecessary_rxn= list(set(tx_and_biomass) - set(necessary_rxn))

#blocking _tx and _biomass reactions that are not considered
for i in unecessary_rxn: 
    new.GetReaction(i).lower_bound = 0.0
    new.GetReaction(i).upper_bound = 0.0

#freeing _tx and _biomass reactions that are considered
for i in necessary_rxn: 
    if new.GetReaction(i).lower_bound == 0.0:
        new.GetReaction(i).upper_bound == 1000.0
    else: 
        new.GetReaction(i).lower_bound == 1000.0
        new.GetReaction(i).upper_bound == 1000.0

#setting constraints
new.SetConstraint('ATPase_tx', 90, 90)
new.SetConstraint('NADPHoxc_tx', 10, 10)
new.SetConstraint('NADPHoxm_tx', 10, 10)
new.SetConstraint('NADPHoxp_tx', 10, 10)
#setting constraints for sucrose entering and exiting cytoplasm
new.SetConstraint('Sucrose_ec', -1000, 1000)

#setting objectives
new.SetObjective('Sucrose_tx')
new.SetObjDirec('Min')

# %%
import scobra.analysis.FVA as FVA

# %%
FVA.FVA(new, reaclist = new.reactions, cobra = True)
# Out:
# no

# %%
FVA.AllFluxRange(new)
# Out:
# {'10_FORMYL_THF_pc': (-957.7045177045167, 0.0),
#  '1TRANSKETO_RXN_p': (-333.33333333333354, 324.5454545454546),
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc': (0.0, 226.08630952381026),
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mi': (0.0, 1000.0),
#  '1_PERIOD_18_PERIOD_1_PERIOD_2_RXN_p': (-1000.0, 250.0000000000001),
#  '1_PERIOD_1_PERDIOD_1_PERIOD_255_RXN_c': (0.0, 1000.0),
#  '1_PERIOD_2_PERIOD_1_PERIOD_13_RXN_p': (0.0, 1000.0),
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m': (0.0, 687.2497570456758),
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p': (0.0, 957.7045177045173),
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c': (0.0, 1000.0),
#  '1_PERIOD_5_PERIOD_1_PERIOD_20_RXN_c': (0.0, 0.0),
#  '1_PERIOD_8_PERIOD_4_PERIOD_9_RXN_p': (0.0, 0.0),
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p': (0.0, 1000.0),
#  '2KG_ACONITATE_mc': (-1000.0, 1000.0),
#  '2KG_CIT_mc': (-1000.0, 1000.0),
#  '2KG_ISOCITRATE_mc': (-1000.0, 1000.0),
#  '2KG_MAL_mc': (-1000.0, 1000.0),
#  '2KG_MAL_pc': (-1000.0, 0.0),
#  '2KG_OAA_mc': (-1000.0, 1000.0),
#  '2KG_SUC_mc': (-1000.0, 1000.0),
#  '2OXOGLUTARATEDEH_RXN_m': (0.0, 610.4056437389773),
#  '2PGADEHYDRAT_RXN_c': (-1000.0, 1000.0),
#  '2PGADEHYDRAT_RXN_p': (-1000.0, 1000.0),
#  '2TRANSKETO_RXN_p': (-324.5454545454543, 333.3333333333348),
#  '2_ISOPROPYLMALATESYN_RXN_p': (0.0, 0.0),
#  '2_KETOGLUTARATE_xc': (-1000.0000000000003, 1000.0000000000001),
#  '2_PERIOD_3_PERIOD_1_PERIOD_180_RXN_p': (0.0, 0.0),
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c': (0.0, 1000.0),
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p': (0.0, 0.0),
#  '2_PERIOD_7_PERIOD_1_PERIOD_90_RXN_c': (-1000.0, 1000.0),
#  '2_PERIOD_7_PERIOD_7_PERIOD_13_RXN_c': (0.0, 1000.0000000000002),
#  '2_PERIOD_7_PERIOD_7_PERIOD_34_RXN_c': (0.0, 1000.0000000000002),
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c': (0.0, 0.0),
#  '3PGAREARR_RXN_c': (-1000.0, 999.9999999999992),
#  '3PGAREARR_RXN_p': (-999.9999999999995, 999.9999999999999),
#  '3PGA_Pi_pc': (-1000.0, 1000.0),
#  '3_DEHYDROQUINATE_DEHYDRATASE_RXN_p': (0.0, 0.0),
#  '3_DEHYDROQUINATE_SYNTHASE_RXN_p': (0.0, 0.0),
#  '3_ISOPROPYLMALDEHYDROG_RXN_p': (0.0, 0.0),
#  '3_ISOPROPYLMALISOM_RXN_p': (0.0, 0.0),
#  '4_AMINO_BUTYRATE_PROTON_rev_vc': (0.0, 1000.0),
#  '4_AMINO_BUTYRATE_PROTON_vc': (0.0, 1000.0),
#  '4_AMINO_BUTYRATE_mc': (-657.878787878788, 0.0),
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p': (0.0, 0.0),
#  '4_PERIOD_2_PERIOD_1_PERIOD_59_RXN_p': (0.0, 0.0),
#  '4_PERIOD_2_PERIOD_1_PERIOD_61_RXN_p': (0.0, 0.0),
#  '5_METHYL_THF_pc': (0.0, 0.0),
#  '6PFRUCTPHOS_RXN_c': (0.0, 1000.0),
#  '6PFRUCTPHOS_RXN_p': (0.0, 1000.0),
#  '6PGLUCONDEHYDROG_RXN_c': (0.0, 1000.0),
#  '6PGLUCONDEHYDROG_RXN_p': (0.0, 999.999999999999),
#  '6PGLUCONOLACT_RXN_c': (0.0, 1000.0),
#  '6PGLUCONOLACT_RXN_p': (0.0, 999.999999999999),
#  '6_PERIOD_3_PERIOD_4_PERIOD_16_RXN_p': (0.0, 1000.0),
#  'ACETALD_mc': (-500.0, 0.0),
#  'ACETATE_COA_LIGASE_RXN_p': (0.0, 0.0),
#  'ACETATE_COA_LIGASE_RXN_x': (0.0, 499.99999999999983),
#  'ACETOLACTREDUCTOISOM_RXN_p': (0.0, 0.0),
#  'ACETOLACTSYN_RXN_p': (0.0, 0.0),
#  'ACETOOHBUTREDUCTOISOM_RXN_p': (0.0, 0.0),
#  'ACETOOHBUTSYN_RXN_p': (0.0, 0.0),
#  'ACETYLGLUTKIN_RXN_p': (0.0, 1000.0000000000002),
#  'ACETYLORNTRANSAM_RXN_p': (0.0, 1000.0000000000003),
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p': (0.0, 0.0),
#  'ACET_mc': (0.0, 500.0000000000002),
#  'ACET_pc': (0.0, 0.0),
#  'ACET_xc': (-499.99999999999994, 0.0),
#  'ACONITATEDEHYDR_RXN_c': (-1000.0, 1000.0),
#  'ACONITATEDEHYDR_RXN_m': (-999.9999999999999, 1000.0),
#  'ACONITATEHYDR_RXN_c': (-1000.0, 1000.0),
#  'ACONITATEHYDR_RXN_m': (-1000.0000000000002, 1000.0),
#  'ACSERLY_RXN_c': (0.0, 0.0),
#  'ACSERLY_RXN_p': (0.0, 0.0),
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p': (0.0, 0.0),
#  'ADENYL_KIN_RXN_c': (-1000.0, 1000.0),
#  'ADENYL_KIN_RXN_m': (-917.7266081871346, 1000.0),
#  'ADENYL_KIN_RXN_p': (-1000.0000000000001, 1000.0),
#  'ADP_pc': (-1000.0, 1000.0),
#  'AICARTRANSFORM_RXN_p': (0.0, 0.0),
#  'ALANINE_AMINOTRANSFERASE_RXN_c': (0.0, 0.0),
#  'ALANINE_AMINOTRANSFERASE_RXN_m': (0.0, 657.8787878787874),
#  'ALANINE_AMINOTRANSFERASE_RXN_x': (-1000.0, 0.0),
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x': (0.0, 1000.0),
#  'ALANINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'ALCOHOL_DEHYDROG_RXN_c': (-1000.0, 0.0),
#  'AMPSYN_RXN_p': (0.0, 0.0),
#  'AMP_ATP_xc': (0.0, 499.9999999999999),
#  'AMP_pc': (-499.99999999999994, 1000.0),
#  'ANTHRANSYN_RXN_p': (0.0, 0.0),
#  'ARGININE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'ARGSUCCINLYA_RXN_c': (0.0, 0.0),
#  'ARGSUCCINSYN_RXN_c': (0.0, 0.0),
#  'ARG_CITRULLINE_mc': (-1000.0, 1000.0),
#  'ARG_HIS_mc': (-1000.0, 1000.0),
#  'ARG_LYS_mc': (-999.9999999999999, 1000.0),
#  'ARG_ORNITHINE_mc': (-1000.0, 1000.0),
#  'ARG_PROTON_rev_vc': (0.0, 1000.0),
#  'ARG_PROTON_vc': (0.0, 1000.0),
#  'ARG_mc': (-1000.0, 0.0),
#  'ASNSYNA_RXN_c': (0.0, 0.0),
#  'ASN_PROTON_rev_vc': (0.0, 1000.0),
#  'ASN_PROTON_vc': (0.0, 1000.0000000000001),
#  'ASPAMINOTRANS_RXN_c': (-1000.0, 1000.0),
#  'ASPAMINOTRANS_RXN_m': (-999.9999999999999, 1000.0000000000001),
#  'ASPAMINOTRANS_RXN_p': (0.0, 999.9999999999993),
#  'ASPAMINOTRANS_RXN_x': (-1000.0, 1000.0000000000001),
#  'ASPARAGINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'ASPARTATEKIN_RXN_p': (0.0, 500.0000000000011),
#  'ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_p': (0.0, 500.0000000000002),
#  'ASPARTATE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p': (0.0, 0.0),
#  'ATP_ADP_Pi_pc': (-1000.0, 1000.0),
#  'ATP_ADP_mc': (-1000.0, 1000.0),
#  'ATP_AMP_mc': (-917.7266081871345, 999.9999999999978),
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c': (0.0, 0.0),
#  'ATP_pc': (-1000.0, 1000.0000000000006),
#  'ATPase_tx': (90.0, 90.0),
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_p': (0.0, 0.0),
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p': (0.0, 0.0),
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_p': (0.0, 0.0),
#  'Biomass_tx': (0.0, 0.0),
#  'CA2_rev_vc': (0.0, 0.0),
#  'CARBAMATE_KINASE_RXN_p': (-1000.0000000000001, 0.0),
#  'CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p': (0.0, 0.0),
#  'CATAL_RXN_x': (0.0, 276.94286914513737),
#  'CELLULOSE_SYNTHASE_GDP_FORMING_RXN_c': (0.0, 0.0),
#  'CELLULOSE_SYNTHASE_UDP_FORMING_RXN_c': (0.0, 0.0),
#  'CHORISMATEMUT_RXN_p': (0.0, 0.0),
#  'CHORISMATE_SYNTHASE_RXN_p': (0.0, 0.0),
#  'CITSYN_RXN_m': (0.0, 657.8787878787878),
#  'CITSYN_RXN_x': (0.0, 373.50476190476166),
#  'CIT_ACONITATE_mc': (-1000.0, 1000.0),
#  'CIT_ISOCITRATE_mc': (-1000.0, 1000.0),
#  'CIT_PROTON_rev_vc': (0.0, 1000.0),
#  'CIT_PROTON_vc': (0.0, 1000.0000000000001),
#  'CIT_xc': (0.0, 373.5047619047626),
#  'CO2_ec': (-1000.0, 95.93709043250317),
#  'CO2_mc': (-990.0000000000002, 1000.0),
#  'CO2_pc': (-947.380952380952, 1000.0),
#  'CO2_tx': (-1000.0, 95.93709043250283),
#  'CONIFERIN_BETA_GLUCOSIDASE_RXN_c': (0.0, 1000.0000000000001),
#  'CYSPH_RXN_p': (0.0, 0.0),
#  'CYSTAGLY_RXN_p': (0.0, 0.0),
#  'CYSTATHIONINE_BETA_LYASE_RXN_p': (0.0, 0.0),
#  'CYS_PROTON_rev_vc': (0.0, 1000.0),
#  'CYS_PROTON_vc': (0.0, 1000.0),
#  'CYTOCHROME_C_OXIDASE_RXN_mc': (0.0, 113.04315476190513),
#  'CYTOCHROME_C_OXIDASE_RXN_mi': (0.0, 500.0000000000006),
#  'Ca_biomass': (0.0, 0.0),
#  'Ca_ec': (0.0, 0.0),
#  'Ca_tx': (0.0, 0.0),
#  'Cellulose_biomass': (0.0, 0.0),
#  'DAHPSYN_RXN_p': (0.0, 0.0),
#  'DHAP_3PGA_pc': (-1000.0, 1000.0),
#  'DHAP_Pi_pc': (-1000.0, 1000.0),
#  'DIAMINOPIMDECARB_RXN_p': (0.0, 0.0),
#  'DIAMINOPIMEPIM_RXN_p': (0.0, 0.0),
#  'DIHYDRODIPICSYN_RXN_p': (0.0, 0.0),
#  'DIHYDROPICRED_RXN_NADP_p': (0.0, 0.0),
#  'DIHYDROPICRED_RXN_NAD_p': (0.0, 0.0),
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p': (0.0, 0.0),
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p': (0.0, 0.0),
#  'F16ALDOLASE_RXN_c': (-998.5640875055053, 1000.0),
#  'F16ALDOLASE_RXN_p': (-1000.0, 999.9999999999995),
#  'F16BDEPHOS_RXN_c': (0.0, 1000.0),
#  'F16BDEPHOS_RXN_p': (0.0, 1000.0),
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p': (0.0, 0.0),
#  'FERRIC_CHELATE_REDUCTASE_RXN_c': (0.0, 1000.0),
#  'FORMATETHFLIG_RXN_p': (0.0, 1000.0000000000003),
#  'FORMATE_mc': (-687.2497570456754, 0.0),
#  'FORMATE_pc': (0.0, 687.2497570456754),
#  'FORMYLTHFDEFORMYL_RXN_p': (0.0, 1000.0),
#  'FRUCTOKINASE_RXN_c': (0.0, 1000.0),
#  'FRU_PROTON_rev_vc': (0.0, 1000.0),
#  'FRU_vc': (0.0, 1000.0),
#  'FUMHYDR_RXN_c': (-1000.0000000000001, 999.9999999999909),
#  'FUMHYDR_RXN_m': (-999.9999999999998, 1000.0),
#  'FUM_PROTON_vc': (0.0, 0.0),
#  'FUM_pc': (0.0, 0.0),
#  'FattyAcid_biomass': (0.0, 0.0),
#  'Ferredoxin_Plastoquinone_Reductase_p': (0.0, 1000.0),
#  'G6P_Pi_pc': (-1000.0, 1000.0),
#  'GABATRANSAM_RXN_m': (0.0, 657.8787878787876),
#  'GAPOXNPHOSPHN_RXN_c': (-1000.0, 1000.0),
#  'GAPOXNPHOSPHN_RXN_p': (-1000.0, 1000.0),
#  'GAP_3PGA_pc': (-1000.0, 1000.0),
#  'GAP_Pi_pc': (-1000.0, 1000.0),
#  'GCVMULTI_RXN_m': (0.0, 601.1428571428569),
#  'GDPKIN_RXN_c': (0.0, 1000.0),
#  'GDPKIN_RXN_m': (-610.4056437389772, 0.0),
#  'GDPKIN_RXN_p': (0.0, 0.0),
#  'GLC_PROTON_rev_vc': (0.0, 1000.0),
#  'GLC_ec': (0.0, 0.0),
#  'GLC_pc': (-1000.0, 999.9999999999994),
#  'GLC_tx': (0.0, 0.0),
#  'GLC_vc': (0.0, 1000.0),
#  'GLN_GLU_mc': (0.0, 1000.0),
#  'GLN_GLU_pc': (-1000.0, 0.0),
#  'GLN_PROTON_rev_vc': (0.0, 1000.0),
#  'GLN_PROTON_vc': (0.0, 1000.0),
#  'GLT_MAL_pc': (-499.99999999999983, 1000.0000000000002),
#  'GLT_PROTON_rev_vc': (0.0, 1000.0),
#  'GLT_PROTON_vc': (0.0, 1000.0),
#  'GLT_xc': (-1000.0, 999.9999999999994),
#  'GLU6PDEHYDROG_RXN_c': (0.0, 999.9999999999999),
#  'GLU6PDEHYDROG_RXN_p': (0.0, 1000.0),
#  'GLUC1PADENYLTRANS_RXN_p': (0.0, 999.9999999999999),
#  'GLUC1PURIDYLTRANS_RXN_c': (-83.33333333333323, 1000.0),
#  'GLUCOKIN_RXN_c': (0.0, 1000.0),
#  'GLUCOKIN_RXN_p': (0.0, 1000.0),
#  'GLUCURONOKINASE_RXN_c': (0.0, 0.0),
#  'GLURS_RXN_c': (0.0, 0.0),
#  'GLUTAMATE_DEHYDROGENASE_RXN_m': (0.0, 1000.0),
#  'GLUTAMATE_N_ACETYLTRANSFERASE_RXN_p': (0.0, 1000.0000000000005),
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p': (0.0, 1000.0),
#  'GLUTAMATE_SYNTHASE_NADH_RXN_p': (0.0, 1000.0),
#  'GLUTAMIDOTRANS_RXN_p': (0.0, 0.0),
#  'GLUTAMINESYN_RXN_c': (0.0, 1000.0),
#  'GLUTAMINESYN_RXN_m': (0.0, 1000.0),
#  'GLUTAMINESYN_RXN_p': (0.0, 1000.0000000000006),
#  'GLUTAMINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'GLUTATHIONE_PEROXIDASE_RXN_p': (0.0, 500.0),
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p': (0.0, 1000.0),
#  'GLUTDECARBOX_RXN_c': (0.0, 657.878787878788),
#  'GLUTKIN_RXN_c': (0.0, 0.0),
#  'GLUTSEMIALDEHYDRROG_RXN_c': (0.0, 0.0),
#  'GLY3KIN_RXN_p': (0.0, 276.94286914513737),
#  'GLYC3PDEHYDROGBIOSYN_RXN_c': (0.0, 1000.0),
#  'GLYCERATE_GLYCOLLATE_pc': (0.0, 276.9428691451374),
#  'GLYCINE_AMINOTRANSFERASE_RXN_x': (-1000.0, 549.8599439775915),
#  'GLYCINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'GLYCOGENSYN_RXN_p': (0.0, 999.9999999999999),
#  'GLYOHMETRANS_RXN_c': (-1000.0, 1000.0),
#  'GLYOHMETRANS_RXN_m': (-1000.0000000000007, 999.9999999999998),
#  'GLYOHMETRANS_RXN_p': (-1000.0000000000002, 1000.0000000000002),
#  'GLY_PROTON_rev_vc': (0.0, 1000.0),
#  'GLY_PROTON_vc': (0.0, 1000.0000000000001),
#  'GLY_mc': (-1000.0, 1000.0),
#  'GLY_pc': (-1000.0, 1000.0),
#  'GLY_xc': (-500.0, 734.106586559858),
#  'GPH_RXN_p': (0.0, 553.8857382902748),
#  'Glycerate_xc': (0.0, 276.9428691451374),
#  'Glycerol_biomass': (0.0, 0.0),
#  'Glycolate_xc': (-553.8857382902748, 0.0),
#  'H2O_ec': (-916.6666666666697, 142.50000000000074),
#  'H2O_mc': (-1000.0, 1000.0),
#  'H2O_pc': (-1000.0, 1000.0),
#  'H2O_tx': (-916.6666666666696, 142.50000000000054),
#  'H2O_xc': (-999.9999999999995, 553.8857382902755),
#  'HEXOKINASE_RXN_MANNOSE_c': (0.0, 1000.0000000000016),
#  'HISTALDEHYD_RXN_p': (0.0, 0.0),
#  'HISTAMINOTRANS_RXN_p': (0.0, 0.0),
#  'HISTCYCLOHYD_RXN_p': (0.0, 0.0),
#  'HISTIDINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'HISTIDPHOS_RXN_p': (0.0, 0.0),
#  'HISTOLDEHYD_RXN_p': (0.0, 0.0),
#  'HISTPRATPHYD_RXN_p': (0.0, 0.0),
#  'HIS_CITRULLINE_mc': (-1000.0, 1000.0),
#  'HIS_ORNITHINE_mc': (-1000.0, 1000.0),
#  'HIS_PROTON_rev_vc': (0.0, 1000.0),
#  'HIS_PROTON_vc': (0.0, 1000.0),
#  'HIS_pc': (0.0, 0.0),
#  'HOMOCYSMETB12_RXN_c': (0.0, 0.0),
#  'HOMOCYSMETB12_RXN_p': (0.0, 0.0),
#  'HOMOSERDEHYDROG_RXN_NADP_p': (0.0, 500.00000000000017),
#  'HOMOSERDEHYDROG_RXN_NAD_p': (0.0, 500.0000000000001),
#  'HOMOSERKIN_RXN_p': (0.0, 499.9999999999999),
#  'HOMO_CYS_pc': (0.0, 0.0),
#  'HS_pc': (0.0, 0.0),
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x': (0.0, 276.9428691451373),
#  'H_ic': (0.0, 1000.0),
#  'H_im': (0.0, 1000.0),
#  'H_pc': (-1000.0, 1000.0),
#  'H_tx': (0.0, 998.5454004610696),
#  'H_xc': (0.0, 1000.0),
#  'IGPSYN_RXN_p': (0.0, 0.0),
#  'ILE_PROTON_rev_vc': (0.0, 1000.0),
#  'ILE_PROTON_vc': (0.0, 1000.0),
#  'ILE_pc': (0.0, 0.0),
#  'IMIDPHOSDEHYD_RXN_p': (0.0, 0.0),
#  'IMPCYCLOHYDROLASE_RXN_p': (0.0, 0.0),
#  'INORGPYROPHOSPHAT_RXN_c': (0.0, 1000.0),
#  'INORGPYROPHOSPHAT_RXN_p': (0.0, 1000.0),
#  'INORGPYROPHOSPHAT_RXN_x': (0.0, 499.9999999999999),
#  'ISOCITDEH_RXN_c': (-1000.0, 1000.0),
#  'ISOCITDEH_RXN_m': (-990.0000000000005, 1000.0000000000016),
#  'ISOCITRATE_ACONITATE_mc': (-1000.0, 1000.0),
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m': (0.0, 1000.0),
#  'ISOCIT_CLEAV_RXN_x': (0.0, 549.8599439775905),
#  'ISOLEUCINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'K_biomass': (0.0, 0.0),
#  'K_ec': (0.0, 0.0),
#  'K_rev_vc': (0.0, 0.0),
#  'K_tx': (0.0, 0.0),
#  'LEUCINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'LEU_PROTON_rev_vc': (0.0, 1000.0),
#  'LEU_PROTON_vc': (0.0, 1000.0),
#  'LEU_pc': (0.0, 0.0),
#  'LYSINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'LYS_ORNITHINE_mc': (-1000.0, 1000.0000000000002),
#  'LYS_PROTON_rev_vc': (0.0, 999.9999999999999),
#  'LYS_PROTON_vc': (0.0, 1000.0),
#  'LYS_pc': (0.0, 0.0),
#  'L_ALPHA_ALANINE_PROTON_rev_vc': (0.0, 999.9999999999999),
#  'L_ALPHA_ALANINE_PROTON_vc': (0.0, 1000.0),
#  'L_ASCORBATE_PEROXIDASE_RXN_p': (0.0, 499.99999999999994),
#  'L_ASPARTATE_GLU_mc': (-1000.0, 1000.0),
#  'L_ASPARTATE_PROTON_rev_vc': (0.0, 1000.0),
#  'L_ASPARTATE_PROTON_vc': (0.0, 1000.0),
#  'L_ASPARTATE_pc': (-1000.0, 0.0),
#  'L_ASPARTATE_xc': (-1000.0, 1000.0),
#  'L_CITRULLINE_pc': (0.0, 1000.0000000000002),
#  'MALATE_DEHYDROGENASE_NADPs_RXN_p': (0.0, 1000.0),
#  'MALATE_DEH_RXN_c': (-1000.0, 1000.0),
#  'MALATE_DEH_RXN_m': (-1000.0, 1000.0),
#  'MALATE_DEH_RXN_p': (-1000.0, 1000.0),
#  'MALATE_DEH_RXN_x': (0.0, 276.94286914513737),
#  'MALIC_NADP_RXN_c': (0.0, 1000.0),
#  'MALIC_NADP_RXN_p': (0.0, 1000.0000000000002),
#  'MALIC_NAD_RXN_m': (0.0, 732.4206349206352),
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p': (0.0, 0.0),
#  'MALSYN_RXN_x': (0.0, 500.00000000000006),
#  'MALTODEG_RXN_c': (0.0, 499.99999999999994),
#  'MALTODEXGLUCOSID_RXN_p': (0.0, 999.9999999999995),
#  'MAL_ACONITATE_mc': (-1000.0, 1000.0),
#  'MAL_CIT_mc': (-1000.0, 1000.0),
#  'MAL_CIT_vc': (-1000.0000000000001, 999.9999999999994),
#  'MAL_ISOCITRATE_mc': (-1000.0, 1000.0),
#  'MAL_PROTON_rev_vc': (0.0, 1000.0),
#  'MAL_PROTON_vc': (0.0, 1000.0),
#  'MAL_Pi_mc': (-1000.0, 1000.0),
#  'MAL_SO4_mc': (-1000.0, 1000.0),
#  'MAL_SUC_mc': (-1000.0, 1000.0),
#  'MAL_xc': (-276.94286914513754, 500.0000000000001),
#  'MANNITOL_1_PHOSPHATE_RXN_c': (0.0, 1000.0000000000014),
#  'MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c': (0.0, 1000.0000000000014),
#  'MANNPGUANYLTRANGDP_RXN_c': (0.0, 1000.0000000000002),
#  'MANNPISOM_RXN_c': (0.0, 0.0),
#  'MDA_Fd_Ascorbate_p': (0.0, 1000.0000000000001),
#  'METHENYLTHFCYCLOHYDRO_RXN_c': (0.0, 957.7045177045167),
#  'METHIONINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'METHYLENETHFDEHYDROG_NADP_RXN_c': (0.0, 957.7045177045167),
#  'METHYLENE_THF_mc': (-1000.0000000000008, 1000.0),
#  'METHYLENE_THF_pc': (-1000.0000000000002, 1000.0000000000002),
#  'MET_PROTON_rev_vc': (0.0, 1000.0),
#  'MET_PROTON_vc': (0.0, 1000.0),
#  'MET_pc': (0.0, 0.0),
#  'MG2_rev_vc': (0.0, 0.0),
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c': (0.0, 0.0),
#  'MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_c': (0.0, 0.0),
#  'MYO_INOSITOL_OXYGENASE_RXN_c': (0.0, 0.0),
#  'Mehler_Reaction_p': (0.0, 1000.0),
#  'Mg_biomass': (0.0, 0.0),
#  'Mg_ec': (0.0, 0.0),
#  'Mg_tx': (0.0, 0.0),
#  'Mitochondrial_ATP_Synthase_m': (0.0, 979.351473922906),
#  'NADH_DEHYDROG_A_RXN_mc': (0.0, 339.12946428571433),
#  'NADH_DEHYDROG_A_RXN_mi': (0.0, 1000.0),
#  'NADH_KINASE_RXN_c': (0.0, 1000.0),
#  'NADPH_Dehydrogenase_p': (0.0, 1000.0),
#  'NADPHoxc_tx': (10.0, 10.0),
#  'NADPHoxm_tx': (10.0, 10.0),
#  'NADPHoxp_tx': (10.0, 10.0),
#  'NADPPHOSPHAT_RXN_c': (0.0, 1000.0),
#  'NH3_mc': (0.0, 1000.0),
#  'NH3_pc': (-999.9999999999998, 0.0),
#  'NH4_ec': (0.0, 0.0),
#  'NH4_tx': (0.0, 0.0),
#  'NITRATE_PROTON_rev_vc': (0.0, 500.0),
#  'NITRATE_REDUCTASE_NADH_RXN_c': (0.0, 0.0),
#  'NITRATE_vc': (0.0, 1000.0),
#  'NITRITE_pc': (0.0, 0.0),
#  'N_ACETYLGLUTPREDUCT_RXN_p': (0.0, 1000.0000000000002),
#  'Nitrate_ec': (0.0, 0.0),
#  'Nitrate_tx': (0.0, 0.0),
#  'O2_ec': (-95.93709043250323, 1000.0000000000002),
#  'O2_mc': (-1000.0, -5.000000000000114),
#  'O2_pc': (-990.0000000000009, 120.00000000000168),
#  'O2_tx': (-95.93709043250324, 1000.0000000000001),
#  'O2_xc': (-276.94286914513776, 0.0),
#  'OAA_ACONITATE_mc': (-1000.0, 1000.0),
#  'OAA_CIT_mc': (-1000.0, 1000.0),
#  'OAA_ISOCITRATE_mc': (-1000.0, 1000.0),
#  'OAA_MAL_mc': (-1000.0, 1000.0),
#  'OAA_MAL_pc': (-1000.0, 1000.0),
#  'OAA_Pi_mc': (-1000.0, 1000.0),
#  'OAA_SO4_mc': (-1000.0, 1000.0),
#  'OAA_SUC_mc': (-1000.0, 1000.0),
#  'OAA_xc': (-1000.0, 1000.0),
#  'ORNCARBAMTRANSFER_RXN_p': (0.0, 0.0),
#  'ORNITHINE_CITRULLINE_mc': (-1000.0, 1000.0),
#  'ORNITHINE_CITRULLINE_pc': (0.0, 1000.0000000000002),
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m': (0.0, 1000.0000000000005),
#  'PALMITATE_pc': (0.0, 0.0),
#  'PEPCARBOXYKIN_RXN_c': (0.0, 999.9999999999998),
#  'PEPCARBOX_RXN_c': (0.0, 1000.0),
#  'PEPDEPHOS_RXN_c': (0.0, 1000.0),
#  'PEPDEPHOS_RXN_p': (0.0, 1000.0),
#  'PEP_Pi_pc': (-1000.0, 1000.0),
#  'PGLUCISOM_RXN_c': (-1000.0, 998.4571428571426),
#  'PGLUCISOM_RXN_p': (-1000.0, 1000.0),
#  'PGLYCDEHYDROG_RXN_p': (0.0, 478.85225885225907),
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'PHE_PROTON_rev_vc': (0.0, 1000.0),
#  'PHE_PROTON_vc': (0.0, 1000.0),
#  'PHE_pc': (0.0, 0.0),
#  'PHOSGLYPHOS_RXN_c': (-1000.0000000000001, 1000.0000000000001),
#  'PHOSGLYPHOS_RXN_p': (-1000.0000000000001, 1000.0),
#  'PHOSPHOGLUCMUT_RXN_c': (-999.9999999999999, 583.3333333333336),
#  'PHOSPHOGLUCMUT_RXN_p': (-999.9999999999999, 0.0),
#  'PHOSPHORIBULOKINASE_RXN_p': (0.0, 1000.0),
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p': (0.0, 500.0000000000006),
#  'PRAISOM_RXN_p': (0.0, 0.0),
#  'PREPHENATEDEHYDROG_RXN_p': (0.0, 0.0),
#  'PREPHENATE_DEHYDROGENASE_NADP_RXN_p': (0.0, 0.0),
#  'PREPHENATE_TRANSAMINE_RXN_p': (0.0, 0.0),
#  'PRIBFAICARPISOM_RXN_p': (0.0, 0.0),
#  'PROTONATP_rev_vc': (0.0, 1000.0),
#  'PROTON_ATPase_c': (0.0, 1000.0),
#  'PROTON_PPi_rev_vc': (0.0, 1000.0),
#  'PRO_GLU_mc': (-999.9999999999992, 499.99999999999943),
#  'PRO_PROTON_rev_vc': (0.0, 1000.0),
#  'PRO_PROTON_vc': (0.0, 1000.0),
#  'PRO_mc': (-499.9999999999995, 1000.0),
#  'PRPPSYN_RXN_p': (0.0, 0.0),
#  'PRTRANS_RXN_p': (0.0, 0.0),
#  'PSERTRANSAM_RXN_p': (0.0, 478.85225885225924),
#  'PSII_RXN_p': (0.0, 250.0),
#  'PYRROLINECARBREDUCT_RXN_NADP_c': (0.0, 0.0),
#  'PYRROLINECARBREDUCT_RXN_NAD_c': (0.0, 0.0),
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_c': (0.0, 1000.0),
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p': (0.0, 999.9999999999997),
#  'PYRUVATE_PROTON_mc': (-657.8787878787878, 540.7994078460397),
#  'PYRUVATE_pc': (-1000.0, 1000.0),
#  'PYRUVDEH_RXN_m': (0.0, 657.8787878787875),
#  'PYRUVDEH_RXN_p': (0.0, 0.0),
#  'Phloem_output_tx': (0.0, 0.0),
#  'Photon_ep': (0.0, 1000.0),
#  'Photon_tx': (0.0, 1000.0),
#  'Pi_PROTON_mc': (-1000.0, 1000.0),
#  'Pi_ec': (0.0, 0.0),
#  'Pi_tx': (0.0, 0.0),
#  'Pi_xc': (0.0, 1000.0000000000008),
#  'Plastidial_ATP_Synthase_p': (0.0, 428.5714285714285),
#  'Plastoquinol_Oxidase_p': (0.0, 750.0000000000014),
#  'Protein_Polymerisation_c': (0.0, 0.0),
#  'Protein_Processing_c': (0.0, 0.0),
#  'Protein_Translocation_c': (0.0, 0.0),
#  'RIB5PISOM_RXN_p': (-333.3333333333342, 324.5454545454531),
#  'RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p': (0.0, 1000.0),
#  'RIBULP3EPIM_RXN_c': (0.0, 1000.0),
#  'RIBULP3EPIM_RXN_p': (-747.9550511793498, 666.6666666666672),
#  'RXN0_1483_c': (0.0, 500.0000000000001),
#  'RXN0_2381_p': (0.0, 0.0),
#  'RXN0_2382_p': (0.0, 0.0),
#  'RXN0_5114_p': (0.0, 478.85225885225907),
#  'RXN0_5184_c': (0.0, 499.99999999999983),
#  'RXN0_5224_c': (0.0, 1000.0),
#  'RXN0_5224_p': (0.0, 0.0),
#  'RXN0_5260_m': (0.0, 999.9999999999983),
#  'RXN0_5330_NADP_c': (0.0, 1000.0),
#  'RXN0_5330_NADP_mc': (0.0, 1000.0),
#  'RXN0_5330_NADP_mi': (0.0, 1000.0),
#  'RXN0_5330_NAD_c': (0.0, 1000.0),
#  'RXN0_5330_NAD_mc': (0.0, 1000.0),
#  'RXN0_5330_NAD_mi': (0.0, 1000.0),
#  'RXN1F_66_p': (-555.0000000000009, 0.0),
#  'RXN490_3650_p': (0.0, 1000.0),
#  'RXN66_1_c': (0.0, 1000.0),
#  'RXN66_3_c': (0.0, 500.00000000000006),
#  'RXN66_3_m': (0.0, 499.9999999999998),
#  'RXN_10745_NAD_c': (0.0, 1000.0),
#  'RXN_10786_c': (0.0, 1000.0000000000003),
#  'RXN_12541_c': (0.0, 1000.0000000000001),
#  'RXN_14351_pc': (0.0, 500.0),
#  'RXN_1461_c': (0.0, 980.238095238095),
#  'RXN_1826_p': (0.0, 999.9999999999995),
#  'RXN_1827_p': (0.0, 499.9999999999999),
#  'RXN_2141_p': (0.0, 499.9999999999998),
#  'RXN_3521_p': (0.0, 499.99999999999994),
#  'RXN_3522_p': (0.0, 500.00000000000006),
#  'RXN_3523_p': (0.0, 500.0),
#  'RXN_5682_p': (0.0, 0.0),
#  'RXN_6883_mc': (0.0, 1000.0),
#  'RXN_6883_mi': (0.0, 1000.0),
#  'RXN_6884_m': (0.0, 995.0000000000006),
#  'RXN_6902_m': (0.0, 657.8787878787874),
#  'RXN_7183_NADP_m': (0.0, 1000.0000000000003),
#  'RXN_7674_p': (0.0, 555.0000000000009),
#  'RXN_7676_p': (0.0, 554.9999999999999),
#  'RXN_7677_p': (0.0, 555.0000000000008),
#  'RXN_7678_NADP_p': (0.0, 555.0000000000002),
#  'RXN_7678_NAD_p': (0.0, 555.0000000000009),
#  'RXN_7679_p': (0.0, 555.0000000000009),
#  'RXN_7737_p': (0.0, 0.0),
#  'RXN_7800_p': (0.0, 0.0),
#  'RXN_7978_p': (0.0, 1000.0),
#  'RXN_7979_p': (0.0, 1000.0),
#  'RXN_7984_p': (0.0, 1000.0000000000002),
#  'RXN_7985_p': (0.0, 1000.0000000000001),
#  'RXN_8001_p': (0.0, 0.0),
#  'RXN_8991_p': (0.0, 0.0),
#  'RXN_9104_c': (0.0, 0.0),
#  'RXN_9514_p': (0.0, 0.0),
#  'RXN_9516_p': (0.0, 0.0),
#  'RXN_9518_p': (0.0, 0.0),
#  'RXN_9520_p': (0.0, 0.0),
#  'RXN_9523_p': (0.0, 0.0),
#  'RXN_9524_p': (0.0, 0.0),
#  'RXN_9527_p': (0.0, 0.0),
#  'RXN_9528_p': (0.0, 0.0),
#  'RXN_9531_p': (0.0, 0.0),
#  'RXN_9532_p': (0.0, 0.0),
#  'RXN_9533_p': (0.0, 0.0),
#  'RXN_9535_p': (0.0, 0.0),
#  'RXN_9536_p': (0.0, 0.0),
#  'RXN_9537_p': (0.0, 0.0),
#  'RXN_9539_p': (0.0, 0.0),
#  'RXN_9540_p': (0.0, 0.0),
#  'RXN_9549_p': (0.0, 0.0),
#  'RXN_961_p': (0.0, 553.8857382902747),
#  'RXN_9648_p': (0.0, 0.0),
#  'RXN_9650_p': (0.0, 0.0),
#  'RXN_9651_p': (0.0, 0.0),
#  'RXN_9652_p': (0.0, 0.0),
#  'RXN_9653_p': (0.0, 0.0),
#  'RXN_9654_p': (0.0, 0.0),
#  'RXN_9655_p': (0.0, 0.0),
#  'RXN_9657_p': (0.0, 0.0),
#  'RXN_9658_p': (0.0, 0.0),
#  'RXN_9659_p': (0.0, 0.0),
#  'RXN_9660_p': (0.0, 0.0),
#  'RXN_9661_p': (0.0, 0.0),
#  'RXN_9662_p': (0.0, 0.0),
#  'RXN_9663_p': (0.0, 0.0),
#  'RXN_969_x': (0.0, 553.8857382902747),
#  'SEDOBISALDOL_RXN_p': (0.0, 1000.0),
#  'SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p': (0.0, 999.9999999999999),
#  'SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x': (0.0, 276.9428691451376),
#  'SERINE_O_ACETTRAN_RXN_c': (0.0, 0.0),
#  'SERINE_O_ACETTRAN_RXN_p': (0.0, 0.0),
#  'SERINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'SER_PROTON_rev_vc': (0.0, 1000.0000000000001),
#  'SER_PROTON_vc': (0.0, 1000.0),
#  'SER_mc': (-1000.0000000000002, 1000.0),
#  'SER_pc': (-1000.0, 999.9999999999997),
#  'SER_xc': (-276.94286914513737, 0.0),
#  'SHIKIMATE_5_DEHYDROGENASE_RXN_p': (0.0, 0.0),
#  'SHIKIMATE_KINASE_RXN_p': (0.0, 0.0),
#  'SO4_ec': (0.0, 0.0),
#  'SO4_pc': (0.0, 0.0),
#  'SO4_tx': (0.0, 0.0),
#  'SPONTPRO_RXN_c': (0.0, 0.0),
#  'SPONTPRO_RXN_m': (0.0, 999.9999999999998),
#  'SUCCCOASYN_RXN_m': (0.0, 610.4056437389773),
#  'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m': (0.0, 610.4056437389772),
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc': (0.0, 657.878787878788),
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mi': (0.0, 657.878787878788),
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m': (0.0, 657.878787878788),
#  'SUCCINYL_COA_HYDROLASE_RXN_m': (0.0, 610.4056437389768),
#  'SUCROSE_PHOSPHATASE_RXN_c': (0.0, 998.5454004610696),
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c': (0.0, 998.5454004610696),
#  'SUCROSE_PROTON_rev_vc': (0.0, 1000.0),
#  'SUCROSE_PROTON_vc': (0.0, 1000.0),
#  'SUCROSE_SYNTHASE_RXN_c': (0.0, 1000.0),
#  'SUC_ACONITATE_mc': (-1000.0, 1000.0),
#  'SUC_CIT_mc': (-1000.0, 1000.0),
#  'SUC_FUM_mc': (-1000.0, 1000.0),
#  'SUC_ISOCITRATE_mc': (-1000.0, 1000.0),
#  'SUC_Pi_mc': (-1000.0, 1000.0),
#  'SUC_SO4_mc': (-1000.0, 1000.0),
#  'SUC_xc': (0.0, 549.8599439775904),
#  'SULFATE_ADENYLYLTRANS_RXN_p': (0.0, 0.0),
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p': (0.0, 0.0),
#  'SUPEROX_DISMUT_RXN_c': (0.0, 1000.0000000000001),
#  'SUPEROX_DISMUT_RXN_p': (0.0, 500.0),
#  'Starch_biomass': (0.0, 0.0),
#  'Sucrose_ec': (-7.99475753604194, 83.33333333333343),
#  'Sucrose_tx': (-7.99475753604194, 83.33333333333343),
#  'THF_mc': (-1000.0, 1000.0000000000002),
#  'THF_pc': (-1000.0, 1000.0),
#  'THREDEHYD_RXN_p': (0.0, 0.0),
#  'THREONINE_ALDOLASE_RXN_c': (0.0, 500.0000000000002),
#  'THREONINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'THREO_DS_ISO_CITRATE_xc': (-549.8599439775916, 0.0),
#  'THRESYN_RXN_p': (0.0, 500.00000000000006),
#  'THR_PROTON_rev_vc': (0.0, 1000.0),
#  'THR_PROTON_vc': (0.0, 1000.0),
#  'THR_pc': (0.0, 500.00000000000017),
#  'TRANSALDOL_RXN_p': (-324.54545454545456, 1000.0),
#  'TRIOSEPISOMERIZATION_RXN_c': (-1000.0, 1000.0),
#  'TRIOSEPISOMERIZATION_RXN_p': (-1000.0, 1000.0),
#  'TRP_PROTON_rev_vc': (0.0, 1000.0),
#  'TRP_PROTON_vc': (0.0, 1000.0),
#  'TRP_pc': (0.0, 0.0),
#  'TYRAMINOTRANS_RXN_p': (0.0, 0.0),
#  'TYROSINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'TYR_PROTON_rev_vc': (0.0, 1000.0),
#  'TYR_PROTON_vc': (0.0, 1000.0),
#  'TYR_pc': (0.0, 0.0),
#  'UDPKIN_RXN_c': (-83.3333333333329, 999.9999999999994),
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c': (0.0, 0.0),
#  'UGD_RXN_c': (0.0, 0.0),
#  'VALINE_TRNA_LIGASE_RXN_c': (0.0, 0.0),
#  'VAL_PROTON_rev_vc': (0.0, 1000.0),
#  'VAL_PROTON_vc': (0.0, 1000.0),
#  'VAL_pc': (0.0, 0.0),
#  'X5P_Pi_pc': (-1000.0, 0.0),
#  'Xylan_biomass': (0.0, 0.0),
#  'diel_biomass': (0.0, 0.0),
#  'pALA_biomass': (0.0, 0.0),
#  'pARG_biomass': (0.0, 0.0),
#  'pASN_biomass': (0.0, 0.0),
#  'pASP_biomass': (0.0, 0.0),
#  'pGLN_biomass': (0.0, 0.0),
#  'pGLU_biomass': (0.0, 0.0),
#  'pGLY_biomass': (0.0, 0.0),
#  'pHIS_biomass': (0.0, 0.0),
#  'pILE_biomass': (0.0, 0.0),
#  'pLEU_biomass': (0.0, 0.0),
#  'pLYS_biomass': (0.0, 0.0),
#  'pMET_biomass': (0.0, 0.0),
#  'pPHE_biomass': (0.0, 0.0),
#  'pSER_biomass': (0.0, 0.0),
#  'pTHR_biomass': (0.0, 0.0),
#  'pTYR_biomass': (0.0, 0.0),
#  'pVAL_biomass': (0.0, 0.0),
#  'sALA_biomass': (0.0, 0.0),
#  'sASP_biomass': (0.0, 0.0),
#  'sCIT_biomass': (0.0, 0.0),
#  'sFUM_biomass': (0.0, 0.0),
#  'sGABA_biomass': (0.0, 0.0),
#  'sGLN_biomass': (0.0, 0.0),
#  'sGLU_biomass': (0.0, 0.0),
#  'sMAL_biomass': (0.0, 0.0),
#  'sSUCROSE_biomass': (0.0, 0.0),
#  'sSUC_biomass': (0.0, 0.0),
#  'unlProtHYPO_c': (0.0, 998.5454004610688)}

# %%
FVA.FVA(new, reaclist = new.reactions, cobra = True)
FVA.FluxVariability(new, fva=fva)

# %%
FVA.FluxRange(new, 'Sucrose_tx')
FVA.InternalCycles(new)
# Out:
# Process PoolWorker-3:
# Process PoolWorker-4:
# Traceback (most recent call last):
# Process PoolWorker-1:
# Process PoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     result = (True, func(*args, **kwds))
#     self.run()
#   File "scobra/analysis/FVA.py", line 88, in FluxRange
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     model.ZeroObjective()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "scobra/classes/model.py", line 441, in ZeroObjective
#     self._target(*self._args, **self._kwargs)
#     self.SetObjective({reac:0})
#     self._target(*self._args, **self._kwargs)
#   File "scobra/classes/model.py", line 405, in SetObjective
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     reac.objective_coefficient = reacval
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/cobra/core/reaction.py", line 178, in objective_coefficient
#     set_objective(self.model, {self: value}, additive=True)
#     result = (True, func(*args, **kwds))
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/cobra/util/solver.py", line 113, in set_objective
#     reverse_value = model.solver.objective.expression
#   File "scobra/analysis/FVA.py", line 88, in FluxRange
#     result = (True, func(*args, **kwds))
#   File "scobra/analysis/FVA.py", line 88, in FluxRange
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/optlang/interface.py", line 431, in expression
#     model.ZeroObjective()
#   File "scobra/classes/model.py", line 441, in ZeroObjective
#   File "scobra/analysis/FVA.py", line 98, in FluxRange
#     self.SetObjective({reac:0})
#     if math.isnan(model.solution.f):
#     return self._get_expression()
#     model.ZeroObjective()
#   File "scobra/classes/model.py", line 405, in SetObjective
#   File "scobra/classes/model.py", line 174, in solution
#     return get_solution(self)
#     reac.objective_coefficient = reacval
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/optlang/glpk_interface.py", line 324, in _get_expression
#   File "scobra/classes/model.py", line 441, in ZeroObjective
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/cobra/core/reaction.py", line 177, in objective_coefficient
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/cobra/core/solution.py", line 314, in get_solution
#     constr_duals = model.solver.shadow_prices
#     if self.flux_expression is not None:
#     self.SetObjective({reac:0})
#     self._expression = expression + getattr(self.problem, "_objective_offset", 0)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/cobra/core/reaction.py", line 126, in flux_expression
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/optlang/interface.py", line 416, in problem
#   File "scobra/classes/model.py", line 405, in SetObjective
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/optlang/interface.py", line 1287, in shadow_prices
#     return 1. * self.forward_variable - 1. * self.reverse_variable
#     reac.objective_coefficient = reacval
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/decorators.py", line 91, in __sympifyit_wrapper
#     @property
#     zip(self._get_constraint_names(), self._get_shadow_prices())
#   File "/usr/lib/python2.7/collections.py", line 69, in __init__
#     return func(a, b)
#     self.__update(*args, **kwds)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/cobra/core/reaction.py", line 178, in objective_coefficient
# KeyboardInterrupt
#   File "/home/kristoforus/compbio/updating_scobra/lib/python2.7/_abcoll.py", line 572, in update
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/decorators.py", line 132, in binary_op_wrapper
#     set_objective(self.model, {self: value}, additive=True)
#     self[key] = value
#     return func(self, other)
#   File "/usr/lib/python2.7/collections.py", line 79, in __setitem__
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/cobra/util/solver.py", line 113, in set_objective
#     return dict_setitem(self, key, value)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/expr.py", line 130, in __sub__
# KeyboardInterrupt
#     reverse_value = model.solver.objective.expression
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/optlang/interface.py", line 431, in expression
#     return self._get_expression()
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/optlang/glpk_interface.py", line 323, in _get_expression
#     expression = symbolics.add([symbolics.mul(term) for term in term_generator()])
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/optlang/glpk_interface.py", line 318, in term_generator
#     return Add(self, -other)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/cache.py", line 93, in wrapper
#     for index in range(1, glp_get_num_cols(self.problem.problem) + 1):
# KeyboardInterrupt
#     retval = cfunc(*args, **kwargs)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/compatibility.py", line 809, in wrapper
#     result = user_function(*args, **kwds)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/operations.py", line 41, in __new__
#     c_part, nc_part, order_symbols = cls.flatten(args)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/add.py", line 219, in flatten
#     newseq.append(Mul(c, s))
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/cache.py", line 93, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/compatibility.py", line 809, in wrapper
#     result = user_function(*args, **kwds)
#   File "/home/kristoforus/compbio/updating_scobra/local/lib/python2.7/site-packages/sympy/core/operations.py", line 33, in __new__
#     if not options.pop('evaluate', global_evaluate[0]):
# KeyboardInterrupt

# %%
print('Test Completed')

# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
gparentdir = os.path.dirname(os.path.dirname(currentdir))
sys.path.insert(0, gparentdir)
import scobra
import get_all_functions as gaf
import re
new = scobra.Model("sample/Diel_Leaf_Model_cleaned.xls")
#new = scobra.model(n)

#new=scobra.Model('models/Diel_Leaf_Model_cleaned.xls')

#Maximize Sucrose output (objective)
#vary light (scan)
#allow CO2 and O2, even Proton and Water
#Output maintenance ATP and NADPHox
tx_and_biomass = []
for i in new.Reactions(): 
    if '_tx' in i:
        tx_and_biomass.append(re.search('(.*)_tx', i).group())
    elif '_biomass' in i: 
        tx_and_biomass.append(re.search('(.*)_biomass', i).group())
#tx_and_biomass.append(re.search('(.*)_tx', 'slkdfjd_tx').group())
tx_and_biomass

necessary_rxn= ['ATPase_tx', 'CO2_tx', 'Photon_tx', 'O2_tx','H2O_tx', 'H_tx','NADPHoxc_tx','NADPHoxm_tx','NADPHoxp_tx','Sucrose_tx']
unecessary_rxn= list(set(tx_and_biomass) - set(necessary_rxn))

#blocking _tx and _biomass reactions that are not considered
for i in unecessary_rxn: 
    new.GetReaction(i).lower_bound = 0.0
    new.GetReaction(i).upper_bound = 0.0

#freeing _tx and _biomass reactions that are considered
for i in necessary_rxn: 
    if new.GetReaction(i).lower_bound == 0.0:
        new.GetReaction(i).upper_bound == 1000.0
    else: 
        new.GetReaction(i).lower_bound == 1000.0
        new.GetReaction(i).upper_bound == 1000.0

#setting constraints
new.SetConstraint('ATPase_tx', 90, 90)
new.SetConstraint('NADPHoxc_tx', 10, 10)
new.SetConstraint('NADPHoxm_tx', 10, 10)
new.SetConstraint('NADPHoxp_tx', 10, 10)
#setting constraints for sucrose entering and exiting cytoplasm
new.SetConstraint('Sucrose_ec', -1000, 1000)

#setting objectives
new.SetObjective('Sucrose_tx')
new.SetObjDirec('Min')

#setting constraint and running scan
#result = {}
#for i in range(0,1000,20):
#    new.SetConstraint('Photon_tx', i, i)
#    new.Solve()
#    x = new.GetSol()['Sucrose_tx']
#    result[i] = x

#new.Solve() 
#new.MinFluxSolve()

new.Solve()
# Out:
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(  )' for <Reaction HEXOKINASE_RXN_MANNOSE_c at 0x7fd851ea3c10>
# optimal

# %%
import scobra.analysis.Graph as graph

# %%
graph.DeadMetabolites(new, reaclist=new.reactions, cobra=True) #will not work with the default cobra=False
# Out:
# no
# ['Acetoacetyl_ACPs_p',
#  'LEU_p',
#  'Charged_ALA_tRNAs_c',
#  'CPD_7100_p',
#  'R_3_hydroxyhexanoyl_ACPs_p',
#  'LYS_tRNAs_c',
#  'PHOSPHORIBOSYL_ATP_p',
#  'pGLY_b',
#  'R_3_Hydroxypalmitoyl_ACPs_p',
#  'HS_p',
#  'HS_c',
#  'pHIS_b',
#  'NITRATE_e',
#  'L_GLUTAMATE_5_P_c1_p',
#  'VAL_p',
#  'ARG_tRNAs_c',
#  'MALONYL_ACP_p',
#  'PRPP_p',
#  'Crotonyl_ACPs_p',
#  'Protein_tranlocation_cost_c',
#  '3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_p',
#  'Charged_MET_tRNAs_c',
#  'MGII_v',
#  'MGII_e',
#  'MGII_c',
#  'ADENYLOSUCC_p',
#  'sSUC_b',
#  'sGLN_b',
#  'L_GLUTAMATE_GAMMA_SEMIALDEHYDE_c1_p',
#  '3_oxo_decanoyl_ACPs_p',
#  'HIS_tRNAs_c',
#  'THR_tRNAs_c',
#  'UDP_D_XYLOSE_c',
#  'Charged_GLY_tRNAs_c',
#  'L_ARGININO_SUCCINATE_c',
#  'UDP_GLUCURONATE_c',
#  'CPD_510_c',
#  'GLUCURONATE_c',
#  'sGLU_b',
#  'SHIKIMATE_5P_p',
#  '2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_p',
#  'sALA_b',
#  'Charged_ASN_tRNAs_c',
#  'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_p',
#  'L_HISTIDINOL_P_p',
#  'LL_DIAMINOPIMELATE_p',
#  'Charged_ILE_tRNAs_c',
#  '3_oxo_dodecanoyl_ACPs_p',
#  '2K_4CH3_PENTANOATE_p',
#  'aHS_c',
#  'INDOLE_p',
#  'CO_A_p',
#  'P_HYDROXY_PHENYLPYRUVATE_p',
#  'PALMITATE_p',
#  'PALMITATE_c',
#  'CYS_p',
#  'Charged_ARG_tRNAs_c',
#  'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_p',
#  'ASP_tRNAs_c',
#  'SO3_p',
#  'pPHE_b',
#  'aGDP_p',
#  'HOMO_CYS_c',
#  'Hexanoyl_ACPs_p',
#  'IMP_p',
#  'X_Phloem_contribution_t1_',
#  'MALONYL_COA_p',
#  'HOMO_CYS_p',
#  'PHE_tRNAs_c',
#  'pVAL_b',
#  'pTYR_b',
#  'sMAL_b',
#  'Trans_D2_decenoyl_ACPs_p',
#  'L_DELTA1_PYRROLINE_5_CARBOXYLATE_c1_p',
#  'Starch_b',
#  '3_CARBOXY_3_HYDROXY_ISOCAPROATE_p',
#  'pTHR_b',
#  'Charged_GLN_tRNAs_c',
#  '2_KETO_3_METHYL_VALERATE_p',
#  'MESO_DIAMINOPIMELATE_p',
#  'Charged_THR_tRNAs_c',
#  '3_DEHYDRO_SHIKIMATE_p',
#  'INDOLE_3_GLYCEROL_P_p',
#  'PREPHENATE_p',
#  'ACETYL_COA_c',
#  'Glycerol_b',
#  'APS_p',
#  'Beta_3_hydroxybutyryl_ACPs_p',
#  'CHORISMATE_p',
#  'SER_tRNAs_c',
#  'Decanoyl_ACPs_p',
#  'ILE_p',
#  '2_KETO_ISOVALERATE_p',
#  'bHISTIDINAL_p',
#  'KI_v',
#  'ILE_tRNAs_c',
#  '2_ACETO_2_HYDROXY_BUTYRATE_p',
#  'Protein_polymerisation_cost_c',
#  'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_p',
#  'MET_tRNAs_c',
#  'aSO3_p',
#  'LYS_p',
#  'TYR_p',
#  'AICAR_p',
#  'sFUM_b',
#  'TRP_p',
#  'GTP_p',
#  'pSER_b',
#  'Charged_GLT_tRNAs_c',
#  'ANTHRANILATE_p',
#  'Charged_HIS_tRNAs_c',
#  'CPD_659_p',
#  'GLY_tRNAs_c',
#  'Dodecanoyl_ACPs_p',
#  'Mg_b',
#  '2_ACETO_LACTATE_p',
#  'pMET_b',
#  'KI_c',
#  'CAII_e',
#  'Myristoyl_ACPs_p',
#  'sGABA_b',
#  'NITRITE_c',
#  'HISTIDINOL_p',
#  'CO_A_c',
#  'Protein_processing_cost_c',
#  'NITRITE_p',
#  'Charged_SER_tRNAs_c',
#  'Palmitoyl_ACPs_p',
#  'VAL_tRNAs_c',
#  'TYR_tRNAs_c',
#  'GLT_tRNAs_c',
#  'FUM_p',
#  '2_Octenoyl_ACPs_p',
#  'FUM_v',
#  'aFUM_v',
#  '2_OXOBUTANOATE_p',
#  'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_p',
#  'sASP_b',
#  'HIS_p',
#  'ALA_tRNAs_c',
#  'KI_e',
#  'CELLULOSE_c',
#  'Butanoyl_ACPs_p',
#  'CPD_9451_p',
#  'AMMONIUM_e',
#  '3_oxo_palmitoyl_ACPs_p',
#  '5_METHYL_THF_c',
#  'Charged_TYR_tRNAs_c',
#  'K_b',
#  '5_METHYL_THF_p',
#  'ACETYLSERINE_p',
#  'Tetradec_2_enoyl_ACPs_p',
#  'pGLU_b',
#  'ACETYL_COA_p',
#  'Octanoyl_ACPs_p',
#  'HCO3_p',
#  'pALA_b',
#  'sCIT_b',
#  '3_Oxo_octanoyl_ACPs_p',
#  'XYLAN_c',
#  'Hex_2_enoyl_ACPs_p',
#  'aGTP_p',
#  'pLEU_b',
#  'R_3_hydroxymyristoyl_ACPs_p',
#  'ACETYLSERINE_c',
#  '3_ENOLPYRUVYL_SHIKIMATE_5P_p',
#  'PHOSPHORIBOSYL_AMP_p',
#  '2_Hexadecenoyl_ACPs_p',
#  'Charged_PHE_tRNAs_c',
#  'FattyAcid_b',
#  'ACP_p',
#  'ASN_tRNAs_c',
#  'Cellulose_b',
#  'R_3_hydroxydodecanoyl_ACPs_p',
#  'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_p',
#  '3_Hydroxy_octanoyl_ACPs_p',
#  'Ca_b',
#  'HISTIDINAL_p',
#  '1_KETO_2_METHYLVALERATE_p',
#  'Charged_LEU_tRNAs_c',
#  'pILE_b',
#  'aPRPP_p',
#  'Xylan_b',
#  'Charged_LYS_tRNAs_c',
#  'L_CYSTATHIONINE_p',
#  'SHIKIMATE_p',
#  'N_5_PHOSPHORIBOSYL_ANTHRANILATE_p',
#  'LEU_tRNAs_c',
#  '3_oxo_myristoyl_ACPs_p',
#  'PHE_p',
#  'PHOSPHORIBOSYL_FORMIMINO_AICAR_P_p',
#  'ACET_p',
#  'Beta_hydroxydecanoyl_ACPs_p',
#  'Charged_VAL_tRNAs_c',
#  'Charged_ASP_tRNAs_c',
#  'pGLN_b',
#  'pASP_b',
#  'pASN_b',
#  'Dodec_2_enoyl_ACPs_p',
#  'CAII_v',
#  'GLN_tRNAs_c',
#  'pLYS_b',
#  'CAII_c',
#  'IMIDAZOLE_ACETOL_P_p',
#  '2_3_DIHYDRODIPICOLINATE_p',
#  'MYO_INOSITOL_c',
#  'Pi_e',
#  '1_L_MYO_INOSITOL_1_P_c',
#  'MET_p',
#  'DIOH_ISOVALERATE_p',
#  'GLC_e',
#  'sSUCROSE_b',
#  'GDP_p',
#  '3_oxo_hexanoyl_ACPs_p',
#  'SULFATE_e',
#  'DEHYDROQUINATE_p',
#  'SULFATE_p',
#  'pARG_b']

# %%
graph.NoDeadEndModel(new)
# Out:
# <model None at 0x7f8aaa01ef10>

# %%
graph.DeadEndMetabolites(new)
# Out:
# ['Cellulose_b',
#  'sSUC_b',
#  'Glycerol_b',
#  'aFUM_v',
#  'sGLN_b',
#  'Starch_b',
#  'sGLU_b',
#  'sASP_b',
#  'Xylan_b',
#  'sGABA_b',
#  'sFUM_b',
#  'sALA_b',
#  'X_Phloem_contribution_t1_',
#  'sMAL_b',
#  'FattyAcid_b',
#  'sCIT_b',
#  'FUM_v']

# %%
graph.PeripheralMetabolites(new)
# Out:
# ['sGABA_b',
#  'sASP_b',
#  'Cellulose_b',
#  'sFUM_b',
#  'FUM_v',
#  'sGLU_b',
#  'sALA_b',
#  'sMAL_b',
#  'FattyAcid_b',
#  'Glycerol_b',
#  'aFUM_v',
#  'X_Phloem_contribution_t1_',
#  'sCIT_b',
#  'Xylan_b',
#  'sSUC_b',
#  'Starch_b',
#  'sGLN_b']

# %%
graph.ChokepointReactions(new)
# Out:
# ['10_FORMYL_THF_pc',
#  'CYTOCHROME_C_OXIDASE_RXN_mc',
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc',
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mi',
#  'CYTOCHROME_C_OXIDASE_RXN_mi',
#  '1_PERIOD_1_PERDIOD_1_PERIOD_255_RXN_c',
#  'HEXOKINASE_RXN_MANNOSE_c',
#  'MANNITOL_1_PHOSPHATE_RXN_c',
#  'FORMATE_mc',
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p',
#  '1_PERIOD_8_PERIOD_4_PERIOD_9_RXN_p',
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p',
#  'SULFATE_ADENYLYLTRANS_RXN_p',
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p',
#  '2OXOGLUTARATEDEH_RXN_m',
#  '2_ISOPROPYLMALATESYN_RXN_p',
#  '3_ISOPROPYLMALISOM_RXN_p',
#  '2_PERIOD_3_PERIOD_1_PERIOD_180_RXN_p',
#  'RXN_9514_p',
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p',
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c',
#  'CONIFERIN_BETA_GLUCOSIDASE_RXN_c',
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p',
#  'CHORISMATE_SYNTHASE_RXN_p',
#  'SHIKIMATE_KINASE_RXN_p',
#  'GDPKIN_RXN_c',
#  '2_PERIOD_7_PERIOD_7_PERIOD_13_RXN_c',
#  'MANNPGUANYLTRANGDP_RXN_c',
#  '2_PERIOD_7_PERIOD_7_PERIOD_34_RXN_c',
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c',
#  '3_DEHYDROQUINATE_SYNTHASE_RXN_p',
#  '3_DEHYDROQUINATE_DEHYDRATASE_RXN_p',
#  'SHIKIMATE_5_DEHYDROGENASE_RXN_p',
#  'DAHPSYN_RXN_p',
#  '3_ISOPROPYLMALDEHYDROG_RXN_p',
#  'RXN_7800_p',
#  'RXN_8991_p',
#  '4_AMINO_BUTYRATE_PROTON_vc',
#  '4_AMINO_BUTYRATE_PROTON_rev_vc',
#  '4_AMINO_BUTYRATE_mc',
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p',
#  'RXN_9524_p',
#  '4_PERIOD_2_PERIOD_1_PERIOD_59_RXN_p',
#  'RXN_9659_p',
#  'RXN_9540_p',
#  '4_PERIOD_2_PERIOD_1_PERIOD_61_RXN_p',
#  'RXN_9663_p',
#  '5_METHYL_THF_pc',
#  '6PGLUCONOLACT_RXN_c',
#  '6PGLUCONDEHYDROG_RXN_c',
#  'RIBULP3EPIM_RXN_c',
#  '6PGLUCONOLACT_RXN_p',
#  '6PGLUCONDEHYDROG_RXN_p',
#  'GLU6PDEHYDROG_RXN_c',
#  'GLU6PDEHYDROG_RXN_p',
#  'ACETALD_mc',
#  'AMP_ATP_xc',
#  'ACETATE_COA_LIGASE_RXN_x',
#  'INORGPYROPHOSPHAT_RXN_x',
#  'ACET_xc',
#  'ACETOLACTSYN_RXN_p',
#  'ACETOLACTREDUCTOISOM_RXN_p',
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p',
#  'ACETOOHBUTSYN_RXN_p',
#  'ACETOOHBUTREDUCTOISOM_RXN_p',
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p',
#  'GLUTAMATE_N_ACETYLTRANSFERASE_RXN_p',
#  'ACETYLGLUTKIN_RXN_p',
#  'N_ACETYLGLUTPREDUCT_RXN_p',
#  'ACETYLORNTRANSAM_RXN_p',
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p',
#  'RXN0_5224_p',
#  'ACET_mc',
#  'SERINE_O_ACETTRAN_RXN_c',
#  'ACSERLY_RXN_c',
#  'HS_pc',
#  'CYSPH_RXN_p',
#  'SERINE_O_ACETTRAN_RXN_p',
#  'ACSERLY_RXN_p',
#  'IMPCYCLOHYDROLASE_RXN_p',
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p',
#  'GDPKIN_RXN_p',
#  'AMPSYN_RXN_p',
#  'AICARTRANSFORM_RXN_p',
#  'GLUTAMIDOTRANS_RXN_p',
#  'ALANINE_AMINOTRANSFERASE_RXN_m',
#  'ALANINE_AMINOTRANSFERASE_RXN_x',
#  'pALA_biomass',
#  'ALANINE_TRNA_LIGASE_RXN_c',
#  'ALCOHOL_DEHYDROG_RXN_c',
#  'FUM_pc',
#  'ARGININE_TRNA_LIGASE_RXN_c',
#  'pARG_biomass',
#  'ARGSUCCINSYN_RXN_c',
#  'ARGSUCCINLYA_RXN_c',
#  'ARG_PROTON_vc',
#  'ARG_PROTON_rev_vc',
#  'ASN_PROTON_vc',
#  'ASN_PROTON_rev_vc',
#  'pASN_biomass',
#  'ASPARAGINE_TRNA_LIGASE_RXN_c',
#  'ASPARTATEKIN_RXN_p',
#  'ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_p',
#  'ASPARTATE_TRNA_LIGASE_RXN_c',
#  'pASP_biomass',
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p',
#  'HISTPRATPHYD_RXN_p',
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c',
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_p',
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p',
#  'pSER_biomass',
#  'Biomass_tx',
#  'pTHR_biomass',
#  'pGLU_biomass',
#  'pTYR_biomass',
#  'Ca_biomass',
#  'pVAL_biomass',
#  'Mg_biomass',
#  'pGLN_biomass',
#  'K_biomass',
#  'pGLY_biomass',
#  'pHIS_biomass',
#  'pILE_biomass',
#  'pLEU_biomass',
#  'pLYS_biomass',
#  'pMET_biomass',
#  'pPHE_biomass',
#  'Ca_ec',
#  'CA2_rev_vc',
#  'PHE_pc',
#  'PREPHENATE_TRANSAMINE_RXN_p',
#  'RXN_969_x',
#  'CATAL_RXN_x',
#  'Cellulose_biomass',
#  'CHORISMATEMUT_RXN_p',
#  'PYRUVDEH_RXN_m',
#  'CITSYN_RXN_m',
#  'CIT_xc',
#  'HOMOSERKIN_RXN_p',
#  'CYS_PROTON_vc',
#  'CYS_PROTON_rev_vc',
#  'O2_mc',
#  'Ca_tx',
#  'LYS_pc',
#  'DIAMINOPIMEPIM_RXN_p',
#  'DIAMINOPIMDECARB_RXN_p',
#  'RXN_7737_p',
#  'DIHYDRODIPICSYN_RXN_p',
#  'NITRITE_pc',
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p',
#  'FERRIC_CHELATE_REDUCTASE_RXN_c',
#  'FRU_PROTON_rev_vc',
#  'FRU_vc',
#  'PALMITATE_pc',
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m',
#  'GDPKIN_RXN_m',
#  'GLC_PROTON_rev_vc',
#  'GLC_vc',
#  'GLC_tx',
#  'GLC_ec',
#  'GLN_GLU_mc',
#  'GLN_PROTON_vc',
#  'GLN_PROTON_rev_vc',
#  'GLT_PROTON_vc',
#  'GLT_PROTON_rev_vc',
#  'GLUC1PADENYLTRANS_RXN_p',
#  'GLYCOGENSYN_RXN_p',
#  'MYO_INOSITOL_OXYGENASE_RXN_c',
#  'GLUCURONOKINASE_RXN_c',
#  'GLURS_RXN_c',
#  'IMIDPHOSDEHYD_RXN_p',
#  'PRIBFAICARPISOM_RXN_p',
#  'GLUTAMINE_TRNA_LIGASE_RXN_c',
#  'SUPEROX_DISMUT_RXN_p',
#  'GLUTKIN_RXN_c',
#  'GLUTSEMIALDEHYDRROG_RXN_c',
#  'SPONTPRO_RXN_c',
#  'GLYCERATE_GLYCOLLATE_pc',
#  'GLYC3PDEHYDROGBIOSYN_RXN_c',
#  'GLYCINE_TRNA_LIGASE_RXN_c',
#  'GLY_PROTON_vc',
#  'GLY_PROTON_rev_vc',
#  'RXN_961_p',
#  'GPH_RXN_p',
#  'Glycerate_xc',
#  'Glycolate_xc',
#  'HISTOLDEHYD_RXN_p',
#  'HISTALDEHYD_RXN_p',
#  'HIS_pc',
#  'HISTAMINOTRANS_RXN_p',
#  'HISTIDPHOS_RXN_p',
#  'HISTCYCLOHYD_RXN_p',
#  'HISTIDINE_TRNA_LIGASE_RXN_c',
#  'HIS_PROTON_vc',
#  'HIS_PROTON_rev_vc',
#  'HOMO_CYS_pc',
#  'MET_pc',
#  'MALATE_DEH_RXN_x',
#  'SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x',
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x',
#  'PRAISOM_RXN_p',
#  'IGPSYN_RXN_p',
#  'RXN0_2381_p',
#  'ILE_PROTON_vc',
#  'ILE_PROTON_rev_vc',
#  'Pi_xc',
#  'SUC_xc',
#  'THREO_DS_ISO_CITRATE_xc',
#  'ISOLEUCINE_TRNA_LIGASE_RXN_c',
#  'K_rev_vc',
#  'K_tx',
#  'K_ec',
#  'LEUCINE_TRNA_LIGASE_RXN_c',
#  'LEU_PROTON_vc',
#  'LEU_PROTON_rev_vc',
#  'LYSINE_TRNA_LIGASE_RXN_c',
#  'LYS_PROTON_vc',
#  'LYS_PROTON_rev_vc',
#  'L_ALPHA_ALANINE_PROTON_vc',
#  'L_ALPHA_ALANINE_PROTON_rev_vc',
#  'L_ASPARTATE_PROTON_vc',
#  'L_ASPARTATE_PROTON_rev_vc',
#  'MALTODEG_RXN_c',
#  'MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c',
#  'RXN_3521_p',
#  'METHYLENETHFDEHYDROG_NADP_RXN_c',
#  'METHENYLTHFCYCLOHYDRO_RXN_c',
#  'METHIONINE_TRNA_LIGASE_RXN_c',
#  'MET_PROTON_vc',
#  'MET_PROTON_rev_vc',
#  'Mg_ec',
#  'MG2_rev_vc',
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c',
#  'MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_c',
#  'Mehler_Reaction_p',
#  'Mg_tx',
#  'Plastidial_ATP_Synthase_p',
#  'NH4_tx',
#  'NH4_ec',
#  'NITRATE_PROTON_rev_vc',
#  'NITRATE_vc',
#  'NITRATE_REDUCTASE_NADH_RXN_c',
#  'Nitrate_tx',
#  'Nitrate_ec',
#  'RXN0_5224_c',
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c',
#  'PHE_PROTON_vc',
#  'PHE_PROTON_rev_vc',
#  'PHOSPHORIBULOKINASE_RXN_p',
#  'RXN490_3650_p',
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p',
#  'PRTRANS_RXN_p',
#  'TYRAMINOTRANS_RXN_p',
#  'PRO_PROTON_vc',
#  'PRO_PROTON_rev_vc',
#  'PSERTRANSAM_RXN_p',
#  'Photon_ep',
#  'sSUCROSE_biomass',
#  'Phloem_output_tx',
#  'Photon_tx',
#  'Pi_tx',
#  'Pi_ec',
#  'Protein_Polymerisation_c',
#  'Protein_Processing_c',
#  'Protein_Translocation_c',
#  'TRP_pc',
#  'RXN1F_66_p',
#  'RXN66_1_c',
#  'RXN_12541_c',
#  'SUPEROX_DISMUT_RXN_c',
#  'RXN_1827_p',
#  'RXN_6884_m',
#  'SPONTPRO_RXN_m',
#  'RXN_7677_p',
#  'RXN_7674_p',
#  'RXN_7676_p',
#  'RXN_7679_p',
#  'RXN_7985_p',
#  'RXN_7978_p',
#  'RXN_7979_p',
#  'RXN_7984_p',
#  'RXN_9104_c',
#  'Xylan_biomass',
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c',
#  'RXN_9657_p',
#  'RXN_9518_p',
#  'RXN_9520_p',
#  'RXN_9658_p',
#  'RXN_9528_p',
#  'RXN_9655_p',
#  'RXN_9660_p',
#  'RXN_9532_p',
#  'RXN_9533_p',
#  'RXN_9661_p',
#  'RXN_9536_p',
#  'RXN_9537_p',
#  'RXN_9662_p',
#  'RXN_9549_p',
#  'SEDOBISALDOL_RXN_p',
#  'SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p',
#  'SER_xc',
#  'SERINE_TRNA_LIGASE_RXN_c',
#  'SER_PROTON_vc',
#  'SER_PROTON_rev_vc',
#  'SO4_tx',
#  'SO4_ec',
#  'SO4_pc',
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c',
#  'SUCROSE_PHOSPHATASE_RXN_c',
#  'SUCROSE_PROTON_vc',
#  'SUCROSE_PROTON_rev_vc',
#  'THREONINE_TRNA_LIGASE_RXN_c',
#  'THR_PROTON_vc',
#  'THR_PROTON_rev_vc',
#  'TRP_PROTON_vc',
#  'TRP_PROTON_rev_vc',
#  'TYROSINE_TRNA_LIGASE_RXN_c',
#  'TYR_PROTON_vc',
#  'TYR_PROTON_rev_vc',
#  'VALINE_TRNA_LIGASE_RXN_c',
#  'VAL_PROTON_vc',
#  'VAL_PROTON_rev_vc']

# %%
graph.GetNeighbours(new, 'ACSERLY_RXN_c')
graph.GetNeighboursAsDic(new, 'ACSERLY_RXN_c')
graph.Degree(new, 'ACSERLY_RXN_c')
graph.DegreeDist(new)
graph.MetabolitesDegree(new)
graph.ReactionsDegree(new)
# Out:
# {'10_FORMYL_THF_pc': 2,
#  '1TRANSKETO_RXN_p': 4,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc': 6,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mi': 6,
#  '1_PERIOD_18_PERIOD_1_PERIOD_2_RXN_p': 5,
#  '1_PERIOD_1_PERDIOD_1_PERIOD_255_RXN_c': 5,
#  '1_PERIOD_2_PERIOD_1_PERIOD_13_RXN_p': 6,
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m': 4,
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p': 4,
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c': 6,
#  '1_PERIOD_5_PERIOD_1_PERIOD_20_RXN_c': 5,
#  '1_PERIOD_8_PERIOD_4_PERIOD_9_RXN_p': 7,
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p': 4,
#  '2KG_ACONITATE_mc': 6,
#  '2KG_CIT_mc': 6,
#  '2KG_ISOCITRATE_mc': 6,
#  '2KG_MAL_mc': 4,
#  '2KG_MAL_pc': 4,
#  '2KG_OAA_mc': 4,
#  '2KG_SUC_mc': 4,
#  '2OXOGLUTARATEDEH_RXN_m': 6,
#  '2PGADEHYDRAT_RXN_c': 3,
#  '2PGADEHYDRAT_RXN_p': 3,
#  '2TRANSKETO_RXN_p': 4,
#  '2_ISOPROPYLMALATESYN_RXN_p': 6,
#  '2_KETOGLUTARATE_xc': 2,
#  '2_PERIOD_3_PERIOD_1_PERIOD_180_RXN_p': 6,
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c': 6,
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p': 4,
#  '2_PERIOD_7_PERIOD_1_PERIOD_90_RXN_c': 7,
#  '2_PERIOD_7_PERIOD_7_PERIOD_13_RXN_c': 7,
#  '2_PERIOD_7_PERIOD_7_PERIOD_34_RXN_c': 7,
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c': 7,
#  '3PGAREARR_RXN_c': 2,
#  '3PGAREARR_RXN_p': 2,
#  '3PGA_Pi_pc': 6,
#  '3_DEHYDROQUINATE_DEHYDRATASE_RXN_p': 4,
#  '3_DEHYDROQUINATE_SYNTHASE_RXN_p': 3,
#  '3_ISOPROPYLMALDEHYDROG_RXN_p': 5,
#  '3_ISOPROPYLMALISOM_RXN_p': 3,
#  '4_AMINO_BUTYRATE_PROTON_rev_vc': 4,
#  '4_AMINO_BUTYRATE_PROTON_vc': 4,
#  '4_AMINO_BUTYRATE_mc': 2,
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p': 3,
#  '4_PERIOD_2_PERIOD_1_PERIOD_59_RXN_p': 3,
#  '4_PERIOD_2_PERIOD_1_PERIOD_61_RXN_p': 3,
#  '5_METHYL_THF_pc': 2,
#  '6PFRUCTPHOS_RXN_c': 7,
#  '6PFRUCTPHOS_RXN_p': 7,
#  '6PGLUCONDEHYDROG_RXN_c': 5,
#  '6PGLUCONDEHYDROG_RXN_p': 5,
#  '6PGLUCONOLACT_RXN_c': 4,
#  '6PGLUCONOLACT_RXN_p': 4,
#  '6_PERIOD_3_PERIOD_4_PERIOD_16_RXN_p': 10,
#  'ACETALD_mc': 2,
#  'ACETATE_COA_LIGASE_RXN_p': 9,
#  'ACETATE_COA_LIGASE_RXN_x': 8,
#  'ACETOLACTREDUCTOISOM_RXN_p': 5,
#  'ACETOLACTSYN_RXN_p': 4,
#  'ACETOOHBUTREDUCTOISOM_RXN_p': 5,
#  'ACETOOHBUTSYN_RXN_p': 5,
#  'ACETYLGLUTKIN_RXN_p': 7,
#  'ACETYLORNTRANSAM_RXN_p': 4,
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p': 9,
#  'ACET_mc': 2,
#  'ACET_pc': 2,
#  'ACET_xc': 2,
#  'ACONITATEDEHYDR_RXN_c': 3,
#  'ACONITATEDEHYDR_RXN_m': 3,
#  'ACONITATEHYDR_RXN_c': 3,
#  'ACONITATEHYDR_RXN_m': 3,
#  'ACSERLY_RXN_c': 6,
#  'ACSERLY_RXN_p': 4,
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p': 9,
#  'ADENYL_KIN_RXN_c': 6,
#  'ADENYL_KIN_RXN_m': 6,
#  'ADENYL_KIN_RXN_p': 6,
#  'ADP_pc': 6,
#  'AICARTRANSFORM_RXN_p': 4,
#  'ALANINE_AMINOTRANSFERASE_RXN_c': 4,
#  'ALANINE_AMINOTRANSFERASE_RXN_m': 4,
#  'ALANINE_AMINOTRANSFERASE_RXN_x': 4,
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x': 4,
#  'ALANINE_TRNA_LIGASE_RXN_c': 9,
#  'ALCOHOL_DEHYDROG_RXN_c': 5,
#  'AMPSYN_RXN_p': 3,
#  'AMP_ATP_xc': 8,
#  'AMP_pc': 2,
#  'ANTHRANSYN_RXN_p': 6,
#  'ARGININE_TRNA_LIGASE_RXN_c': 9,
#  'ARGSUCCINLYA_RXN_c': 3,
#  'ARGSUCCINSYN_RXN_c': 9,
#  'ARG_CITRULLINE_mc': 4,
#  'ARG_HIS_mc': 4,
#  'ARG_LYS_mc': 4,
#  'ARG_ORNITHINE_mc': 4,
#  'ARG_PROTON_rev_vc': 4,
#  'ARG_PROTON_vc': 4,
#  'ARG_mc': 2,
#  'ASNSYNA_RXN_c': 9,
#  'ASN_PROTON_rev_vc': 4,
#  'ASN_PROTON_vc': 4,
#  'ASPAMINOTRANS_RXN_c': 4,
#  'ASPAMINOTRANS_RXN_m': 4,
#  'ASPAMINOTRANS_RXN_p': 4,
#  'ASPAMINOTRANS_RXN_x': 4,
#  'ASPARAGINE_TRNA_LIGASE_RXN_c': 9,
#  'ASPARTATEKIN_RXN_p': 7,
#  'ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_p': 6,
#  'ASPARTATE_TRNA_LIGASE_RXN_c': 9,
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p': 8,
#  'ATP_ADP_Pi_pc': 13,
#  'ATP_ADP_mc': 10,
#  'ATP_AMP_mc': 8,
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c': 11,
#  'ATP_pc': 6,
#  'ATPase_tx': 8,
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_p': 4,
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p': 4,
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_p': 4,
#  'Biomass_tx': 20,
#  'CA2_rev_vc': 4,
#  'CARBAMATE_KINASE_RXN_p': 8,
#  'CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p': 5,
#  'CATAL_RXN_x': 3,
#  'CELLULOSE_SYNTHASE_GDP_FORMING_RXN_c': 5,
#  'CELLULOSE_SYNTHASE_UDP_FORMING_RXN_c': 5,
#  'CHORISMATEMUT_RXN_p': 2,
#  'CHORISMATE_SYNTHASE_RXN_p': 3,
#  'CITSYN_RXN_m': 6,
#  'CITSYN_RXN_x': 6,
#  'CIT_ACONITATE_mc': 4,
#  'CIT_ISOCITRATE_mc': 4,
#  'CIT_PROTON_rev_vc': 5,
#  'CIT_PROTON_vc': 4,
#  'CIT_xc': 2,
#  'CO2_ec': 2,
#  'CO2_mc': 2,
#  'CO2_pc': 2,
#  'CO2_tx': 1,
#  'CONIFERIN_BETA_GLUCOSIDASE_RXN_c': 4,
#  'CYSPH_RXN_p': 4,
#  'CYSTAGLY_RXN_p': 5,
#  'CYSTATHIONINE_BETA_LYASE_RXN_p': 5,
#  'CYS_PROTON_rev_vc': 4,
#  'CYS_PROTON_vc': 4,
#  'CYTOCHROME_C_OXIDASE_RXN_mc': 6,
#  'CYTOCHROME_C_OXIDASE_RXN_mi': 6,
#  'Ca_biomass': 2,
#  'Ca_ec': 4,
#  'Ca_tx': 1,
#  'Cellulose_biomass': 2,
#  'DAHPSYN_RXN_p': 5,
#  'DHAP_3PGA_pc': 4,
#  'DHAP_Pi_pc': 6,
#  'DIAMINOPIMDECARB_RXN_p': 4,
#  'DIAMINOPIMEPIM_RXN_p': 2,
#  'DIHYDRODIPICSYN_RXN_p': 5,
#  'DIHYDROPICRED_RXN_NADP_p': 5,
#  'DIHYDROPICRED_RXN_NAD_p': 5,
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p': 3,
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p': 3,
#  'F16ALDOLASE_RXN_c': 3,
#  'F16ALDOLASE_RXN_p': 3,
#  'F16BDEPHOS_RXN_c': 6,
#  'F16BDEPHOS_RXN_p': 4,
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p': 6,
#  'FERRIC_CHELATE_REDUCTASE_RXN_c': 5,
#  'FORMATETHFLIG_RXN_p': 10,
#  'FORMATE_mc': 2,
#  'FORMATE_pc': 2,
#  'FORMYLTHFDEFORMYL_RXN_p': 5,
#  'FRUCTOKINASE_RXN_c': 7,
#  'FRU_PROTON_rev_vc': 4,
#  'FRU_vc': 2,
#  'FUMHYDR_RXN_c': 3,
#  'FUMHYDR_RXN_m': 3,
#  'FUM_PROTON_vc': 5,
#  'FUM_pc': 2,
#  'FattyAcid_biomass': 8,
#  'Ferredoxin_Plastoquinone_Reductase_p': 5,
#  'G6P_Pi_pc': 6,
#  'GABATRANSAM_RXN_m': 4,
#  'GAPOXNPHOSPHN_RXN_c': 7,
#  'GAPOXNPHOSPHN_RXN_p': 6,
#  'GAP_3PGA_pc': 4,
#  'GAP_Pi_pc': 6,
#  'GCVMULTI_RXN_m': 7,
#  'GDPKIN_RXN_c': 8,
#  'GDPKIN_RXN_m': 9,
#  'GDPKIN_RXN_p': 9,
#  'GLC_PROTON_rev_vc': 4,
#  'GLC_ec': 4,
#  'GLC_pc': 2,
#  'GLC_tx': 1,
#  'GLC_vc': 2,
#  'GLN_GLU_mc': 4,
#  'GLN_GLU_pc': 4,
#  'GLN_PROTON_rev_vc': 4,
#  'GLN_PROTON_vc': 4,
#  'GLT_MAL_pc': 4,
#  'GLT_PROTON_rev_vc': 4,
#  'GLT_PROTON_vc': 4,
#  'GLT_xc': 2,
#  'GLU6PDEHYDROG_RXN_c': 5,
#  'GLU6PDEHYDROG_RXN_p': 5,
#  'GLUC1PADENYLTRANS_RXN_p': 7,
#  'GLUC1PURIDYLTRANS_RXN_c': 7,
#  'GLUCOKIN_RXN_c': 7,
#  'GLUCOKIN_RXN_p': 7,
#  'GLUCURONOKINASE_RXN_c': 7,
#  'GLURS_RXN_c': 9,
#  'GLUTAMATE_DEHYDROGENASE_RXN_m': 7,
#  'GLUTAMATE_N_ACETYLTRANSFERASE_RXN_p': 4,
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p': 6,
#  'GLUTAMATE_SYNTHASE_NADH_RXN_p': 6,
#  'GLUTAMIDOTRANS_RXN_p': 6,
#  'GLUTAMINESYN_RXN_c': 10,
#  'GLUTAMINESYN_RXN_m': 9,
#  'GLUTAMINESYN_RXN_p': 9,
#  'GLUTAMINE_TRNA_LIGASE_RXN_c': 9,
#  'GLUTATHIONE_PEROXIDASE_RXN_p': 4,
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p': 5,
#  'GLUTDECARBOX_RXN_c': 4,
#  'GLUTKIN_RXN_c': 7,
#  'GLUTSEMIALDEHYDRROG_RXN_c': 7,
#  'GLY3KIN_RXN_p': 7,
#  'GLYC3PDEHYDROGBIOSYN_RXN_c': 5,
#  'GLYCERATE_GLYCOLLATE_pc': 4,
#  'GLYCINE_AMINOTRANSFERASE_RXN_x': 4,
#  'GLYCINE_TRNA_LIGASE_RXN_c': 9,
#  'GLYCOGENSYN_RXN_p': 5,
#  'GLYOHMETRANS_RXN_c': 5,
#  'GLYOHMETRANS_RXN_m': 5,
#  'GLYOHMETRANS_RXN_p': 5,
#  'GLY_PROTON_rev_vc': 4,
#  'GLY_PROTON_vc': 4,
#  'GLY_mc': 2,
#  'GLY_pc': 2,
#  'GLY_xc': 2,
#  'GPH_RXN_p': 4,
#  'Glycerate_xc': 2,
#  'Glycerol_biomass': 2,
#  'Glycolate_xc': 2,
#  'H2O_ec': 2,
#  'H2O_mc': 2,
#  'H2O_pc': 2,
#  'H2O_tx': 1,
#  'H2O_xc': 2,
#  'HEXOKINASE_RXN_MANNOSE_c': 7,
#  'HISTALDEHYD_RXN_p': 7,
#  'HISTAMINOTRANS_RXN_p': 4,
#  'HISTCYCLOHYD_RXN_p': 3,
#  'HISTIDINE_TRNA_LIGASE_RXN_c': 9,
#  'HISTIDPHOS_RXN_p': 4,
#  'HISTOLDEHYD_RXN_p': 6,
#  'HISTPRATPHYD_RXN_p': 6,
#  'HIS_CITRULLINE_mc': 4,
#  'HIS_ORNITHINE_mc': 4,
#  'HIS_PROTON_rev_vc': 4,
#  'HIS_PROTON_vc': 3,
#  'HIS_pc': 2,
#  'HOMOCYSMETB12_RXN_c': 4,
#  'HOMOCYSMETB12_RXN_p': 4,
#  'HOMOSERDEHYDROG_RXN_NADP_p': 5,
#  'HOMOSERDEHYDROG_RXN_NAD_p': 5,
#  'HOMOSERKIN_RXN_p': 7,
#  'HOMO_CYS_pc': 2,
#  'HS_pc': 4,
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x': 5,
#  'H_ic': 2,
#  'H_im': 2,
#  'H_pc': 2,
#  'H_tx': 1,
#  'H_xc': 2,
#  'IGPSYN_RXN_p': 5,
#  'ILE_PROTON_rev_vc': 4,
#  'ILE_PROTON_vc': 4,
#  'ILE_pc': 2,
#  'IMIDPHOSDEHYD_RXN_p': 3,
#  'IMPCYCLOHYDROLASE_RXN_p': 3,
#  'INORGPYROPHOSPHAT_RXN_c': 6,
#  'INORGPYROPHOSPHAT_RXN_p': 5,
#  'INORGPYROPHOSPHAT_RXN_x': 6,
#  'ISOCITDEH_RXN_c': 5,
#  'ISOCITDEH_RXN_m': 5,
#  'ISOCITRATE_ACONITATE_mc': 4,
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m': 5,
#  'ISOCIT_CLEAV_RXN_x': 3,
#  'ISOLEUCINE_TRNA_LIGASE_RXN_c': 9,
#  'K_biomass': 2,
#  'K_ec': 4,
#  'K_rev_vc': 4,
#  'K_tx': 1,
#  'LEUCINE_TRNA_LIGASE_RXN_c': 9,
#  'LEU_PROTON_rev_vc': 4,
#  'LEU_PROTON_vc': 4,
#  'LEU_pc': 2,
#  'LYSINE_TRNA_LIGASE_RXN_c': 9,
#  'LYS_ORNITHINE_mc': 4,
#  'LYS_PROTON_rev_vc': 4,
#  'LYS_PROTON_vc': 4,
#  'LYS_pc': 2,
#  'L_ALPHA_ALANINE_PROTON_rev_vc': 4,
#  'L_ALPHA_ALANINE_PROTON_vc': 4,
#  'L_ASCORBATE_PEROXIDASE_RXN_p': 4,
#  'L_ASPARTATE_GLU_mc': 4,
#  'L_ASPARTATE_PROTON_rev_vc': 4,
#  'L_ASPARTATE_PROTON_vc': 4,
#  'L_ASPARTATE_pc': 2,
#  'L_ASPARTATE_xc': 2,
#  'L_CITRULLINE_pc': 2,
#  'MALATE_DEHYDROGENASE_NADPs_RXN_p': 5,
#  'MALATE_DEH_RXN_c': 5,
#  'MALATE_DEH_RXN_m': 5,
#  'MALATE_DEH_RXN_p': 5,
#  'MALATE_DEH_RXN_x': 5,
#  'MALIC_NADP_RXN_c': 5,
#  'MALIC_NADP_RXN_p': 5,
#  'MALIC_NAD_RXN_m': 5,
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p': 4,
#  'MALSYN_RXN_x': 6,
#  'MALTODEG_RXN_c': 3,
#  'MALTODEXGLUCOSID_RXN_p': 3,
#  'MAL_ACONITATE_mc': 6,
#  'MAL_CIT_mc': 6,
#  'MAL_CIT_vc': 8,
#  'MAL_ISOCITRATE_mc': 6,
#  'MAL_PROTON_rev_vc': 5,
#  'MAL_PROTON_vc': 4,
#  'MAL_Pi_mc': 6,
#  'MAL_SO4_mc': 4,
#  'MAL_SUC_mc': 4,
#  'MAL_xc': 2,
#  'MANNITOL_1_PHOSPHATE_RXN_c': 6,
#  'MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c': 5,
#  'MANNPGUANYLTRANGDP_RXN_c': 7,
#  'MANNPISOM_RXN_c': 2,
#  'MDA_Fd_Ascorbate_p': 5,
#  'METHENYLTHFCYCLOHYDRO_RXN_c': 4,
#  'METHIONINE_TRNA_LIGASE_RXN_c': 9,
#  'METHYLENETHFDEHYDROG_NADP_RXN_c': 4,
#  'METHYLENE_THF_mc': 2,
#  'METHYLENE_THF_pc': 2,
#  'MET_PROTON_rev_vc': 4,
#  'MET_PROTON_vc': 4,
#  'MET_pc': 2,
#  'MG2_rev_vc': 4,
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c': 6,
#  'MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_c': 2,
#  'MYO_INOSITOL_OXYGENASE_RXN_c': 5,
#  'Mehler_Reaction_p': 4,
#  'Mg_biomass': 2,
#  'Mg_ec': 4,
#  'Mg_tx': 1,
#  'Mitochondrial_ATP_Synthase_m': 8,
#  'NADH_DEHYDROG_A_RXN_mc': 6,
#  'NADH_DEHYDROG_A_RXN_mi': 6,
#  'NADH_KINASE_RXN_c': 7,
#  'NADPH_Dehydrogenase_p': 6,
#  'NADPHoxc_tx': 5,
#  'NADPHoxm_tx': 5,
#  'NADPHoxp_tx': 5,
#  'NADPPHOSPHAT_RXN_c': 6,
#  'NH3_mc': 2,
#  'NH3_pc': 2,
#  'NH4_ec': 2,
#  'NH4_tx': 1,
#  'NITRATE_PROTON_rev_vc': 4,
#  'NITRATE_REDUCTASE_NADH_RXN_c': 6,
#  'NITRATE_vc': 2,
#  'NITRITE_pc': 4,
#  'N_ACETYLGLUTPREDUCT_RXN_p': 6,
#  'Nitrate_ec': 4,
#  'Nitrate_tx': 1,
#  'O2_ec': 2,
#  'O2_mc': 2,
#  'O2_pc': 2,
#  'O2_tx': 1,
#  'O2_xc': 2,
#  'OAA_ACONITATE_mc': 6,
#  'OAA_CIT_mc': 6,
#  'OAA_ISOCITRATE_mc': 6,
#  'OAA_MAL_mc': 4,
#  'OAA_MAL_pc': 4,
#  'OAA_Pi_mc': 6,
#  'OAA_SO4_mc': 4,
#  'OAA_SUC_mc': 4,
#  'OAA_xc': 2,
#  'ORNCARBAMTRANSFER_RXN_p': 5,
#  'ORNITHINE_CITRULLINE_mc': 4,
#  'ORNITHINE_CITRULLINE_pc': 4,
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m': 4,
#  'PALMITATE_pc': 2,
#  'PEPCARBOXYKIN_RXN_c': 8,
#  'PEPCARBOX_RXN_c': 6,
#  'PEPDEPHOS_RXN_c': 7,
#  'PEPDEPHOS_RXN_p': 7,
#  'PEP_Pi_pc': 6,
#  'PGLUCISOM_RXN_c': 2,
#  'PGLUCISOM_RXN_p': 2,
#  'PGLYCDEHYDROG_RXN_p': 5,
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c': 9,
#  'PHE_PROTON_rev_vc': 4,
#  'PHE_PROTON_vc': 4,
#  'PHE_pc': 2,
#  'PHOSGLYPHOS_RXN_c': 7,
#  'PHOSGLYPHOS_RXN_p': 7,
#  'PHOSPHOGLUCMUT_RXN_c': 2,
#  'PHOSPHOGLUCMUT_RXN_p': 2,
#  'PHOSPHORIBULOKINASE_RXN_p': 7,
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p': 6,
#  'PRAISOM_RXN_p': 2,
#  'PREPHENATEDEHYDROG_RXN_p': 5,
#  'PREPHENATE_DEHYDROGENASE_NADP_RXN_p': 5,
#  'PREPHENATE_TRANSAMINE_RXN_p': 4,
#  'PRIBFAICARPISOM_RXN_p': 2,
#  'PROTONATP_rev_vc': 9,
#  'PROTON_ATPase_c': 9,
#  'PROTON_PPi_rev_vc': 7,
#  'PRO_GLU_mc': 4,
#  'PRO_PROTON_rev_vc': 4,
#  'PRO_PROTON_vc': 4,
#  'PRO_mc': 2,
#  'PRPPSYN_RXN_p': 7,
#  'PRTRANS_RXN_p': 7,
#  'PSERTRANSAM_RXN_p': 4,
#  'PSII_RXN_p': 7,
#  'PYRROLINECARBREDUCT_RXN_NADP_c': 5,
#  'PYRROLINECARBREDUCT_RXN_NAD_c': 5,
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_c': 10,
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p': 9,
#  'PYRUVATE_PROTON_mc': 4,
#  'PYRUVATE_pc': 2,
#  'PYRUVDEH_RXN_m': 6,
#  'PYRUVDEH_RXN_p': 6,
#  'Phloem_output_tx': 27,
#  'Photon_ep': 2,
#  'Photon_tx': 1,
#  'Pi_PROTON_mc': 5,
#  'Pi_ec': 5,
#  'Pi_tx': 1,
#  'Pi_xc': 6,
#  'Plastidial_ATP_Synthase_p': 8,
#  'Plastoquinol_Oxidase_p': 4,
#  'Protein_Polymerisation_c': 9,
#  'Protein_Processing_c': 9,
#  'Protein_Translocation_c': 9,
#  'RIB5PISOM_RXN_p': 2,
#  'RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p': 5,
#  'RIBULP3EPIM_RXN_c': 2,
#  'RIBULP3EPIM_RXN_p': 2,
#  'RXN0_1483_c': 5,
#  'RXN0_2381_p': 3,
#  'RXN0_2382_p': 4,
#  'RXN0_5114_p': 4,
#  'RXN0_5184_c': 5,
#  'RXN0_5224_c': 4,
#  'RXN0_5224_p': 4,
#  'RXN0_5260_m': 4,
#  'RXN0_5330_NADP_c': 5,
#  'RXN0_5330_NADP_mc': 5,
#  'RXN0_5330_NADP_mi': 5,
#  'RXN0_5330_NAD_c': 5,
#  'RXN0_5330_NAD_mc': 5,
#  'RXN0_5330_NAD_mi': 5,
#  'RXN1F_66_p': 7,
#  'RXN490_3650_p': 5,
#  'RXN66_1_c': 4,
#  'RXN66_3_c': 6,
#  'RXN66_3_m': 6,
#  'RXN_10745_NAD_c': 5,
#  'RXN_10786_c': 7,
#  'RXN_12541_c': 4,
#  'RXN_14351_pc': 2,
#  'RXN_1461_c': 4,
#  'RXN_1826_p': 3,
#  'RXN_1827_p': 3,
#  'RXN_2141_p': 3,
#  'RXN_3521_p': 4,
#  'RXN_3522_p': 5,
#  'RXN_3523_p': 3,
#  'RXN_5682_p': 5,
#  'RXN_6883_mc': 5,
#  'RXN_6883_mi': 5,
#  'RXN_6884_m': 5,
#  'RXN_6902_m': 4,
#  'RXN_7183_NADP_m': 6,
#  'RXN_7674_p': 7,
#  'RXN_7676_p': 7,
#  'RXN_7677_p': 7,
#  'RXN_7678_NADP_p': 5,
#  'RXN_7678_NAD_p': 5,
#  'RXN_7679_p': 6,
#  'RXN_7737_p': 6,
#  'RXN_7800_p': 4,
#  'RXN_7978_p': 7,
#  'RXN_7979_p': 7,
#  'RXN_7984_p': 5,
#  'RXN_7985_p': 5,
#  'RXN_8001_p': 6,
#  'RXN_8991_p': 3,
#  'RXN_9104_c': 5,
#  'RXN_9514_p': 5,
#  'RXN_9516_p': 6,
#  'RXN_9518_p': 5,
#  'RXN_9520_p': 3,
#  'RXN_9523_p': 6,
#  'RXN_9524_p': 5,
#  'RXN_9527_p': 6,
#  'RXN_9528_p': 5,
#  'RXN_9531_p': 6,
#  'RXN_9532_p': 5,
#  'RXN_9533_p': 3,
#  'RXN_9535_p': 6,
#  'RXN_9536_p': 5,
#  'RXN_9537_p': 3,
#  'RXN_9539_p': 6,
#  'RXN_9540_p': 5,
#  'RXN_9549_p': 5,
#  'RXN_961_p': 5,
#  'RXN_9648_p': 6,
#  'RXN_9650_p': 6,
#  'RXN_9651_p': 6,
#  'RXN_9652_p': 6,
#  'RXN_9653_p': 6,
#  'RXN_9654_p': 6,
#  'RXN_9655_p': 3,
#  'RXN_9657_p': 5,
#  'RXN_9658_p': 5,
#  'RXN_9659_p': 5,
#  'RXN_9660_p': 5,
#  'RXN_9661_p': 5,
#  'RXN_9662_p': 5,
#  'RXN_9663_p': 5,
#  'RXN_969_x': 4,
#  'SEDOBISALDOL_RXN_p': 3,
#  'SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p': 4,
#  'SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x': 4,
#  'SERINE_O_ACETTRAN_RXN_c': 4,
#  'SERINE_O_ACETTRAN_RXN_p': 4,
#  'SERINE_TRNA_LIGASE_RXN_c': 9,
#  'SER_PROTON_rev_vc': 4,
#  'SER_PROTON_vc': 4,
#  'SER_mc': 2,
#  'SER_pc': 2,
#  'SER_xc': 2,
#  'SHIKIMATE_5_DEHYDROGENASE_RXN_p': 5,
#  'SHIKIMATE_KINASE_RXN_p': 7,
#  'SO4_ec': 4,
#  'SO4_pc': 2,
#  'SO4_tx': 1,
#  'SPONTPRO_RXN_c': 2,
#  'SPONTPRO_RXN_m': 4,
#  'SUCCCOASYN_RXN_m': 9,
#  'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m': 9,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc': 4,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mi': 4,
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m': 6,
#  'SUCCINYL_COA_HYDROLASE_RXN_m': 5,
#  'SUCROSE_PHOSPHATASE_RXN_c': 6,
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c': 6,
#  'SUCROSE_PROTON_rev_vc': 4,
#  'SUCROSE_PROTON_vc': 4,
#  'SUCROSE_SYNTHASE_RXN_c': 6,
#  'SUC_ACONITATE_mc': 6,
#  'SUC_CIT_mc': 6,
#  'SUC_FUM_mc': 4,
#  'SUC_ISOCITRATE_mc': 6,
#  'SUC_Pi_mc': 6,
#  'SUC_SO4_mc': 4,
#  'SUC_xc': 2,
#  'SULFATE_ADENYLYLTRANS_RXN_p': 7,
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p': 7,
#  'SUPEROX_DISMUT_RXN_c': 4,
#  'SUPEROX_DISMUT_RXN_p': 4,
#  'Starch_biomass': 2,
#  'Sucrose_ec': 4,
#  'Sucrose_tx': 1,
#  'THF_mc': 2,
#  'THF_pc': 2,
#  'THREDEHYD_RXN_p': 3,
#  'THREONINE_ALDOLASE_RXN_c': 3,
#  'THREONINE_TRNA_LIGASE_RXN_c': 9,
#  'THREO_DS_ISO_CITRATE_xc': 2,
#  'THRESYN_RXN_p': 4,
#  'THR_PROTON_rev_vc': 4,
#  'THR_PROTON_vc': 4,
#  'THR_pc': 2,
#  'TRANSALDOL_RXN_p': 4,
#  'TRIOSEPISOMERIZATION_RXN_c': 2,
#  'TRIOSEPISOMERIZATION_RXN_p': 2,
#  'TRP_PROTON_rev_vc': 4,
#  'TRP_PROTON_vc': 4,
#  'TRP_pc': 2,
#  'TYRAMINOTRANS_RXN_p': 4,
#  'TYROSINE_TRNA_LIGASE_RXN_c': 9,
#  'TYR_PROTON_rev_vc': 4,
#  'TYR_PROTON_vc': 4,
#  'TYR_pc': 2,
#  'UDPKIN_RXN_c': 9,
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c': 4,
#  'UGD_RXN_c': 6,
#  'VALINE_TRNA_LIGASE_RXN_c': 9,
#  'VAL_PROTON_rev_vc': 4,
#  'VAL_PROTON_vc': 4,
#  'VAL_pc': 2,
#  'X5P_Pi_pc': 6,
#  'Xylan_biomass': 2,
#  'diel_biomass': 1,
#  'pALA_biomass': 8,
#  'pARG_biomass': 8,
#  'pASN_biomass': 8,
#  'pASP_biomass': 8,
#  'pGLN_biomass': 8,
#  'pGLU_biomass': 8,
#  'pGLY_biomass': 8,
#  'pHIS_biomass': 8,
#  'pILE_biomass': 8,
#  'pLEU_biomass': 8,
#  'pLYS_biomass': 8,
#  'pMET_biomass': 8,
#  'pPHE_biomass': 8,
#  'pSER_biomass': 8,
#  'pTHR_biomass': 8,
#  'pTYR_biomass': 8,
#  'pVAL_biomass': 8,
#  'sALA_biomass': 2,
#  'sASP_biomass': 2,
#  'sCIT_biomass': 2,
#  'sFUM_biomass': 2,
#  'sGABA_biomass': 2,
#  'sGLN_biomass': 2,
#  'sGLU_biomass': 2,
#  'sMAL_biomass': 2,
#  'sSUCROSE_biomass': 2,
#  'sSUC_biomass': 2,
#  'unlProtHYPO_c': 1}

# %%
print('Test Completed')

# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
gparentdir = os.path.dirname(os.path.dirname(currentdir))
sys.path.insert(0, gparentdir)
import scobra
import get_all_functions as gaf
import re
new = scobra.Model("sample/Diel_Leaf_Model_cleaned.xls")
#new = scobra.model(n)

#new=scobra.Model('models/Diel_Leaf_Model_cleaned.xls')

#Maximize Sucrose output (objective)
#vary light (scan)
#allow CO2 and O2, even Proton and Water
#Output maintenance ATP and NADPHox
tx_and_biomass = []
for i in new.Reactions(): 
    if '_tx' in i:
        tx_and_biomass.append(re.search('(.*)_tx', i).group())
    elif '_biomass' in i: 
        tx_and_biomass.append(re.search('(.*)_biomass', i).group())
#tx_and_biomass.append(re.search('(.*)_tx', 'slkdfjd_tx').group())
tx_and_biomass

necessary_rxn= ['ATPase_tx', 'CO2_tx', 'Photon_tx', 'O2_tx','H2O_tx', 'H_tx','NADPHoxc_tx','NADPHoxm_tx','NADPHoxp_tx','Sucrose_tx']
unecessary_rxn= list(set(tx_and_biomass) - set(necessary_rxn))

#blocking _tx and _biomass reactions that are not considered
for i in unecessary_rxn: 
    new.GetReaction(i).lower_bound = 0.0
    new.GetReaction(i).upper_bound = 0.0

#freeing _tx and _biomass reactions that are considered
for i in necessary_rxn: 
    if new.GetReaction(i).lower_bound == 0.0:
        new.GetReaction(i).upper_bound == 1000.0
    else: 
        new.GetReaction(i).lower_bound == 1000.0
        new.GetReaction(i).upper_bound == 1000.0

#setting constraints
new.SetConstraint('ATPase_tx', 90, 90)
new.SetConstraint('NADPHoxc_tx', 10, 10)
new.SetConstraint('NADPHoxm_tx', 10, 10)
new.SetConstraint('NADPHoxp_tx', 10, 10)
#setting constraints for sucrose entering and exiting cytoplasm
new.SetConstraint('Sucrose_ec', -1000, 1000)

#setting objectives
new.SetObjective('Sucrose_tx')
new.SetObjDirec('Min')

#setting constraint and running scan
#result = {}
#for i in range(0,1000,20):
#    new.SetConstraint('Photon_tx', i, i)
#    new.Solve()
#    x = new.GetSol()['Sucrose_tx']
#    result[i] = x

#new.Solve() 
#new.MinFluxSolve()

new.Solve()
# Out:
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(  )' for <Reaction HEXOKINASE_RXN_MANNOSE_c at 0x7fd052acabd0>
# optimal

# %%
[x.id for x in new.reactions]
# Out:
# ['10_FORMYL_THF_pc',
#  '1TRANSKETO_RXN_p',
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc',
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mi',
#  '1_PERIOD_18_PERIOD_1_PERIOD_2_RXN_p',
#  '1_PERIOD_1_PERDIOD_1_PERIOD_255_RXN_c',
#  '1_PERIOD_2_PERIOD_1_PERIOD_13_RXN_p',
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m',
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p',
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c',
#  '1_PERIOD_5_PERIOD_1_PERIOD_20_RXN_c',
#  '1_PERIOD_8_PERIOD_4_PERIOD_9_RXN_p',
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p',
#  '2KG_ACONITATE_mc',
#  '2KG_CIT_mc',
#  '2KG_ISOCITRATE_mc',
#  '2KG_MAL_mc',
#  '2KG_MAL_pc',
#  '2KG_OAA_mc',
#  '2KG_SUC_mc',
#  '2OXOGLUTARATEDEH_RXN_m',
#  '2PGADEHYDRAT_RXN_c',
#  '2PGADEHYDRAT_RXN_p',
#  '2TRANSKETO_RXN_p',
#  '2_ISOPROPYLMALATESYN_RXN_p',
#  '2_KETOGLUTARATE_xc',
#  '2_PERIOD_3_PERIOD_1_PERIOD_180_RXN_p',
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c',
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p',
#  '2_PERIOD_7_PERIOD_1_PERIOD_90_RXN_c',
#  '2_PERIOD_7_PERIOD_7_PERIOD_13_RXN_c',
#  '2_PERIOD_7_PERIOD_7_PERIOD_34_RXN_c',
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c',
#  '3PGAREARR_RXN_c',
#  '3PGAREARR_RXN_p',
#  '3PGA_Pi_pc',
#  '3_DEHYDROQUINATE_DEHYDRATASE_RXN_p',
#  '3_DEHYDROQUINATE_SYNTHASE_RXN_p',
#  '3_ISOPROPYLMALDEHYDROG_RXN_p',
#  '3_ISOPROPYLMALISOM_RXN_p',
#  '4_AMINO_BUTYRATE_PROTON_rev_vc',
#  '4_AMINO_BUTYRATE_PROTON_vc',
#  '4_AMINO_BUTYRATE_mc',
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p',
#  '4_PERIOD_2_PERIOD_1_PERIOD_59_RXN_p',
#  '4_PERIOD_2_PERIOD_1_PERIOD_61_RXN_p',
#  '5_METHYL_THF_pc',
#  '6PFRUCTPHOS_RXN_c',
#  '6PFRUCTPHOS_RXN_p',
#  '6PGLUCONDEHYDROG_RXN_c',
#  '6PGLUCONDEHYDROG_RXN_p',
#  '6PGLUCONOLACT_RXN_c',
#  '6PGLUCONOLACT_RXN_p',
#  '6_PERIOD_3_PERIOD_4_PERIOD_16_RXN_p',
#  'ACETALD_mc',
#  'ACETATE_COA_LIGASE_RXN_p',
#  'ACETATE_COA_LIGASE_RXN_x',
#  'ACETOLACTREDUCTOISOM_RXN_p',
#  'ACETOLACTSYN_RXN_p',
#  'ACETOOHBUTREDUCTOISOM_RXN_p',
#  'ACETOOHBUTSYN_RXN_p',
#  'ACETYLGLUTKIN_RXN_p',
#  'ACETYLORNTRANSAM_RXN_p',
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p',
#  'ACET_mc',
#  'ACET_pc',
#  'ACET_xc',
#  'ACONITATEDEHYDR_RXN_c',
#  'ACONITATEDEHYDR_RXN_m',
#  'ACONITATEHYDR_RXN_c',
#  'ACONITATEHYDR_RXN_m',
#  'ACSERLY_RXN_c',
#  'ACSERLY_RXN_p',
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p',
#  'ADENYL_KIN_RXN_c',
#  'ADENYL_KIN_RXN_m',
#  'ADENYL_KIN_RXN_p',
#  'ADP_pc',
#  'AICARTRANSFORM_RXN_p',
#  'ALANINE_AMINOTRANSFERASE_RXN_c',
#  'ALANINE_AMINOTRANSFERASE_RXN_m',
#  'ALANINE_AMINOTRANSFERASE_RXN_x',
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x',
#  'ALANINE_TRNA_LIGASE_RXN_c',
#  'ALCOHOL_DEHYDROG_RXN_c',
#  'AMPSYN_RXN_p',
#  'AMP_ATP_xc',
#  'AMP_pc',
#  'ANTHRANSYN_RXN_p',
#  'ARGININE_TRNA_LIGASE_RXN_c',
#  'ARGSUCCINLYA_RXN_c',
#  'ARGSUCCINSYN_RXN_c',
#  'ARG_CITRULLINE_mc',
#  'ARG_HIS_mc',
#  'ARG_LYS_mc',
#  'ARG_ORNITHINE_mc',
#  'ARG_PROTON_rev_vc',
#  'ARG_PROTON_vc',
#  'ARG_mc',
#  'ASNSYNA_RXN_c',
#  'ASN_PROTON_rev_vc',
#  'ASN_PROTON_vc',
#  'ASPAMINOTRANS_RXN_c',
#  'ASPAMINOTRANS_RXN_m',
#  'ASPAMINOTRANS_RXN_p',
#  'ASPAMINOTRANS_RXN_x',
#  'ASPARAGINE_TRNA_LIGASE_RXN_c',
#  'ASPARTATEKIN_RXN_p',
#  'ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_p',
#  'ASPARTATE_TRNA_LIGASE_RXN_c',
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p',
#  'ATP_ADP_Pi_pc',
#  'ATP_ADP_mc',
#  'ATP_AMP_mc',
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c',
#  'ATP_pc',
#  'ATPase_tx',
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_p',
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p',
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_p',
#  'Biomass_tx',
#  'CA2_rev_vc',
#  'CARBAMATE_KINASE_RXN_p',
#  'CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p',
#  'CATAL_RXN_x',
#  'CELLULOSE_SYNTHASE_GDP_FORMING_RXN_c',
#  'CELLULOSE_SYNTHASE_UDP_FORMING_RXN_c',
#  'CHORISMATEMUT_RXN_p',
#  'CHORISMATE_SYNTHASE_RXN_p',
#  'CITSYN_RXN_m',
#  'CITSYN_RXN_x',
#  'CIT_ACONITATE_mc',
#  'CIT_ISOCITRATE_mc',
#  'CIT_PROTON_rev_vc',
#  'CIT_PROTON_vc',
#  'CIT_xc',
#  'CO2_ec',
#  'CO2_mc',
#  'CO2_pc',
#  'CO2_tx',
#  'CONIFERIN_BETA_GLUCOSIDASE_RXN_c',
#  'CYSPH_RXN_p',
#  'CYSTAGLY_RXN_p',
#  'CYSTATHIONINE_BETA_LYASE_RXN_p',
#  'CYS_PROTON_rev_vc',
#  'CYS_PROTON_vc',
#  'CYTOCHROME_C_OXIDASE_RXN_mc',
#  'CYTOCHROME_C_OXIDASE_RXN_mi',
#  'Ca_biomass',
#  'Ca_ec',
#  'Ca_tx',
#  'Cellulose_biomass',
#  'DAHPSYN_RXN_p',
#  'DHAP_3PGA_pc',
#  'DHAP_Pi_pc',
#  'DIAMINOPIMDECARB_RXN_p',
#  'DIAMINOPIMEPIM_RXN_p',
#  'DIHYDRODIPICSYN_RXN_p',
#  'DIHYDROPICRED_RXN_NADP_p',
#  'DIHYDROPICRED_RXN_NAD_p',
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p',
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p',
#  'F16ALDOLASE_RXN_c',
#  'F16ALDOLASE_RXN_p',
#  'F16BDEPHOS_RXN_c',
#  'F16BDEPHOS_RXN_p',
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p',
#  'FERRIC_CHELATE_REDUCTASE_RXN_c',
#  'FORMATETHFLIG_RXN_p',
#  'FORMATE_mc',
#  'FORMATE_pc',
#  'FORMYLTHFDEFORMYL_RXN_p',
#  'FRUCTOKINASE_RXN_c',
#  'FRU_PROTON_rev_vc',
#  'FRU_vc',
#  'FUMHYDR_RXN_c',
#  'FUMHYDR_RXN_m',
#  'FUM_PROTON_vc',
#  'FUM_pc',
#  'FattyAcid_biomass',
#  'Ferredoxin_Plastoquinone_Reductase_p',
#  'G6P_Pi_pc',
#  'GABATRANSAM_RXN_m',
#  'GAPOXNPHOSPHN_RXN_c',
#  'GAPOXNPHOSPHN_RXN_p',
#  'GAP_3PGA_pc',
#  'GAP_Pi_pc',
#  'GCVMULTI_RXN_m',
#  'GDPKIN_RXN_c',
#  'GDPKIN_RXN_m',
#  'GDPKIN_RXN_p',
#  'GLC_PROTON_rev_vc',
#  'GLC_ec',
#  'GLC_pc',
#  'GLC_tx',
#  'GLC_vc',
#  'GLN_GLU_mc',
#  'GLN_GLU_pc',
#  'GLN_PROTON_rev_vc',
#  'GLN_PROTON_vc',
#  'GLT_MAL_pc',
#  'GLT_PROTON_rev_vc',
#  'GLT_PROTON_vc',
#  'GLT_xc',
#  'GLU6PDEHYDROG_RXN_c',
#  'GLU6PDEHYDROG_RXN_p',
#  'GLUC1PADENYLTRANS_RXN_p',
#  'GLUC1PURIDYLTRANS_RXN_c',
#  'GLUCOKIN_RXN_c',
#  'GLUCOKIN_RXN_p',
#  'GLUCURONOKINASE_RXN_c',
#  'GLURS_RXN_c',
#  'GLUTAMATE_DEHYDROGENASE_RXN_m',
#  'GLUTAMATE_N_ACETYLTRANSFERASE_RXN_p',
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p',
#  'GLUTAMATE_SYNTHASE_NADH_RXN_p',
#  'GLUTAMIDOTRANS_RXN_p',
#  'GLUTAMINESYN_RXN_c',
#  'GLUTAMINESYN_RXN_m',
#  'GLUTAMINESYN_RXN_p',
#  'GLUTAMINE_TRNA_LIGASE_RXN_c',
#  'GLUTATHIONE_PEROXIDASE_RXN_p',
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p',
#  'GLUTDECARBOX_RXN_c',
#  'GLUTKIN_RXN_c',
#  'GLUTSEMIALDEHYDRROG_RXN_c',
#  'GLY3KIN_RXN_p',
#  'GLYC3PDEHYDROGBIOSYN_RXN_c',
#  'GLYCERATE_GLYCOLLATE_pc',
#  'GLYCINE_AMINOTRANSFERASE_RXN_x',
#  'GLYCINE_TRNA_LIGASE_RXN_c',
#  'GLYCOGENSYN_RXN_p',
#  'GLYOHMETRANS_RXN_c',
#  'GLYOHMETRANS_RXN_m',
#  'GLYOHMETRANS_RXN_p',
#  'GLY_PROTON_rev_vc',
#  'GLY_PROTON_vc',
#  'GLY_mc',
#  'GLY_pc',
#  'GLY_xc',
#  'GPH_RXN_p',
#  'Glycerate_xc',
#  'Glycerol_biomass',
#  'Glycolate_xc',
#  'H2O_ec',
#  'H2O_mc',
#  'H2O_pc',
#  'H2O_tx',
#  'H2O_xc',
#  'HEXOKINASE_RXN_MANNOSE_c',
#  'HISTALDEHYD_RXN_p',
#  'HISTAMINOTRANS_RXN_p',
#  'HISTCYCLOHYD_RXN_p',
#  'HISTIDINE_TRNA_LIGASE_RXN_c',
#  'HISTIDPHOS_RXN_p',
#  'HISTOLDEHYD_RXN_p',
#  'HISTPRATPHYD_RXN_p',
#  'HIS_CITRULLINE_mc',
#  'HIS_ORNITHINE_mc',
#  'HIS_PROTON_rev_vc',
#  'HIS_PROTON_vc',
#  'HIS_pc',
#  'HOMOCYSMETB12_RXN_c',
#  'HOMOCYSMETB12_RXN_p',
#  'HOMOSERDEHYDROG_RXN_NADP_p',
#  'HOMOSERDEHYDROG_RXN_NAD_p',
#  'HOMOSERKIN_RXN_p',
#  'HOMO_CYS_pc',
#  'HS_pc',
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x',
#  'H_ic',
#  'H_im',
#  'H_pc',
#  'H_tx',
#  'H_xc',
#  'IGPSYN_RXN_p',
#  'ILE_PROTON_rev_vc',
#  'ILE_PROTON_vc',
#  'ILE_pc',
#  'IMIDPHOSDEHYD_RXN_p',
#  'IMPCYCLOHYDROLASE_RXN_p',
#  'INORGPYROPHOSPHAT_RXN_c',
#  'INORGPYROPHOSPHAT_RXN_p',
#  'INORGPYROPHOSPHAT_RXN_x',
#  'ISOCITDEH_RXN_c',
#  'ISOCITDEH_RXN_m',
#  'ISOCITRATE_ACONITATE_mc',
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m',
#  'ISOCIT_CLEAV_RXN_x',
#  'ISOLEUCINE_TRNA_LIGASE_RXN_c',
#  'K_biomass',
#  'K_ec',
#  'K_rev_vc',
#  'K_tx',
#  'LEUCINE_TRNA_LIGASE_RXN_c',
#  'LEU_PROTON_rev_vc',
#  'LEU_PROTON_vc',
#  'LEU_pc',
#  'LYSINE_TRNA_LIGASE_RXN_c',
#  'LYS_ORNITHINE_mc',
#  'LYS_PROTON_rev_vc',
#  'LYS_PROTON_vc',
#  'LYS_pc',
#  'L_ALPHA_ALANINE_PROTON_rev_vc',
#  'L_ALPHA_ALANINE_PROTON_vc',
#  'L_ASCORBATE_PEROXIDASE_RXN_p',
#  'L_ASPARTATE_GLU_mc',
#  'L_ASPARTATE_PROTON_rev_vc',
#  'L_ASPARTATE_PROTON_vc',
#  'L_ASPARTATE_pc',
#  'L_ASPARTATE_xc',
#  'L_CITRULLINE_pc',
#  'MALATE_DEHYDROGENASE_NADPs_RXN_p',
#  'MALATE_DEH_RXN_c',
#  'MALATE_DEH_RXN_m',
#  'MALATE_DEH_RXN_p',
#  'MALATE_DEH_RXN_x',
#  'MALIC_NADP_RXN_c',
#  'MALIC_NADP_RXN_p',
#  'MALIC_NAD_RXN_m',
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p',
#  'MALSYN_RXN_x',
#  'MALTODEG_RXN_c',
#  'MALTODEXGLUCOSID_RXN_p',
#  'MAL_ACONITATE_mc',
#  'MAL_CIT_mc',
#  'MAL_CIT_vc',
#  'MAL_ISOCITRATE_mc',
#  'MAL_PROTON_rev_vc',
#  'MAL_PROTON_vc',
#  'MAL_Pi_mc',
#  'MAL_SO4_mc',
#  'MAL_SUC_mc',
#  'MAL_xc',
#  'MANNITOL_1_PHOSPHATE_RXN_c',
#  'MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c',
#  'MANNPGUANYLTRANGDP_RXN_c',
#  'MANNPISOM_RXN_c',
#  'MDA_Fd_Ascorbate_p',
#  'METHENYLTHFCYCLOHYDRO_RXN_c',
#  'METHIONINE_TRNA_LIGASE_RXN_c',
#  'METHYLENETHFDEHYDROG_NADP_RXN_c',
#  'METHYLENE_THF_mc',
#  'METHYLENE_THF_pc',
#  'MET_PROTON_rev_vc',
#  'MET_PROTON_vc',
#  'MET_pc',
#  'MG2_rev_vc',
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c',
#  'MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_c',
#  'MYO_INOSITOL_OXYGENASE_RXN_c',
#  'Mehler_Reaction_p',
#  'Mg_biomass',
#  'Mg_ec',
#  'Mg_tx',
#  'Mitochondrial_ATP_Synthase_m',
#  'NADH_DEHYDROG_A_RXN_mc',
#  'NADH_DEHYDROG_A_RXN_mi',
#  'NADH_KINASE_RXN_c',
#  'NADPH_Dehydrogenase_p',
#  'NADPHoxc_tx',
#  'NADPHoxm_tx',
#  'NADPHoxp_tx',
#  'NADPPHOSPHAT_RXN_c',
#  'NH3_mc',
#  'NH3_pc',
#  'NH4_ec',
#  'NH4_tx',
#  'NITRATE_PROTON_rev_vc',
#  'NITRATE_REDUCTASE_NADH_RXN_c',
#  'NITRATE_vc',
#  'NITRITE_pc',
#  'N_ACETYLGLUTPREDUCT_RXN_p',
#  'Nitrate_ec',
#  'Nitrate_tx',
#  'O2_ec',
#  'O2_mc',
#  'O2_pc',
#  'O2_tx',
#  'O2_xc',
#  'OAA_ACONITATE_mc',
#  'OAA_CIT_mc',
#  'OAA_ISOCITRATE_mc',
#  'OAA_MAL_mc',
#  'OAA_MAL_pc',
#  'OAA_Pi_mc',
#  'OAA_SO4_mc',
#  'OAA_SUC_mc',
#  'OAA_xc',
#  'ORNCARBAMTRANSFER_RXN_p',
#  'ORNITHINE_CITRULLINE_mc',
#  'ORNITHINE_CITRULLINE_pc',
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m',
#  'PALMITATE_pc',
#  'PEPCARBOXYKIN_RXN_c',
#  'PEPCARBOX_RXN_c',
#  'PEPDEPHOS_RXN_c',
#  'PEPDEPHOS_RXN_p',
#  'PEP_Pi_pc',
#  'PGLUCISOM_RXN_c',
#  'PGLUCISOM_RXN_p',
#  'PGLYCDEHYDROG_RXN_p',
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c',
#  'PHE_PROTON_rev_vc',
#  'PHE_PROTON_vc',
#  'PHE_pc',
#  'PHOSGLYPHOS_RXN_c',
#  'PHOSGLYPHOS_RXN_p',
#  'PHOSPHOGLUCMUT_RXN_c',
#  'PHOSPHOGLUCMUT_RXN_p',
#  'PHOSPHORIBULOKINASE_RXN_p',
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p',
#  'PRAISOM_RXN_p',
#  'PREPHENATEDEHYDROG_RXN_p',
#  'PREPHENATE_DEHYDROGENASE_NADP_RXN_p',
#  'PREPHENATE_TRANSAMINE_RXN_p',
#  'PRIBFAICARPISOM_RXN_p',
#  'PROTONATP_rev_vc',
#  'PROTON_ATPase_c',
#  'PROTON_PPi_rev_vc',
#  'PRO_GLU_mc',
#  'PRO_PROTON_rev_vc',
#  'PRO_PROTON_vc',
#  'PRO_mc',
#  'PRPPSYN_RXN_p',
#  'PRTRANS_RXN_p',
#  'PSERTRANSAM_RXN_p',
#  'PSII_RXN_p',
#  'PYRROLINECARBREDUCT_RXN_NADP_c',
#  'PYRROLINECARBREDUCT_RXN_NAD_c',
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_c',
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p',
#  'PYRUVATE_PROTON_mc',
#  'PYRUVATE_pc',
#  'PYRUVDEH_RXN_m',
#  'PYRUVDEH_RXN_p',
#  'Phloem_output_tx',
#  'Photon_ep',
#  'Photon_tx',
#  'Pi_PROTON_mc',
#  'Pi_ec',
#  'Pi_tx',
#  'Pi_xc',
#  'Plastidial_ATP_Synthase_p',
#  'Plastoquinol_Oxidase_p',
#  'Protein_Polymerisation_c',
#  'Protein_Processing_c',
#  'Protein_Translocation_c',
#  'RIB5PISOM_RXN_p',
#  'RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p',
#  'RIBULP3EPIM_RXN_c',
#  'RIBULP3EPIM_RXN_p',
#  'RXN0_1483_c',
#  'RXN0_2381_p',
#  'RXN0_2382_p',
#  'RXN0_5114_p',
#  'RXN0_5184_c',
#  'RXN0_5224_c',
#  'RXN0_5224_p',
#  'RXN0_5260_m',
#  'RXN0_5330_NADP_c',
#  'RXN0_5330_NADP_mc',
#  'RXN0_5330_NADP_mi',
#  'RXN0_5330_NAD_c',
#  'RXN0_5330_NAD_mc',
#  'RXN0_5330_NAD_mi',
#  'RXN1F_66_p',
#  'RXN490_3650_p',
#  'RXN66_1_c',
#  'RXN66_3_c',
#  'RXN66_3_m',
#  'RXN_10745_NAD_c',
#  'RXN_10786_c',
#  'RXN_12541_c',
#  'RXN_14351_pc',
#  'RXN_1461_c',
#  'RXN_1826_p',
#  'RXN_1827_p',
#  'RXN_2141_p',
#  'RXN_3521_p',
#  'RXN_3522_p',
#  'RXN_3523_p',
#  'RXN_5682_p',
#  'RXN_6883_mc',
#  'RXN_6883_mi',
#  'RXN_6884_m',
#  'RXN_6902_m',
#  'RXN_7183_NADP_m',
#  'RXN_7674_p',
#  'RXN_7676_p',
#  'RXN_7677_p',
#  'RXN_7678_NADP_p',
#  'RXN_7678_NAD_p',
#  'RXN_7679_p',
#  'RXN_7737_p',
#  'RXN_7800_p',
#  'RXN_7978_p',
#  'RXN_7979_p',
#  'RXN_7984_p',
#  'RXN_7985_p',
#  'RXN_8001_p',
#  'RXN_8991_p',
#  'RXN_9104_c',
#  'RXN_9514_p',
#  'RXN_9516_p',
#  'RXN_9518_p',
#  'RXN_9520_p',
#  'RXN_9523_p',
#  'RXN_9524_p',
#  'RXN_9527_p',
#  'RXN_9528_p',
#  'RXN_9531_p',
#  'RXN_9532_p',
#  'RXN_9533_p',
#  'RXN_9535_p',
#  'RXN_9536_p',
#  'RXN_9537_p',
#  'RXN_9539_p',
#  'RXN_9540_p',
#  'RXN_9549_p',
#  'RXN_961_p',
#  'RXN_9648_p',
#  'RXN_9650_p',
#  'RXN_9651_p',
#  'RXN_9652_p',
#  'RXN_9653_p',
#  'RXN_9654_p',
#  'RXN_9655_p',
#  'RXN_9657_p',
#  'RXN_9658_p',
#  'RXN_9659_p',
#  'RXN_9660_p',
#  'RXN_9661_p',
#  'RXN_9662_p',
#  'RXN_9663_p',
#  'RXN_969_x',
#  'SEDOBISALDOL_RXN_p',
#  'SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p',
#  'SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x',
#  'SERINE_O_ACETTRAN_RXN_c',
#  'SERINE_O_ACETTRAN_RXN_p',
#  'SERINE_TRNA_LIGASE_RXN_c',
#  'SER_PROTON_rev_vc',
#  'SER_PROTON_vc',
#  'SER_mc',
#  'SER_pc',
#  'SER_xc',
#  'SHIKIMATE_5_DEHYDROGENASE_RXN_p',
#  'SHIKIMATE_KINASE_RXN_p',
#  'SO4_ec',
#  'SO4_pc',
#  'SO4_tx',
#  'SPONTPRO_RXN_c',
#  'SPONTPRO_RXN_m',
#  'SUCCCOASYN_RXN_m',
#  'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m',
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc',
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mi',
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m',
#  'SUCCINYL_COA_HYDROLASE_RXN_m',
#  'SUCROSE_PHOSPHATASE_RXN_c',
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c',
#  'SUCROSE_PROTON_rev_vc',
#  'SUCROSE_PROTON_vc',
#  'SUCROSE_SYNTHASE_RXN_c',
#  'SUC_ACONITATE_mc',
#  'SUC_CIT_mc',
#  'SUC_FUM_mc',
#  'SUC_ISOCITRATE_mc',
#  'SUC_Pi_mc',
#  'SUC_SO4_mc',
#  'SUC_xc',
#  'SULFATE_ADENYLYLTRANS_RXN_p',
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p',
#  'SUPEROX_DISMUT_RXN_c',
#  'SUPEROX_DISMUT_RXN_p',
#  'Starch_biomass',
#  'Sucrose_ec',
#  'Sucrose_tx',
#  'THF_mc',
#  'THF_pc',
#  'THREDEHYD_RXN_p',
#  'THREONINE_ALDOLASE_RXN_c',
#  'THREONINE_TRNA_LIGASE_RXN_c',
#  'THREO_DS_ISO_CITRATE_xc',
#  'THRESYN_RXN_p',
#  'THR_PROTON_rev_vc',
#  'THR_PROTON_vc',
#  'THR_pc',
#  'TRANSALDOL_RXN_p',
#  'TRIOSEPISOMERIZATION_RXN_c',
#  'TRIOSEPISOMERIZATION_RXN_p',
#  'TRP_PROTON_rev_vc',
#  'TRP_PROTON_vc',
#  'TRP_pc',
#  'TYRAMINOTRANS_RXN_p',
#  'TYROSINE_TRNA_LIGASE_RXN_c',
#  'TYR_PROTON_rev_vc',
#  'TYR_PROTON_vc',
#  'TYR_pc',
#  'UDPKIN_RXN_c',
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c',
#  'UGD_RXN_c',
#  'VALINE_TRNA_LIGASE_RXN_c',
#  'VAL_PROTON_rev_vc',
#  'VAL_PROTON_vc',
#  'VAL_pc',
#  'X5P_Pi_pc',
#  'Xylan_biomass',
#  'diel_biomass',
#  'pALA_biomass',
#  'pARG_biomass',
#  'pASN_biomass',
#  'pASP_biomass',
#  'pGLN_biomass',
#  'pGLU_biomass',
#  'pGLY_biomass',
#  'pHIS_biomass',
#  'pILE_biomass',
#  'pLEU_biomass',
#  'pLYS_biomass',
#  'pMET_biomass',
#  'pPHE_biomass',
#  'pSER_biomass',
#  'pTHR_biomass',
#  'pTYR_biomass',
#  'pVAL_biomass',
#  'sALA_biomass',
#  'sASP_biomass',
#  'sCIT_biomass',
#  'sFUM_biomass',
#  'sGABA_biomass',
#  'sGLN_biomass',
#  'sGLU_biomass',
#  'sMAL_biomass',
#  'sSUCROSE_biomass',
#  'sSUC_biomass',
#  'unlProtHYPO_c',
#  'FluxDiff0_mindifffromflux_sum_reaction',
#  '10_FORMYL_THF_pc_reverse',
#  '1TRANSKETO_RXN_p_reverse',
#  '1_PERIOD_18_PERIOD_1_PERIOD_2_RXN_p_reverse',
#  '2KG_ACONITATE_mc_reverse',
#  '2KG_CIT_mc_reverse',
#  '2KG_ISOCITRATE_mc_reverse',
#  '2KG_MAL_mc_reverse',
#  '2KG_MAL_pc_reverse',
#  '2KG_OAA_mc_reverse',
#  '2KG_SUC_mc_reverse',
#  '2PGADEHYDRAT_RXN_c_reverse',
#  '2PGADEHYDRAT_RXN_p_reverse',
#  '2TRANSKETO_RXN_p_reverse',
#  '2_KETOGLUTARATE_xc_reverse',
#  '2_PERIOD_7_PERIOD_1_PERIOD_90_RXN_c_reverse',
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c_reverse',
#  '3PGAREARR_RXN_c_reverse',
#  '3PGAREARR_RXN_p_reverse',
#  '3PGA_Pi_pc_reverse',
#  '4_AMINO_BUTYRATE_mc_reverse',
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p_reverse',
#  '5_METHYL_THF_pc_reverse',
#  'ACETALD_mc_reverse',
#  'ACET_mc_reverse',
#  'ACET_pc_reverse',
#  'ACET_xc_reverse',
#  'ACONITATEDEHYDR_RXN_c_reverse',
#  'ACONITATEDEHYDR_RXN_m_reverse',
#  'ACONITATEHYDR_RXN_c_reverse',
#  'ACONITATEHYDR_RXN_m_reverse',
#  'ADENYL_KIN_RXN_c_reverse',
#  'ADENYL_KIN_RXN_m_reverse',
#  'ADENYL_KIN_RXN_p_reverse',
#  'ADP_pc_reverse',
#  'ALANINE_AMINOTRANSFERASE_RXN_c_reverse',
#  'ALANINE_AMINOTRANSFERASE_RXN_m_reverse',
#  'ALANINE_AMINOTRANSFERASE_RXN_x_reverse',
#  'ALCOHOL_DEHYDROG_RXN_c_reverse',
#  'AMP_ATP_xc_reverse',
#  'AMP_pc_reverse',
#  'ANTHRANSYN_RXN_p_reverse',
#  'ARG_CITRULLINE_mc_reverse',
#  'ARG_HIS_mc_reverse',
#  'ARG_LYS_mc_reverse',
#  'ARG_ORNITHINE_mc_reverse',
#  'ARG_mc_reverse',
#  'ASPAMINOTRANS_RXN_c_reverse',
#  'ASPAMINOTRANS_RXN_m_reverse',
#  'ASPAMINOTRANS_RXN_p_reverse',
#  'ASPAMINOTRANS_RXN_x_reverse',
#  'ATP_ADP_Pi_pc_reverse',
#  'ATP_ADP_mc_reverse',
#  'ATP_AMP_mc_reverse',
#  'ATP_pc_reverse',
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_p_reverse',
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p_reverse',
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_p_reverse',
#  'CARBAMATE_KINASE_RXN_p_reverse',
#  'CIT_ACONITATE_mc_reverse',
#  'CIT_ISOCITRATE_mc_reverse',
#  'CIT_xc_reverse',
#  'CO2_ec_reverse',
#  'CO2_mc_reverse',
#  'CO2_pc_reverse',
#  'CO2_tx_reverse',
#  'DHAP_3PGA_pc_reverse',
#  'DHAP_Pi_pc_reverse',
#  'F16ALDOLASE_RXN_c_reverse',
#  'F16ALDOLASE_RXN_p_reverse',
#  'FORMATE_mc_reverse',
#  'FORMATE_pc_reverse',
#  'FUMHYDR_RXN_c_reverse',
#  'FUMHYDR_RXN_m_reverse',
#  'FUM_PROTON_vc_reverse',
#  'FUM_pc_reverse',
#  'G6P_Pi_pc_reverse',
#  'GAPOXNPHOSPHN_RXN_c_reverse',
#  'GAPOXNPHOSPHN_RXN_p_reverse',
#  'GAP_3PGA_pc_reverse',
#  'GAP_Pi_pc_reverse',
#  'GDPKIN_RXN_c_reverse',
#  'GDPKIN_RXN_m_reverse',
#  'GDPKIN_RXN_p_reverse',
#  'GLC_pc_reverse',
#  'GLN_GLU_mc_reverse',
#  'GLN_GLU_pc_reverse',
#  'GLT_MAL_pc_reverse',
#  'GLT_xc_reverse',
#  'GLUC1PURIDYLTRANS_RXN_c_reverse',
#  'GLYCERATE_GLYCOLLATE_pc_reverse',
#  'GLYCINE_AMINOTRANSFERASE_RXN_x_reverse',
#  'GLYOHMETRANS_RXN_c_reverse',
#  'GLYOHMETRANS_RXN_m_reverse',
#  'GLYOHMETRANS_RXN_p_reverse',
#  'GLY_mc_reverse',
#  'GLY_pc_reverse',
#  'GLY_xc_reverse',
#  'Glycerate_xc_reverse',
#  'Glycolate_xc_reverse',
#  'H2O_ec_reverse',
#  'H2O_mc_reverse',
#  'H2O_pc_reverse',
#  'H2O_tx_reverse',
#  'H2O_xc_reverse',
#  'HIS_CITRULLINE_mc_reverse',
#  'HIS_ORNITHINE_mc_reverse',
#  'HIS_pc_reverse',
#  'HOMO_CYS_pc_reverse',
#  'HS_pc_reverse',
#  'H_pc_reverse',
#  'H_xc_reverse',
#  'ILE_pc_reverse',
#  'ISOCITDEH_RXN_c_reverse',
#  'ISOCITDEH_RXN_m_reverse',
#  'ISOCITRATE_ACONITATE_mc_reverse',
#  'LEU_pc_reverse',
#  'LYS_ORNITHINE_mc_reverse',
#  'LYS_pc_reverse',
#  'L_ASPARTATE_GLU_mc_reverse',
#  'L_ASPARTATE_pc_reverse',
#  'L_ASPARTATE_xc_reverse',
#  'L_CITRULLINE_pc_reverse',
#  'MALATE_DEH_RXN_c_reverse',
#  'MALATE_DEH_RXN_m_reverse',
#  'MALATE_DEH_RXN_p_reverse',
#  'MALATE_DEH_RXN_x_reverse',
#  'MALTODEG_RXN_c_reverse',
#  'MAL_ACONITATE_mc_reverse',
#  'MAL_CIT_mc_reverse',
#  'MAL_CIT_vc_reverse',
#  'MAL_ISOCITRATE_mc_reverse',
#  'MAL_Pi_mc_reverse',
#  'MAL_SO4_mc_reverse',
#  'MAL_SUC_mc_reverse',
#  'MAL_xc_reverse',
#  'MANNPISOM_RXN_c_reverse',
#  'METHYLENE_THF_mc_reverse',
#  'METHYLENE_THF_pc_reverse',
#  'MET_pc_reverse',
#  'NH3_mc_reverse',
#  'NH3_pc_reverse',
#  'O2_ec_reverse',
#  'O2_mc_reverse',
#  'O2_pc_reverse',
#  'O2_tx_reverse',
#  'O2_xc_reverse',
#  'OAA_ACONITATE_mc_reverse',
#  'OAA_CIT_mc_reverse',
#  'OAA_ISOCITRATE_mc_reverse',
#  'OAA_MAL_mc_reverse',
#  'OAA_MAL_pc_reverse',
#  'OAA_Pi_mc_reverse',
#  'OAA_SO4_mc_reverse',
#  'OAA_SUC_mc_reverse',
#  'OAA_xc_reverse',
#  'ORNCARBAMTRANSFER_RXN_p_reverse',
#  'ORNITHINE_CITRULLINE_mc_reverse',
#  'ORNITHINE_CITRULLINE_pc_reverse',
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m_reverse',
#  'PALMITATE_pc_reverse',
#  'PEP_Pi_pc_reverse',
#  'PGLUCISOM_RXN_c_reverse',
#  'PGLUCISOM_RXN_p_reverse',
#  'PGLYCDEHYDROG_RXN_p_reverse',
#  'PHE_pc_reverse',
#  'PHOSGLYPHOS_RXN_c_reverse',
#  'PHOSGLYPHOS_RXN_p_reverse',
#  'PHOSPHOGLUCMUT_RXN_c_reverse',
#  'PHOSPHOGLUCMUT_RXN_p_reverse',
#  'PRO_GLU_mc_reverse',
#  'PRO_mc_reverse',
#  'PRTRANS_RXN_p_reverse',
#  'PSERTRANSAM_RXN_p_reverse',
#  'PYRUVATE_PROTON_mc_reverse',
#  'PYRUVATE_pc_reverse',
#  'Photon_tx_reverse',
#  'Pi_PROTON_mc_reverse',
#  'Pi_xc_reverse',
#  'RIB5PISOM_RXN_p_reverse',
#  'RIBULP3EPIM_RXN_c_reverse',
#  'RIBULP3EPIM_RXN_p_reverse',
#  'RXN0_2381_p_reverse',
#  'RXN0_5184_c_reverse',
#  'RXN0_5224_c_reverse',
#  'RXN0_5224_p_reverse',
#  'RXN1F_66_p_reverse',
#  'SER_mc_reverse',
#  'SER_pc_reverse',
#  'SER_xc_reverse',
#  'SO4_pc_reverse',
#  'SPONTPRO_RXN_c_reverse',
#  'SPONTPRO_RXN_m_reverse',
#  'SUC_ACONITATE_mc_reverse',
#  'SUC_CIT_mc_reverse',
#  'SUC_FUM_mc_reverse',
#  'SUC_ISOCITRATE_mc_reverse',
#  'SUC_Pi_mc_reverse',
#  'SUC_SO4_mc_reverse',
#  'SUC_xc_reverse',
#  'Sucrose_ec_reverse',
#  'Sucrose_tx_reverse',
#  'THF_mc_reverse',
#  'THF_pc_reverse',
#  'THREO_DS_ISO_CITRATE_xc_reverse',
#  'THR_pc_reverse',
#  'TRANSALDOL_RXN_p_reverse',
#  'TRIOSEPISOMERIZATION_RXN_c_reverse',
#  'TRIOSEPISOMERIZATION_RXN_p_reverse',
#  'TRP_pc_reverse',
#  'TYRAMINOTRANS_RXN_p_reverse',
#  'TYR_pc_reverse',
#  'UDPKIN_RXN_c_reverse',
#  'VAL_pc_reverse',
#  'X5P_Pi_pc_reverse',
#  'FluxDiff0_mindifffromflux_sum_reaction_reverse',
#  'FluxDiff1_mindifffromflux_sum_reaction']

# %%
import scobra.analysis.GeometricFBA as gfba
gfba.GeometricSol(new, cobra=True)
# Out:
# no
# {<Reaction F16ALDOLASE_RXN_p_reverse at 0x7f1a7c0d3690>: (31.979030144171411, 39.973787680204708), <Reaction F16BDEPHOS_RXN_c at 0x7f1a7c421210>: (7.9947575360508836, 15.989515072068595), <Reaction OAA_MAL_mc at 0x7f1a7c290b90>: (18.1258191350272, 28.125819134998522), <Reaction OAA_ISOCITRATE_mc at 0x7f1a7c290450>: (0.0, 10.000000000010576), <Reaction GAP_3PGA_pc at 0x7f1a7c3c9a10>: (4.0104849279957797, 19.999999999984901), <Reaction PGLUCISOM_RXN_c_reverse at 0x7f1a82dad690>: (0.0, 7.9947575360602254), <Reaction F16BDEPHOS_RXN_p at 0x7f1a7c421d50>: (31.979030144176757, 39.973787680194498), <Reaction 2KG_MAL_mc at 0x7f1a7c562cd0>: (0.0, 9.9999999999982396), <Reaction F16ALDOLASE_RXN_c_reverse at 0x7f1a7c0d31d0>: (7.9947575360328624, 15.989515072081364), <Reaction PGLUCISOM_RXN_p_reverse at 0x7f1a82dad710>: (0.0, 7.9947575360602254), <Reaction 2KG_ISOCITRATE_mc at 0x7f1a7c562c50>: (0.0, 9.9999999999991243), <Reaction TRIOSEPISOMERIZATION_RXN_p at 0x7f1a7c10d0d0>: (63.958060288326237, 79.947575360421681), <Reaction DHAP_3PGA_pc at 0x7f1a7c3fd950>: (0.0, 15.989515072075889), <Reaction H2O_pc_reverse at 0x7f1a82de7190>: (78.466579292272172, 86.461336828311033), <Reaction DHAP_Pi_pc at 0x7f1a7c3fd9d0>: (0.0, 15.989515072076316), <Reaction GAP_Pi_pc at 0x7f1a7c3c9990>: (7.9947575361215826, 31.979030144152187), <Reaction G6P_Pi_pc at 0x7f1a7c3c95d0>: (0.0, 7.9947575360342311), <Reaction TRIOSEPISOMERIZATION_RXN_c at 0x7f1a7c10d750>: (0.0, 15.989515072086247)}
# no solution found
# no solution found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5836e8851d55> in <module>()
#       1 import scobra.analysis.GeometricFBA as gfba
# ----> 2 gfba.GeometricSol(new, cobra=True)
#
# /home/kristoforus/compbio/updating_scobra/scobra/analysis/GeometricFBA.py in GeometricSol(model, IncZeroes, AsMtx, tol, Print, cobra)
#      31         model.SetObjAsConstraint(name='FluxDiff'+str(it)+'_mindifffromflux')
#      32         fva = model.FVA(reaclist=variablereacs.keys(), tol=0,
# ---> 33                             PrintStatus=False, cobra=cobra)
#      34         meanflux = fva.GetReacsMeanFlux(fva.keys())
#      35         flux.update(meanflux)
#
# /home/kristoforus/compbio/updating_scobra/scobra/classes/model.pyc in FVA(self, reaclist, subopt, IncZeroes, VaryOnly, AsMtx, tol, PrintStatus, cobra, processes)
#     865         rv = FVA.FVA(self, reaclist=reaclist, subopt=subopt,
#     866             IncZeroes=IncZeroes, VaryOnly=VaryOnly, AsMtx=AsMtx, tol=tol,
# --> 867             PrintStatus=PrintStatus, cobra=cobra)
#     868         if rv: return rv
#     869
#
# /home/kristoforus/compbio/updating_scobra/scobra/analysis/FVA.pyc in FVA(model, reaclist, subopt, IncZeroes, VaryOnly, AsMtx, tol, PrintStatus, cobra, processes)
#      11     state = model.GetState()
#      12     model.Solve(PrintStatus=PrintStatus)
# ---> 13     if model.solution.status != 'optimal' or math.isnan(model.solution.f):
#      14         statusmsg = model.solution.status
#      15         model.SetState(state)
#
# AttributeError: 'NoneType' object has no attribute 'status'

# %%
fva = new.FVA(reaclist=new.reactions,tol=1e-6,PrintStatus=False, cobra=True)
meanflux = fva.GetReacsMeanFlux(fva.keys())
flux = dict(meanflux)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1bb74992e1ea> in <module>()
# ----> 1 fva = new.FVA(reaclist=new.reactions,tol=1e-6,PrintStatus=False, cobra=True)
#       2 meanflux = fva.GetReacsMeanFlux(fva.keys())
#       3 flux = dict(meanflux)
#
# /home/kristoforus/compbio/updating_scobra/scobra/classes/model.pyc in FVA(self, reaclist, subopt, IncZeroes, VaryOnly, AsMtx, tol, PrintStatus, cobra, processes)
#     865         rv = FVA.FVA(self, reaclist=reaclist, subopt=subopt,
#     866             IncZeroes=IncZeroes, VaryOnly=VaryOnly, AsMtx=AsMtx, tol=tol,
# --> 867             PrintStatus=PrintStatus, cobra=cobra)
#     868         if rv: return rv
#     869
#
# /home/kristoforus/compbio/updating_scobra/scobra/analysis/FVA.pyc in FVA(model, reaclist, subopt, IncZeroes, VaryOnly, AsMtx, tol, PrintStatus, cobra, processes)
#      11     state = model.GetState()
#      12     model.Solve(PrintStatus=PrintStatus)
# ---> 13     if model.solution.status != 'optimal' or math.isnan(model.solution.f):
#      14         statusmsg = model.solution.status
#      15         model.SetState(state)
#
# AttributeError: 'NoneType' object has no attribute 'status'

# %%
flux_id = {}
for reac in flux: 
    flux_id[reac.id] = flux[reac]
flux_id
# Out:
# {'10_FORMYL_THF_pc': -478.85225885225913,
#  '1TRANSKETO_RXN_p': -4.3939393939390357,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc': 113.04315476190456,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mi': 500.0,
#  '1_PERIOD_18_PERIOD_1_PERIOD_2_RXN_p': -375.0,
#  '1_PERIOD_1_PERDIOD_1_PERIOD_255_RXN_c': 500.0,
#  '1_PERIOD_2_PERIOD_1_PERIOD_13_RXN_p': 500.0,
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_m': 343.62487852283897,
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p': 478.85225885225913,
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c': 500.0,
#  '1_PERIOD_5_PERIOD_1_PERIOD_20_RXN_c': 0.0,
#  '1_PERIOD_8_PERIOD_4_PERIOD_9_RXN_p': 0.0,
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p': 499.99999999999835,
#  '2KG_ACONITATE_mc': 0.0,
#  '2KG_CIT_mc': 0.0,
#  '2KG_ISOCITRATE_mc': 0.0,
#  '2KG_MAL_mc': 0.0,
#  '2KG_MAL_pc': -500.0,
#  '2KG_OAA_mc': 0.0,
#  '2KG_SUC_mc': 0.0,
#  '2OXOGLUTARATEDEH_RXN_m': 305.20282186948839,
#  '2PGADEHYDRAT_RXN_c': 3.979039320256561e-13,
#  '2PGADEHYDRAT_RXN_p': 3.4106051316484809e-13,
#  '2TRANSKETO_RXN_p': 4.3939393939330103,
#  '2_ISOPROPYLMALATESYN_RXN_p': 0.0,
#  '2_KETOGLUTARATE_xc': 0.0,
#  '2_PERIOD_3_PERIOD_1_PERIOD_180_RXN_p': 0.0,
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c': 500.00000000000034,
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p': 0.0,
#  '2_PERIOD_7_PERIOD_1_PERIOD_90_RXN_c': 0.0,
#  '2_PERIOD_7_PERIOD_7_PERIOD_13_RXN_c': 500.0,
#  '2_PERIOD_7_PERIOD_7_PERIOD_34_RXN_c': 500.0,
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c': 0.0,
#  '3PGAREARR_RXN_c': -3.0695446184836328e-12,
#  '3PGAREARR_RXN_p': 3.979039320256561e-13,
#  '3PGA_Pi_pc': 0.0,
#  '3_DEHYDROQUINATE_DEHYDRATASE_RXN_p': 0.0,
#  '3_DEHYDROQUINATE_SYNTHASE_RXN_p': 0.0,
#  '3_ISOPROPYLMALDEHYDROG_RXN_p': 0.0,
#  '3_ISOPROPYLMALISOM_RXN_p': 0.0,
#  '4_AMINO_BUTYRATE_PROTON_rev_vc': 500.0,
#  '4_AMINO_BUTYRATE_PROTON_vc': 500.0,
#  '4_AMINO_BUTYRATE_mc': -328.93939393939172,
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p': 0.0,
#  '4_PERIOD_2_PERIOD_1_PERIOD_59_RXN_p': 0.0,
#  '4_PERIOD_2_PERIOD_1_PERIOD_61_RXN_p': 0.0,
#  '5_METHYL_THF_pc': 0.0,
#  '6PFRUCTPHOS_RXN_c': 500.0,
#  '6PFRUCTPHOS_RXN_p': 500.0,
#  '6PGLUCONDEHYDROG_RXN_c': 499.99999999999926,
#  '6PGLUCONDEHYDROG_RXN_p': 500.0,
#  '6PGLUCONOLACT_RXN_c': 500.0,
#  '6PGLUCONOLACT_RXN_p': 500.0,
#  '6_PERIOD_3_PERIOD_4_PERIOD_16_RXN_p': 500.0,
#  'ACETALD_mc': -249.99999999999991,
#  'ACETATE_COA_LIGASE_RXN_p': 0.0,
#  'ACETATE_COA_LIGASE_RXN_x': 250.0,
#  'ACETOLACTREDUCTOISOM_RXN_p': 0.0,
#  'ACETOLACTSYN_RXN_p': 0.0,
#  'ACETOOHBUTREDUCTOISOM_RXN_p': 0.0,
#  'ACETOOHBUTSYN_RXN_p': 0.0,
#  'ACETYLGLUTKIN_RXN_p': 500.00000000000131,
#  'ACETYLORNTRANSAM_RXN_p': 500.00000000000131,
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p': 0.0,
#  'ACET_mc': 250.00000000000009,
#  'ACET_pc': 0.0,
#  'ACET_xc': -250.00000000000102,
#  'ACONITATEDEHYDR_RXN_c': 0.0,
#  'ACONITATEDEHYDR_RXN_m': -1.1368683772161603e-13,
#  'ACONITATEHYDR_RXN_c': -5.6843418860808015e-14,
#  'ACONITATEHYDR_RXN_m': 0.0,
#  'ACSERLY_RXN_c': 0.0,
#  'ACSERLY_RXN_p': 0.0,
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p': 0.0,
#  'ADENYL_KIN_RXN_c': 0.0,
#  'ADENYL_KIN_RXN_m': 41.136695906433374,
#  'ADENYL_KIN_RXN_p': 0.0,
#  'ADP_pc': 0.0,
#  'AICARTRANSFORM_RXN_p': 0.0,
#  'ALANINE_AMINOTRANSFERASE_RXN_c': 0.0,
#  'ALANINE_AMINOTRANSFERASE_RXN_m': 328.93939393939382,
#  'ALANINE_AMINOTRANSFERASE_RXN_x': -500.0,
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x': 500.0,
#  'ALANINE_TRNA_LIGASE_RXN_c': 0.0,
#  'ALCOHOL_DEHYDROG_RXN_c': -500.0,
#  'AMPSYN_RXN_p': 0.0,
#  'AMP_ATP_xc': 250.0,
#  'AMP_pc': 249.99999999999963,
#  'ANTHRANSYN_RXN_p': 0.0,
#  'ARGININE_TRNA_LIGASE_RXN_c': 0.0,
#  'ARGSUCCINLYA_RXN_c': 0.0,
#  'ARGSUCCINSYN_RXN_c': 0.0,
#  'ARG_CITRULLINE_mc': 0.0,
#  'ARG_HIS_mc': 0.0,
#  'ARG_LYS_mc': 0.0,
#  'ARG_ORNITHINE_mc': 0.0,
#  'ARG_PROTON_rev_vc': 500.0,
#  'ARG_PROTON_vc': 500.0,
#  'ARG_mc': -499.99999999999966,
#  'ASNSYNA_RXN_c': 0.0,
#  'ASN_PROTON_rev_vc': 500.0,
#  'ASN_PROTON_vc': 500.0,
#  'ASPAMINOTRANS_RXN_c': 0.0,
#  'ASPAMINOTRANS_RXN_m': 5.6843418860808015e-14,
#  'ASPAMINOTRANS_RXN_p': 500.00000000000557,
#  'ASPAMINOTRANS_RXN_x': 0.0,
#  'ASPARAGINE_TRNA_LIGASE_RXN_c': 0.0,
#  'ASPARTATEKIN_RXN_p': 250.00000000000003,
#  'ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_p': 250.00000000000003,
#  'ASPARTATE_TRNA_LIGASE_RXN_c': 0.0,
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p': 0.0,
#  'ATP_ADP_Pi_pc': 0.0,
#  'ATP_ADP_mc': 0.0,
#  'ATP_AMP_mc': 41.136695906432521,
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c': 0.0,
#  'ATP_pc': 2.8990143619012088e-12,
#  'ATPase_tx': 90.0,
#  'BRANCHED_CHAINAMINOTRANSFERILEU_RXN_p': 0.0,
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p': 0.0,
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_p': 0.0,
#  'Biomass_tx': 0.0,
#  'CA2_rev_vc': 0.0,
#  'CARBAMATE_KINASE_RXN_p': -500.0,
#  'CARBOXYCYCLOHEXADIENYL_DEHYDRATASE_RXN_p': 0.0,
#  'CATAL_RXN_x': 138.4714345725715,
#  'CELLULOSE_SYNTHASE_GDP_FORMING_RXN_c': 0.0,
#  'CELLULOSE_SYNTHASE_UDP_FORMING_RXN_c': 0.0,
#  'CHORISMATEMUT_RXN_p': 0.0,
#  'CHORISMATE_SYNTHASE_RXN_p': 0.0,
#  'CITSYN_RXN_m': 328.93939393939223,
#  'CITSYN_RXN_x': 186.75238095238095,
#  'CIT_ACONITATE_mc': 0.0,
#  'CIT_ISOCITRATE_mc': 0.0,
#  'CIT_PROTON_rev_vc': 500.0,
#  'CIT_PROTON_vc': 500.0,
#  'CIT_xc': 186.7523809523808,
#  'CO2_ec': -452.0314547837487,
#  'CO2_mc': 5.0000000000023306,
#  'CO2_pc': 26.309523809520385,
#  'CO2_tx': -452.03145478375149,
#  'CONIFERIN_BETA_GLUCOSIDASE_RXN_c': 500.0,
#  'CYSPH_RXN_p': 0.0,
#  'CYSTAGLY_RXN_p': 0.0,
#  'CYSTATHIONINE_BETA_LYASE_RXN_p': 0.0,
#  'CYS_PROTON_rev_vc': 500.0,
#  'CYS_PROTON_vc': 500.0,
#  'CYTOCHROME_C_OXIDASE_RXN_mc': 56.52157738095616,
#  'CYTOCHROME_C_OXIDASE_RXN_mi': 250.0,
#  'Ca_biomass': 0.0,
#  'Ca_ec': 0.0,
#  'Ca_tx': 0.0,
#  'Cellulose_biomass': 0.0,
#  'DAHPSYN_RXN_p': 0.0,
#  'DHAP_3PGA_pc': 0.0,
#  'DHAP_Pi_pc': 0.0,
#  'DIAMINOPIMDECARB_RXN_p': 0.0,
#  'DIAMINOPIMEPIM_RXN_p': 0.0,
#  'DIHYDRODIPICSYN_RXN_p': 0.0,
#  'DIHYDROPICRED_RXN_NADP_p': 0.0,
#  'DIHYDROPICRED_RXN_NAD_p': 0.0,
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p': 0.0,
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p': 0.0,
#  'F16ALDOLASE_RXN_c': 0.71795624724694562,
#  'F16ALDOLASE_RXN_p': 0.0,
#  'F16BDEPHOS_RXN_c': 500.0,
#  'F16BDEPHOS_RXN_p': 500.0,
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p': 0.0,
#  'FERRIC_CHELATE_REDUCTASE_RXN_c': 500.0,
#  'FORMATETHFLIG_RXN_p': 499.99999999999881,
#  'FORMATE_mc': -343.62487852283789,
#  'FORMATE_pc': 343.62487852283783,
#  'FORMYLTHFDEFORMYL_RXN_p': 500.0,
#  'FRUCTOKINASE_RXN_c': 500.0,
#  'FRU_PROTON_rev_vc': 500.0,
#  'FRU_vc': 500.0,
#  'FUMHYDR_RXN_c': -3.1718627724330872e-11,
#  'FUMHYDR_RXN_m': -2.7284841053187847e-12,
#  'FUM_PROTON_vc': 0.0,
#  'FUM_pc': 0.0,
#  'FattyAcid_biomass': 0.0,
#  'Ferredoxin_Plastoquinone_Reductase_p': 500.0,
#  'G6P_Pi_pc': 0.0,
#  'GABATRANSAM_RXN_m': 328.93939393939388,
#  'GAPOXNPHOSPHN_RXN_c': 0.0,
#  'GAPOXNPHOSPHN_RXN_p': 0.0,
#  'GAP_3PGA_pc': 0.0,
#  'GAP_Pi_pc': 0.0,
#  'GCVMULTI_RXN_m': 300.57142857142873,
#  'GDPKIN_RXN_c': 500.0,
#  'GDPKIN_RXN_m': -305.20282186948873,
#  'GDPKIN_RXN_p': 0.0,
#  'GLC_PROTON_rev_vc': 500.0,
#  'GLC_ec': 0.0,
#  'GLC_pc': 2.2737367544323206e-13,
#  'GLC_tx': 0.0,
#  'GLC_vc': 500.0,
#  'GLN_GLU_mc': 500.00000000000051,
#  'GLN_GLU_pc': -500.0,
#  'GLN_PROTON_rev_vc': 500.0,
#  'GLN_PROTON_vc': 500.0,
#  'GLT_MAL_pc': 249.99999999999889,
#  'GLT_PROTON_rev_vc': 500.0,
#  'GLT_PROTON_vc': 500.0,
#  'GLT_xc': 0.0,
#  'GLU6PDEHYDROG_RXN_c': 500.0,
#  'GLU6PDEHYDROG_RXN_p': 500.0,
#  'GLUC1PADENYLTRANS_RXN_p': 500.00000000003018,
#  'GLUC1PURIDYLTRANS_RXN_c': 458.33333333333195,
#  'GLUCOKIN_RXN_c': 500.0,
#  'GLUCOKIN_RXN_p': 500.0,
#  'GLUCURONOKINASE_RXN_c': 0.0,
#  'GLURS_RXN_c': 0.0,
#  'GLUTAMATE_DEHYDROGENASE_RXN_m': 500.0,
#  'GLUTAMATE_N_ACETYLTRANSFERASE_RXN_p': 500.00000000000017,
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p': 500.0,
#  'GLUTAMATE_SYNTHASE_NADH_RXN_p': 500.0,
#  'GLUTAMIDOTRANS_RXN_p': 0.0,
#  'GLUTAMINESYN_RXN_c': 500.0,
#  'GLUTAMINESYN_RXN_m': 500.0,
#  'GLUTAMINESYN_RXN_p': 499.99999999999989,
#  'GLUTAMINE_TRNA_LIGASE_RXN_c': 0.0,
#  'GLUTATHIONE_PEROXIDASE_RXN_p': 250.0,
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p': 500.0,
#  'GLUTDECARBOX_RXN_c': 328.93939393939462,
#  'GLUTKIN_RXN_c': 0.0,
#  'GLUTSEMIALDEHYDRROG_RXN_c': 0.0,
#  'GLY3KIN_RXN_p': 138.47143457256817,
#  'GLYC3PDEHYDROGBIOSYN_RXN_c': 500.0,
#  'GLYCERATE_GLYCOLLATE_pc': 138.47143457256882,
#  'GLYCINE_AMINOTRANSFERASE_RXN_x': -225.07002801120461,
#  'GLYCINE_TRNA_LIGASE_RXN_c': 0.0,
#  'GLYCOGENSYN_RXN_p': 500.0,
#  'GLYOHMETRANS_RXN_c': 0.0,
#  'GLYOHMETRANS_RXN_m': 7.1622707764618099e-12,
#  'GLYOHMETRANS_RXN_p': -5.1159076974727213e-13,
#  'GLY_PROTON_rev_vc': 500.0,
#  'GLY_PROTON_vc': 500.0,
#  'GLY_mc': 3.5242919693700969e-12,
#  'GLY_pc': 0.0,
#  'GLY_xc': 117.05329327992823,
#  'GPH_RXN_p': 276.94286914513754,
#  'Glycerate_xc': 138.47143457256877,
#  'Glycerol_biomass': 0.0,
#  'Glycolate_xc': -276.94286914513737,
#  'H2O_ec': -387.08333333333542,
#  'H2O_mc': 0.0,
#  'H2O_pc': 0.0,
#  'H2O_tx': -387.08333333333104,
#  'H2O_xc': -223.05713085486406,
#  'HEXOKINASE_RXN_MANNOSE_c': 500.0,
#  'HISTALDEHYD_RXN_p': 0.0,
#  'HISTAMINOTRANS_RXN_p': 0.0,
#  'HISTCYCLOHYD_RXN_p': 0.0,
#  'HISTIDINE_TRNA_LIGASE_RXN_c': 0.0,
#  'HISTIDPHOS_RXN_p': 0.0,
#  'HISTOLDEHYD_RXN_p': 0.0,
#  'HISTPRATPHYD_RXN_p': 0.0,
#  'HIS_CITRULLINE_mc': 0.0,
#  'HIS_ORNITHINE_mc': 0.0,
#  'HIS_PROTON_rev_vc': 500.0,
#  'HIS_PROTON_vc': 500.0,
#  'HIS_pc': 0.0,
#  'HOMOCYSMETB12_RXN_c': 0.0,
#  'HOMOCYSMETB12_RXN_p': 0.0,
#  'HOMOSERDEHYDROG_RXN_NADP_p': 249.99999999999946,
#  'HOMOSERDEHYDROG_RXN_NAD_p': 250.00000000000031,
#  'HOMOSERKIN_RXN_p': 250.00000000000068,
#  'HOMO_CYS_pc': 0.0,
#  'HS_pc': 0.0,
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x': 138.47143457256828,
#  'H_ic': 500.0,
#  'H_im': 500.0,
#  'H_pc': 0.0,
#  'H_tx': 499.27270023053472,
#  'H_xc': 500.0,
#  'IGPSYN_RXN_p': 0.0,
#  'ILE_PROTON_rev_vc': 500.0,
#  'ILE_PROTON_vc': 500.0,
#  'ILE_pc': 0.0,
#  'IMIDPHOSDEHYD_RXN_p': 0.0,
#  'IMPCYCLOHYDROLASE_RXN_p': 0.0,
#  'INORGPYROPHOSPHAT_RXN_c': 500.0,
#  'INORGPYROPHOSPHAT_RXN_p': 500.0,
#  'INORGPYROPHOSPHAT_RXN_x': 250.00000000000003,
#  'ISOCITDEH_RXN_c': 6.8212102632969618e-13,
#  'ISOCITDEH_RXN_m': 5.0000000000103455,
#  'ISOCITRATE_ACONITATE_mc': 0.0,
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m': 500.0,
#  'ISOCIT_CLEAV_RXN_x': 274.92997198880039,
#  'ISOLEUCINE_TRNA_LIGASE_RXN_c': 0.0,
#  'K_biomass': 0.0,
#  'K_ec': 0.0,
#  'K_rev_vc': 0.0,
#  'K_tx': 0.0,
#  'LEUCINE_TRNA_LIGASE_RXN_c': 0.0,
#  'LEU_PROTON_rev_vc': 500.0,
#  'LEU_PROTON_vc': 500.0,
#  'LEU_pc': 0.0,
#  'LYSINE_TRNA_LIGASE_RXN_c': 0.0,
#  'LYS_ORNITHINE_mc': 0.0,
#  'LYS_PROTON_rev_vc': 500.0,
#  'LYS_PROTON_vc': 500.0,
#  'LYS_pc': 0.0,
#  'L_ALPHA_ALANINE_PROTON_rev_vc': 500.0,
#  'L_ALPHA_ALANINE_PROTON_vc': 500.0,
#  'L_ASCORBATE_PEROXIDASE_RXN_p': 250.00000000000006,
#  'L_ASPARTATE_GLU_mc': 0.0,
#  'L_ASPARTATE_PROTON_rev_vc': 500.0,
#  'L_ASPARTATE_PROTON_vc': 500.0,
#  'L_ASPARTATE_pc': -500.0,
#  'L_ASPARTATE_xc': -1.1368683772161603e-13,
#  'L_CITRULLINE_pc': 500.0000000000008,
#  'MALATE_DEHYDROGENASE_NADPs_RXN_p': 500.0,
#  'MALATE_DEH_RXN_c': 0.0,
#  'MALATE_DEH_RXN_m': 0.0,
#  'MALATE_DEH_RXN_p': 0.0,
#  'MALATE_DEH_RXN_x': 138.47143457256965,
#  'MALIC_NADP_RXN_c': 499.99999999999534,
#  'MALIC_NADP_RXN_p': 500.0,
#  'MALIC_NAD_RXN_m': 366.21031746031633,
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p': 0.0,
#  'MALSYN_RXN_x': 249.99999999999875,
#  'MALTODEG_RXN_c': 250.00000000000003,
#  'MALTODEXGLUCOSID_RXN_p': 500.0,
#  'MAL_ACONITATE_mc': 0.0,
#  'MAL_CIT_mc': 0.0,
#  'MAL_CIT_vc': 0.0,
#  'MAL_ISOCITRATE_mc': 0.0,
#  'MAL_PROTON_rev_vc': 500.0,
#  'MAL_PROTON_vc': 500.0,
#  'MAL_Pi_mc': 0.0,
#  'MAL_SO4_mc': 0.0,
#  'MAL_SUC_mc': 0.0,
#  'MAL_xc': 111.52856542743018,
#  'MANNITOL_1_PHOSPHATE_RXN_c': 499.99999999999625,
#  'MANNOSE_6_PHOSPHATE_6_REDUCTASE_RXN_c': 500.0,
#  'MANNPGUANYLTRANGDP_RXN_c': 500.0,
#  'MANNPISOM_RXN_c': 0.0,
#  'MDA_Fd_Ascorbate_p': 500.0,
#  'METHENYLTHFCYCLOHYDRO_RXN_c': 478.85225885225913,
#  'METHIONINE_TRNA_LIGASE_RXN_c': 0.0,
#  'METHYLENETHFDEHYDROG_NADP_RXN_c': 478.85225885225907,
#  'METHYLENE_THF_mc': 1.1368683772161603e-13,
#  'METHYLENE_THF_pc': 0.0,
#  'MET_PROTON_rev_vc': 500.0,
#  'MET_PROTON_vc': 500.0,
#  'MET_pc': 0.0,
#  'MG2_rev_vc': 0.0,
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c': 0.0,
#  'MYO_INOSITOL_1_PHOSPHATE_SYNTHASE_RXN_c': 0.0,
#  'MYO_INOSITOL_OXYGENASE_RXN_c': 0.0,
#  'Mehler_Reaction_p': 500.0,
#  'Mg_biomass': 0.0,
#  'Mg_ec': 0.0,
#  'Mg_tx': 0.0,
#  'Mitochondrial_ATP_Synthase_m': 489.67573696145297,
#  'NADH_DEHYDROG_A_RXN_mc': 169.56473214285722,
#  'NADH_DEHYDROG_A_RXN_mi': 500.0,
#  'NADH_KINASE_RXN_c': 500.0,
#  'NADPH_Dehydrogenase_p': 500.0,
#  'NADPHoxc_tx': 10.0,
#  'NADPHoxm_tx': 10.0,
#  'NADPHoxp_tx': 10.0,
#  'NADPPHOSPHAT_RXN_c': 500.0,
#  'NH3_mc': 500.0,
#  'NH3_pc': -500.0,
#  'NH4_ec': 0.0,
#  'NH4_tx': 0.0,
#  'NITRATE_PROTON_rev_vc': 250.0,
#  'NITRATE_REDUCTASE_NADH_RXN_c': 0.0,
#  'NITRATE_vc': 500.0,
#  'NITRITE_pc': 0.0,
#  'N_ACETYLGLUTPREDUCT_RXN_p': 499.99999999999989,
#  'Nitrate_ec': 0.0,
#  'Nitrate_tx': 0.0,
#  'O2_ec': 452.03145478374836,
#  'O2_mc': -502.49999999999943,
#  'O2_pc': -435.00000000000017,
#  'O2_tx': 452.03145478374364,
#  'O2_xc': -138.47143457256692,
#  'OAA_ACONITATE_mc': 0.0,
#  'OAA_CIT_mc': 0.0,
#  'OAA_ISOCITRATE_mc': 0.0,
#  'OAA_MAL_mc': 0.0,
#  'OAA_MAL_pc': 0.0,
#  'OAA_Pi_mc': 0.0,
#  'OAA_SO4_mc': 0.0,
#  'OAA_SUC_mc': 0.0,
#  'OAA_xc': 0.0,
#  'ORNCARBAMTRANSFER_RXN_p': 0.0,
#  'ORNITHINE_CITRULLINE_mc': 0.0,
#  'ORNITHINE_CITRULLINE_pc': 500.00000000000028,
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m': 500.00000000000028,
#  'PALMITATE_pc': 0.0,
#  'PEPCARBOXYKIN_RXN_c': 500.00000000000057,
#  'PEPCARBOX_RXN_c': 500.0,
#  'PEPDEPHOS_RXN_c': 500.0,
#  'PEPDEPHOS_RXN_p': 500.0,
#  'PEP_Pi_pc': 0.0,
#  'PGLUCISOM_RXN_c': -0.77142857142229104,
#  'PGLUCISOM_RXN_p': 0.0,
#  'PGLYCDEHYDROG_RXN_p': 239.42612942612936,
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c': 0.0,
#  'PHE_PROTON_rev_vc': 500.0,
#  'PHE_PROTON_vc': 500.0,
#  'PHE_pc': 0.0,
#  'PHOSGLYPHOS_RXN_c': 0.0,
#  'PHOSGLYPHOS_RXN_p': 0.0,
#  'PHOSPHOGLUCMUT_RXN_c': -208.33333333333297,
#  'PHOSPHOGLUCMUT_RXN_p': -499.99999999999943,
#  'PHOSPHORIBULOKINASE_RXN_p': 500.0,
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p': 250.0,
#  'PRAISOM_RXN_p': 0.0,
#  'PREPHENATEDEHYDROG_RXN_p': 0.0,
#  'PREPHENATE_DEHYDROGENASE_NADP_RXN_p': 0.0,
#  'PREPHENATE_TRANSAMINE_RXN_p': 0.0,
#  'PRIBFAICARPISOM_RXN_p': 0.0,
#  'PROTONATP_rev_vc': 500.0,
#  'PROTON_ATPase_c': 500.0,
#  'PROTON_PPi_rev_vc': 500.0,
#  'PRO_GLU_mc': -250.00000000000054,
#  'PRO_PROTON_rev_vc': 500.0,
#  'PRO_PROTON_vc': 500.0,
#  'PRO_mc': 250.00000000000006,
#  'PRPPSYN_RXN_p': 0.0,
#  'PRTRANS_RXN_p': 0.0,
#  'PSERTRANSAM_RXN_p': 239.42612942612968,
#  'PSII_RXN_p': 125.0,
#  'PYRROLINECARBREDUCT_RXN_NADP_c': 0.0,
#  'PYRROLINECARBREDUCT_RXN_NAD_c': 0.0,
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_c': 500.0,
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p': 499.99999999999989,
#  'PYRUVATE_PROTON_mc': -58.539690016373527,
#  'PYRUVATE_pc': 2.2737367544323206e-13,
#  'PYRUVDEH_RXN_m': 328.93939393939399,
#  'PYRUVDEH_RXN_p': 0.0,
#  'Phloem_output_tx': 0.0,
#  'Photon_ep': 500.0,
#  'Photon_tx': 500.0,
#  'Pi_PROTON_mc': 0.0,
#  'Pi_ec': 0.0,
#  'Pi_tx': 0.0,
#  'Pi_xc': 500.0,
#  'Plastidial_ATP_Synthase_p': 214.28571428571428,
#  'Plastoquinol_Oxidase_p': 375.00000000000119,
#  'Protein_Polymerisation_c': 0.0,
#  'Protein_Processing_c': 0.0,
#  'Protein_Translocation_c': 0.0,
#  'RIB5PISOM_RXN_p': -4.3939393939397178,
#  'RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p': 500.00000000000097,
#  'RIBULP3EPIM_RXN_c': 500.0,
#  'RIBULP3EPIM_RXN_p': -40.644192256341967,
#  'RXN0_1483_c': 250.0,
#  'RXN0_2381_p': 0.0,
#  'RXN0_2382_p': 0.0,
#  'RXN0_5114_p': 239.42612942611945,
#  'RXN0_5184_c': 249.99999999999989,
#  'RXN0_5224_c': 500.0,
#  'RXN0_5224_p': 0.0,
#  'RXN0_5260_m': 500.0,
#  'RXN0_5330_NADP_c': 500.0,
#  'RXN0_5330_NADP_mc': 500.0,
#  'RXN0_5330_NADP_mi': 500.0,
#  'RXN0_5330_NAD_c': 500.0,
#  'RXN0_5330_NAD_mc': 500.0,
#  'RXN0_5330_NAD_mi': 500.0,
#  'RXN1F_66_p': -277.5,
#  'RXN490_3650_p': 500.0,
#  'RXN66_1_c': 500.0,
#  'RXN66_3_c': 250.00000000000034,
#  'RXN66_3_m': 250.00000000000009,
#  'RXN_10745_NAD_c': 500.0,
#  'RXN_10786_c': 500.0,
#  'RXN_12541_c': 500.0,
#  'RXN_14351_pc': 250.00000000000006,
#  'RXN_1461_c': 490.11904761904668,
#  'RXN_1826_p': 500.0,
#  'RXN_1827_p': 250.00000000000003,
#  'RXN_2141_p': 250.00000000000017,
#  'RXN_3521_p': 250.0,
#  'RXN_3522_p': 250.0,
#  'RXN_3523_p': 250.0,
#  'RXN_5682_p': 0.0,
#  'RXN_6883_mc': 500.0,
#  'RXN_6883_mi': 500.0,
#  'RXN_6884_m': 497.49999999999943,
#  'RXN_6902_m': 328.93939393939445,
#  'RXN_7183_NADP_m': 499.99999999999989,
#  'RXN_7674_p': 277.49999999999949,
#  'RXN_7676_p': 277.49999999999949,
#  'RXN_7677_p': 277.49999999999949,
#  'RXN_7678_NADP_p': 277.49999999999983,
#  'RXN_7678_NAD_p': 277.49999999999545,
#  'RXN_7679_p': 277.49999999999545,
#  'RXN_7737_p': 0.0,
#  'RXN_7800_p': 0.0,
#  'RXN_7978_p': 500.00000000000011,
#  'RXN_7979_p': 500.0,
#  'RXN_7984_p': 500.0,
#  'RXN_7985_p': 500.00000000000011,
#  'RXN_8001_p': 0.0,
#  'RXN_8991_p': 0.0,
#  'RXN_9104_c': 0.0,
#  'RXN_9514_p': 0.0,
#  'RXN_9516_p': 0.0,
#  'RXN_9518_p': 0.0,
#  'RXN_9520_p': 0.0,
#  'RXN_9523_p': 0.0,
#  'RXN_9524_p': 0.0,
#  'RXN_9527_p': 0.0,
#  'RXN_9528_p': 0.0,
#  'RXN_9531_p': 0.0,
#  'RXN_9532_p': 0.0,
#  'RXN_9533_p': 0.0,
#  'RXN_9535_p': 0.0,
#  'RXN_9536_p': 0.0,
#  'RXN_9537_p': 0.0,
#  'RXN_9539_p': 0.0,
#  'RXN_9540_p': 0.0,
#  'RXN_9549_p': 0.0,
#  'RXN_961_p': 276.94286914513924,
#  'RXN_9648_p': 0.0,
#  'RXN_9650_p': 0.0,
#  'RXN_9651_p': 0.0,
#  'RXN_9652_p': 0.0,
#  'RXN_9653_p': 0.0,
#  'RXN_9654_p': 0.0,
#  'RXN_9655_p': 0.0,
#  'RXN_9657_p': 0.0,
#  'RXN_9658_p': 0.0,
#  'RXN_9659_p': 0.0,
#  'RXN_9660_p': 0.0,
#  'RXN_9661_p': 0.0,
#  'RXN_9662_p': 0.0,
#  'RXN_9663_p': 0.0,
#  'RXN_969_x': 276.94286914513924,
#  'SEDOBISALDOL_RXN_p': 500.0,
#  'SEDOHEPTULOSE_BISPHOSPHATASE_RXN_p': 500.0,
#  'SERINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x': 138.47143457256999,
#  'SERINE_O_ACETTRAN_RXN_c': 0.0,
#  'SERINE_O_ACETTRAN_RXN_p': 0.0,
#  'SERINE_TRNA_LIGASE_RXN_c': 0.0,
#  'SER_PROTON_rev_vc': 500.0,
#  'SER_PROTON_vc': 500.0,
#  'SER_mc': -1.1368683772161603e-13,
#  'SER_pc': 7.9580786405131221e-13,
#  'SER_xc': -138.47143457256809,
#  'SHIKIMATE_5_DEHYDROGENASE_RXN_p': 0.0,
#  'SHIKIMATE_KINASE_RXN_p': 0.0,
#  'SO4_ec': 0.0,
#  'SO4_pc': 0.0,
#  'SO4_tx': 0.0,
#  'SPONTPRO_RXN_c': 0.0,
#  'SPONTPRO_RXN_m': 499.99999999999852,
#  'SUCCCOASYN_RXN_m': 305.20282186948816,
#  'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m': 305.20282186948816,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc': 328.93939393939445,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mi': 328.93939393939388,
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m': 328.93939393939388,
#  'SUCCINYL_COA_HYDROLASE_RXN_m': 305.2028218694885,
#  'SUCROSE_PHOSPHATASE_RXN_c': 499.27270023053484,
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c': 499.27270023053484,
#  'SUCROSE_PROTON_rev_vc': 500.0,
#  'SUCROSE_PROTON_vc': 500.0,
#  'SUCROSE_SYNTHASE_RXN_c': 500.0000000000004,
#  'SUC_ACONITATE_mc': 0.0,
#  'SUC_CIT_mc': 0.0,
#  'SUC_FUM_mc': 0.0,
#  'SUC_ISOCITRATE_mc': 0.0,
#  'SUC_Pi_mc': 0.0,
#  'SUC_SO4_mc': 0.0,
#  'SUC_xc': 274.929971988793,
#  'SULFATE_ADENYLYLTRANS_RXN_p': 0.0,
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p': 0.0,
#  'SUPEROX_DISMUT_RXN_c': 500.0,
#  'SUPEROX_DISMUT_RXN_p': 250.0,
#  'Starch_biomass': 0.0,
#  'Sucrose_ec': 37.669287898645976,
#  'Sucrose_tx': 37.669287898646211,
#  'THF_mc': -1.6484591469634324e-12,
#  'THF_pc': -7.4464878707658499e-12,
#  'THREDEHYD_RXN_p': 0.0,
#  'THREONINE_ALDOLASE_RXN_c': 250.0,
#  'THREONINE_TRNA_LIGASE_RXN_c': 0.0,
#  'THREO_DS_ISO_CITRATE_xc': -274.92997198879692,
#  'THRESYN_RXN_p': 250.0,
#  'THR_PROTON_rev_vc': 500.0,
#  'THR_PROTON_vc': 500.0,
#  'THR_pc': 250.00000000000003,
#  'TRANSALDOL_RXN_p': 337.72727272727246,
#  'TRIOSEPISOMERIZATION_RXN_c': 0.0,
#  'TRIOSEPISOMERIZATION_RXN_p': 0.0,
#  'TRP_PROTON_rev_vc': 500.0,
#  'TRP_PROTON_vc': 500.0,
#  'TRP_pc': 0.0,
#  'TYRAMINOTRANS_RXN_p': 0.0,
#  'TYROSINE_TRNA_LIGASE_RXN_c': 0.0,
#  'TYR_PROTON_rev_vc': 500.0,
#  'TYR_PROTON_vc': 500.0,
#  'TYR_pc': 0.0,
#  'UDPKIN_RXN_c': 458.33333333333326,
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c': 0.0,
#  'UGD_RXN_c': 0.0,
#  'VALINE_TRNA_LIGASE_RXN_c': 0.0,
#  'VAL_PROTON_rev_vc': 500.0,
#  'VAL_PROTON_vc': 500.0,
#  'VAL_pc': 0.0,
#  'X5P_Pi_pc': -500.0,
#  'Xylan_biomass': 0.0,
#  'diel_biomass': 0.0,
#  'pALA_biomass': 0.0,
#  'pARG_biomass': 0.0,
#  'pASN_biomass': 0.0,
#  'pASP_biomass': 0.0,
#  'pGLN_biomass': 0.0,
#  'pGLU_biomass': 0.0,
#  'pGLY_biomass': 0.0,
#  'pHIS_biomass': 0.0,
#  'pILE_biomass': 0.0,
#  'pLEU_biomass': 0.0,
#  'pLYS_biomass': 0.0,
#  'pMET_biomass': 0.0,
#  'pPHE_biomass': 0.0,
#  'pSER_biomass': 0.0,
#  'pTHR_biomass': 0.0,
#  'pTYR_biomass': 0.0,
#  'pVAL_biomass': 0.0,
#  'sALA_biomass': 0.0,
#  'sASP_biomass': 0.0,
#  'sCIT_biomass': 0.0,
#  'sFUM_biomass': 0.0,
#  'sGABA_biomass': 0.0,
#  'sGLN_biomass': 0.0,
#  'sGLU_biomass': 0.0,
#  'sMAL_biomass': 0.0,
#  'sSUCROSE_biomass': 0.0,
#  'sSUC_biomass': 0.0,
#  'unlProtHYPO_c': 499.27270023056769}

# %%
print('Test Completed')

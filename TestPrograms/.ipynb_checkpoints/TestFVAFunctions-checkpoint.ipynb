# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
gparentdir = os.path.dirname(os.path.dirname(currentdir))
sys.path.insert(0, gparentdir)
import scobra
import get_all_functions as gaf
import re
n = scobra.Model("sample/Supplemental-Data-S1_Core-Leaf-Model.xml")
m = scobra.model(n)
# Out:
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(  )' for <Reaction HEXOKINASE_RXN_MANNOSE_c2 at 0x7fa10dbbf2d0>
# cobra/core/reaction.py:394 UserWarning: malformed gene_reaction_rule '(  )' for <Reaction HEXOKINASE_RXN_MANNOSE_c1 at 0x7fa10dbbfad0>

# %%
import scobra.classes.fva as fva
import scobra.classes.flux as flux
dic = m.ReactionsDegree()
f = fva.fva(dic)
f
# Out:
# {'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p2': 4,
#  'BRANCHED_CHAINAMINOTRANSFERLEU_RXN_p1': 4,
#  'Ca_biomass2': 2,
#  'Ca_biomass1': 2,
#  'PYRUVATE_PROTON_mc1': 4,
#  'PYRUVATE_PROTON_mc2': 4,
#  'Protein_Processing_c1': 9,
#  'Protein_Processing_c2': 9,
#  'Starch_biomass1': 2,
#  'Starch_biomass2': 2,
#  'AMP_pc1': 2,
#  'RXN_9516_p1': 6,
#  'RXN_9516_p2': 6,
#  'AMP_pc2': 2,
#  'TRIOSEPISOMERIZATION_RXN_c1': 2,
#  'TRIOSEPISOMERIZATION_RXN_c2': 2,
#  'RXN_6884_m1': 5,
#  'RXN_6884_m2': 5,
#  'CYTOCHROME_C_OXIDASE_RXN_mc1': 6,
#  'pTYR_biomass2': 8,
#  'pTYR_biomass1': 8,
#  'CYTOCHROME_C_OXIDASE_RXN_mc2': 6,
#  'MDA_Fd_Ascorbate_p2': 5,
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x1': 4,
#  'ALANINE_GLYOXYLATE_AMINOTRANSFERASE_RXN_x2': 4,
#  'MDA_Fd_Ascorbate_p1': 5,
#  'NADPPHOSPHAT_RXN_c1': 6,
#  'NADPPHOSPHAT_RXN_c2': 6,
#  'Pi_ec2': 5,
#  'RXN_6902_m1': 4,
#  'RXN_6902_m2': 4,
#  'Pi_ec1': 5,
#  'pTHR_biomass2': 8,
#  'Photon_ep1': 2,
#  'Photon_ep2': 2,
#  'pTHR_biomass1': 8,
#  'PREPHENATEDEHYDROG_RXN_p2': 5,
#  'PREPHENATEDEHYDROG_RXN_p1': 5,
#  '2KG_ACONITATE_mc1': 6,
#  '2KG_ACONITATE_mc2': 6,
#  'RXN_9653_p2': 6,
#  'Sucrose_ec1': 4,
#  'Sucrose_ec2': 4,
#  'CYS_PROTON_vc1': 4,
#  'HIS_ORNITHINE_mc2': 4,
#  'HIS_ORNITHINE_mc1': 4,
#  'PYRUVDEH_RXN_m1': 6,
#  'RXN_9653_p1': 6,
#  'THF_mc1': 2,
#  'THF_mc2': 2,
#  'RXN66_1_c1': 4,
#  'PHE_PROTON_rev_vc1': 4,
#  'GLYOHMETRANS_RXN_c1': 5,
#  'GLUTDECARBOX_RXN_c2': 4,
#  'GLYOHMETRANS_RXN_c2': 5,
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p2': 8,
#  'ATPPHOSPHORIBOSYLTRANS_RXN_p1': 8,
#  'GLUTAMINE_TRNA_LIGASE_RXN_c2': 9,
#  'GLUTAMINE_TRNA_LIGASE_RXN_c1': 9,
#  'LYS_pc2': 2,
#  'LYS_pc1': 2,
#  'FORMATETHFLIG_RXN_p1': 10,
#  'FORMATETHFLIG_RXN_p2': 10,
#  'Photon_tx1': 1,
#  'Photon_tx2': 1,
#  'SUCROSE_PROTON_rev_vc2': 4,
#  'SUCROSE_PROTON_rev_vc1': 4,
#  'ISOCITRATE_ACONITATE_mc2': 4,
#  'ISOCITRATE_ACONITATE_mc1': 4,
#  '2OXOGLUTARATEDEH_RXN_m2': 6,
#  'Mg_biomass2': 2,
#  '2OXOGLUTARATEDEH_RXN_m1': 6,
#  'ACSERLY_RXN_c2': 6,
#  'MYO_INOSITOL_OXYGENASE_RXN_c2': 5,
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m2': 5,
#  'ACSERLY_RXN_c1': 6,
#  'GLYCOGENSYN_RXN_p2': 5,
#  'SUC_CIT_mc1': 6,
#  'SUC_CIT_mc2': 6,
#  'GLYCOGENSYN_RXN_p1': 5,
#  'NADPHoxp_tx1': 5,
#  'Mg_biomass1': 2,
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c2': 6,
#  'TRP_PROTON_vc1': 4,
#  'TRP_PROTON_vc2': 4,
#  '2_PERIOD_4_PERIOD_1_PERIOD_111_RXN_c1': 6,
#  'ACETYLORNTRANSAM_RXN_p1': 4,
#  'ACETYLORNTRANSAM_RXN_p2': 4,
#  'OAA_CIT_mc2': 6,
#  'OAA_CIT_mc1': 6,
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p1': 9,
#  'PYRUVATEORTHOPHOSPHATE_DIKINASE_RXN_p2': 9,
#  '3_ISOPROPYLMALDEHYDROG_RXN_p2': 5,
#  'THREDEHYD_RXN_p2': 3,
#  'THREDEHYD_RXN_p1': 3,
#  '3_ISOPROPYLMALDEHYDROG_RXN_p1': 5,
#  '3_ISOPROPYLMALISOM_RXN_p2': 3,
#  '3_ISOPROPYLMALISOM_RXN_p1': 3,
#  'INORGPYROPHOSPHAT_RXN_p1': 5,
#  'INORGPYROPHOSPHAT_RXN_p2': 5,
#  'pLYS_biomass1': 8,
#  'pLYS_biomass2': 8,
#  'RXN_9518_p2': 5,
#  'RXN_9518_p1': 5,
#  'GLT_v_dielTransfer': 2,
#  'K_tx2': 1,
#  'NADPHoxp_tx2': 5,
#  'H_pc1': 2,
#  'H_pc2': 2,
#  'ACETATE_COA_LIGASE_RXN_p1': 9,
#  'VAL_v_dielTransfer': 2,
#  'bHIS_v_dielTransfer': 2,
#  'ACETATE_COA_LIGASE_RXN_p2': 9,
#  'MALIC_NADP_RXN_c2': 5,
#  'MALIC_NADP_RXN_c1': 5,
#  '2KG_OAA_mc1': 4,
#  'RIBULOSE_BISPHOSPHATE_CARBOXYLASE_RXN_p1': 5,
#  'RXN_9523_p1': 6,
#  'RXN_7183_NADP_m1': 6,
#  'RXN_7183_NADP_m2': 6,
#  'pARG_biomass1': 8,
#  'pARG_biomass2': 8,
#  'LEU_v_dielTransfer': 2,
#  'LEU_PROTON_rev_vc2': 4,
#  'LYS_PROTON_vc2': 4,
#  'LYS_PROTON_vc1': 4,
#  'LEU_PROTON_rev_vc1': 4,
#  'PRIBFAICARPISOM_RXN_p2': 2,
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p2': 3,
#  '4_PERIOD_2_PERIOD_1_PERIOD_58_RXN_p1': 3,
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p2': 3,
#  'SULFATE_ADENYLYLTRANS_RXN_p1': 7,
#  'sALA_biomass2': 2,
#  'sALA_biomass1': 2,
#  'SULFATE_ADENYLYLTRANS_RXN_p2': 7,
#  'VAL_PROTON_rev_vc2': 4,
#  'RXN0_5184_c1': 5,
#  'VAL_PROTON_rev_vc1': 4,
#  'GLC_tx2': 1,
#  'GLC_tx1': 1,
#  'GLY_pc1': 2,
#  'GLY_pc2': 2,
#  'MET_PROTON_rev_vc2': 4,
#  'MET_PROTON_rev_vc1': 4,
#  'RXN0_1483_c2': 5,
#  'METHIONINE_TRNA_LIGASE_RXN_c2': 9,
#  'RXN_12541_c2': 4,
#  'HOMOSERDEHYDROG_RXN_NAD_p1': 5,
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c2': 11,
#  'ASPAMINOTRANS_RXN_x1': 4,
#  'ASPAMINOTRANS_RXN_x2': 4,
#  'ATP_CITRATE_PRO_S_LYASE_RXN_c1': 11,
#  'TRIOSEPISOMERIZATION_RXN_p1': 2,
#  'TRIOSEPISOMERIZATION_RXN_p2': 2,
#  'METHIONINE_TRNA_LIGASE_RXN_c1': 9,
#  'RXN_7984_p1': 5,
#  'RXN_7984_p2': 5,
#  'RXN0_5330_NAD_mc2': 5,
#  'SUCROSE_PHOSPHATASE_RXN_c1': 6,
#  'SUCROSE_PHOSPHATASE_RXN_c2': 6,
#  'RXN0_5330_NAD_mc1': 5,
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c2': 7,
#  'Mg_tx2': 1,
#  'Mg_tx1': 1,
#  '2_PERIOD_7_PERIOD_7_PERIOD_44_RXN_c1': 7,
#  'TRP_pc1': 2,
#  'TRP_pc2': 2,
#  'MAL_PROTON_vc1': 4,
#  'Biomass_tx1': 20,
#  'Ca_ec1': 4,
#  'MAL_PROTON_vc2': 4,
#  'RXN_9655_p2': 3,
#  'HIS_v_dielTransfer': 2,
#  'RXN_10786_c1': 7,
#  'RXN_10786_c2': 7,
#  'LEU_PROTON_vc1': 4,
#  'LEU_PROTON_vc2': 4,
#  'Glycolate_xc1': 2,
#  'Glycolate_xc2': 2,
#  'CO2_mc1': 2,
#  'FUMHYDR_RXN_c2': 3,
#  'FUMHYDR_RXN_c1': 3,
#  'ASPAMINOTRANS_RXN_c1': 4,
#  'GLYOHMETRANS_RXN_p1': 5,
#  'GLYOHMETRANS_RXN_p2': 5,
#  'ASPAMINOTRANS_RXN_c2': 4,
#  'THREO_DS_ISO_CITRATE_xc2': 2,
#  'THREO_DS_ISO_CITRATE_xc1': 2,
#  'METHYLENETHFDEHYDROG_NADP_RXN_c1': 4,
#  '2PGADEHYDRAT_RXN_c2': 3,
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c1': 6,
#  'PEPCARBOXYKIN_RXN_c1': 8,
#  'PEPCARBOXYKIN_RXN_c2': 8,
#  'MYO_INOSITOL_1OR_4_MONOPHOSPHATASE_RXN_c2': 6,
#  'RIB5PISOM_RXN_p2': 2,
#  'RXN_9655_p1': 3,
#  'RXN_9104_c1': 5,
#  'O2_xc1': 2,
#  'O2_xc2': 2,
#  'MAL_SUC_mc2': 4,
#  'PYRUVDEH_RXN_p2': 6,
#  'PYRUVDEH_RXN_p1': 6,
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p1': 4,
#  '2_PERIOD_5_PERIOD_1_PERIOD_19_RXN_p2': 4,
#  'diel_biomass': 2,
#  'VALINE_TRNA_LIGASE_RXN_c1': 9,
#  'MAL_SUC_mc1': 4,
#  'MANNPGUANYLTRANGDP_RXN_c2': 7,
#  'GLY_mc1': 2,
#  'GLY_mc2': 2,
#  'MANNPGUANYLTRANGDP_RXN_c1': 7,
#  'F16ALDOLASE_RXN_c1': 3,
#  'F16ALDOLASE_RXN_c2': 3,
#  'TRP_v_dielTransfer': 2,
#  'SER_pc1': 2,
#  'SER_pc2': 2,
#  'GLY_xc1': 2,
#  'GAP_Pi_pc1': 6,
#  'GAP_Pi_pc2': 6,
#  'LYSINE_TRNA_LIGASE_RXN_c2': 9,
#  'MANNPISOM_RXN_c2': 2,
#  'MANNPISOM_RXN_c1': 2,
#  'LYSINE_TRNA_LIGASE_RXN_c1': 9,
#  'GCVMULTI_RXN_m1': 7,
#  'GCVMULTI_RXN_m2': 7,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc2': 6,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mc1': 6,
#  'HISTCYCLOHYD_RXN_p2': 3,
#  'HISTCYCLOHYD_RXN_p1': 3,
#  'ACETATE_COA_LIGASE_RXN_x2': 8,
#  'Glycerate_xc1': 2,
#  'IMIDPHOSDEHYD_RXN_p2': 3,
#  'PROTON_ATPase_c1': 9,
#  'PROTON_ATPase_c2': 9,
#  'FRUCTOKINASE_RXN_c2': 7,
#  'ACETOLACTREDUCTOISOM_RXN_p2': 5,
#  'ACETOLACTREDUCTOISOM_RXN_p1': 5,
#  'FRUCTOKINASE_RXN_c1': 7,
#  'CYSPH_RXN_p1': 4,
#  'CYSPH_RXN_p2': 4,
#  'INORGPYROPHOSPHAT_RXN_x1': 6,
#  'INORGPYROPHOSPHAT_RXN_x2': 6,
#  'RXN_9539_p2': 6,
#  'RXN_9539_p1': 6,
#  'TYR_PROTON_rev_vc2': 4,
#  'TYR_PROTON_rev_vc1': 4,
#  'pGLU_biomass2': 8,
#  'pGLU_biomass1': 8,
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p1': 4,
#  '1_PERIOD_8_PERIOD_5_PERIOD_1_RXN_p2': 4,
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p1': 9,
#  'ACETYL_COA_CARBOXYLTRANSFER_RXN_p2': 9,
#  'NADH_DEHYDROG_A_RXN_mi2': 6,
#  'NADH_DEHYDROG_A_RXN_mi1': 6,
#  '6PGLUCONOLACT_RXN_c1': 4,
#  '6PGLUCONOLACT_RXN_c2': 4,
#  'RXN_9652_p1': 6,
#  'PRPPSYN_RXN_p2': 7,
#  'PRPPSYN_RXN_p1': 7,
#  'ACSERLY_RXN_p2': 4,
#  'ACSERLY_RXN_p1': 4,
#  '10_FORMYL_THF_pc1': 2,
#  'HISTOLDEHYD_RXN_p2': 6,
#  'HISTOLDEHYD_RXN_p1': 6,
#  '10_FORMYL_THF_pc2': 2,
#  'MET_pc1': 2,
#  'Glycerate_xc2': 2,
#  'MET_pc2': 2,
#  'RXN_1827_p2': 3,
#  'RXN_1827_p1': 3,
#  'TYROSINE_TRNA_LIGASE_RXN_c2': 9,
#  'ADP_pc2': 6,
#  'TYROSINE_TRNA_LIGASE_RXN_c1': 9,
#  'ADP_pc1': 6,
#  'pVAL_biomass2': 8,
#  'pVAL_biomass1': 8,
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m1': 6,
#  'SUCCINATE_SEMIALDEHYDE_DEHYDROGENASE_RXN_m2': 6,
#  'Mitochondrial_ATP_Synthase_m1': 8,
#  'Mitochondrial_ATP_Synthase_m2': 8,
#  'THREONINE_ALDOLASE_RXN_c1': 3,
#  'THREONINE_ALDOLASE_RXN_c2': 3,
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c2': 9,
#  'PHENYLALANINE_TRNA_LIGASE_RXN_c1': 9,
#  '3PGAREARR_RXN_c2': 2,
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p2': 4,
#  'MALONYL_COA_ACP_TRANSACYL_RXN_p1': 4,
#  'ISOCITDEH_RXN_m2': 5,
#  'ISOCITDEH_RXN_m1': 5,
#  'HOMO_CYS_pc1': 2,
#  'HOMO_CYS_pc2': 2,
#  'ATPase_tx1': 8,
#  'ATPase_tx2': 8,
#  'pLEU_biomass2': 8,
#  'pLEU_biomass1': 8,
#  'FERRIC_CHELATE_REDUCTASE_RXN_c1': 5,
#  'FERRIC_CHELATE_REDUCTASE_RXN_c2': 5,
#  'FORMATE_pc1': 2,
#  'FORMATE_pc2': 2,
#  'ILE_PROTON_vc2': 4,
#  'ILE_PROTON_vc1': 4,
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p1': 6,
#  'PLASTOQUINOL_PLASTOCYANIN_REDUCTASE_RXN_p2': 6,
#  'K_biomass2': 2,
#  'K_biomass1': 2,
#  'GLUCURONOKINASE_RXN_c1': 7,
#  'GLUCURONOKINASE_RXN_c2': 7,
#  'SPONTPRO_RXN_c1': 2,
#  'RXN_7800_p2': 4,
#  'THR_PROTON_rev_vc2': 4,
#  'THR_PROTON_rev_vc1': 4,
#  'RXN_7800_p1': 4,
#  '5_METHYL_THF_pc2': 2,
#  '5_METHYL_THF_pc1': 2,
#  'PEPDEPHOS_RXN_p1': 7,
#  'PEPDEPHOS_RXN_p2': 7,
#  'ORNCARBAMTRANSFER_RXN_p1': 5,
#  'ORNCARBAMTRANSFER_RXN_p2': 5,
#  'SUC_ISOCITRATE_mc2': 6,
#  'SUC_ISOCITRATE_mc1': 6,
#  'H2O_ec2': 2,
#  'NITRATE_PROTON_rev_vc1': 4,
#  'NITRATE_PROTON_rev_vc2': 4,
#  'OAA_SO4_mc1': 4,
#  'OAA_SO4_mc2': 4,
#  'RXN0_5330_NAD_mi1': 5,
#  'RXN0_5330_NAD_mi2': 5,
#  'NH4_ec1': 2,
#  'NH4_ec2': 2,
#  'CA2_rev_vc1': 4,
#  'PROTONATP_rev_vc1': 9,
#  'PROTONATP_rev_vc2': 9,
#  'CA2_rev_vc2': 4,
#  'HOMOCYSMETB12_RXN_c1': 4,
#  'HOMOCYSMETB12_RXN_c2': 4,
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c2': 6,
#  '1_PERIOD_2_PERIOD_1_PERIOD_9_RXN_c1': 6,
#  'CIT_PROTON_vc2': 4,
#  'CIT_PROTON_vc1': 4,
#  'GLUCOKIN_RXN_p1': 7,
#  'LEUCINE_TRNA_LIGASE_RXN_c1': 9,
#  'LEUCINE_TRNA_LIGASE_RXN_c2': 9,
#  'GLUCOKIN_RXN_p2': 7,
#  'RXN_3523_p2': 3,
#  'RXN_3523_p1': 3,
#  'MAL_xc1': 2,
#  'RXN_9549_p1': 5,
#  'RXN_9549_p2': 5,
#  'MAL_xc2': 2,
#  'DIHYDRODIPICSYN_RXN_p1': 5,
#  'DIHYDRODIPICSYN_RXN_p2': 5,
#  'GLUTAMIDOTRANS_RXN_p1': 6,
#  'OAA_ACONITATE_mc1': 6,
#  'OAA_ACONITATE_mc2': 6,
#  'GLUTAMIDOTRANS_RXN_p2': 6,
#  'PRO_PROTON_rev_vc2': 4,
#  'PRO_PROTON_rev_vc1': 4,
#  'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m2': 9,
#  'SUCCINATE_COA_LIGASE_GDP_FORMING_RXN_m1': 9,
#  'RXN_9659_p1': 5,
#  'RXN_9659_p2': 5,
#  'HIS_PROTON_vc2': 3,
#  'HIS_PROTON_vc1': 3,
#  'MAL_Pi_mc2': 6,
#  'MAL_Pi_mc1': 6,
#  'ACET_pc2': 2,
#  'ACET_pc1': 2,
#  'sFUM_biomass2': 2,
#  'sFUM_biomass1': 2,
#  'HISTALDEHYD_RXN_p1': 7,
#  'HISTALDEHYD_RXN_p2': 7,
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x2': 5,
#  'HYDROXYPYRUVATE_REDUCTASE_RXN_NAD_x1': 5,
#  '2_PERIOD_7_PERIOD_7_PERIOD_34_RXN_c1': 7,
#  '2KG_CIT_mc2': 6,
#  '2KG_CIT_mc1': 6,
#  'N_ACETYLGLUTPREDUCT_RXN_p1': 6,
#  'N_ACETYLGLUTPREDUCT_RXN_p2': 6,
#  'L_ALPHA_ALANINE_v_dielTransfer': 2,
#  'PALMITATE_pc1': 2,
#  'PALMITATE_pc2': 2,
#  'THR_PROTON_vc2': 4,
#  'ARGSUCCINLYA_RXN_c2': 3,
#  'ARGSUCCINLYA_RXN_c1': 3,
#  'ACETYLGLUTKIN_RXN_p1': 7,
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p1': 7,
#  'Phloem_output_tx2': 27,
#  'Phloem_output_tx1': 27,
#  'ASNSYNA_RXN_c1': 9,
#  'O2_mc1': 2,
#  'RXN_9651_p2': 6,
#  'SULFITE_REDUCTASE_FERREDOXIN_RXN_p2': 7,
#  'PGLUCISOM_RXN_c2': 2,
#  'ASNSYNA_RXN_c2': 9,
#  'PGLUCISOM_RXN_c1': 2,
#  'PHOSGLYPHOS_RXN_p1': 7,
#  'PHOSGLYPHOS_RXN_p2': 7,
#  '3PGAREARR_RXN_c1': 2,
#  'HEXOKINASE_RXN_MANNOSE_c1': 7,
#  'RXN_3521_p1': 4,
#  'RXN_3521_p2': 4,
#  'ASPARAGINE_TRNA_LIGASE_RXN_c2': 9,
#  'ALANINE_AMINOTRANSFERASE_RXN_c2': 4,
#  'ALANINE_AMINOTRANSFERASE_RXN_c1': 4,
#  'Mehler_Reaction_p1': 4,
#  'Mehler_Reaction_p2': 4,
#  'Ferredoxin_Plastoquinone_Reductase_p2': 5,
#  'RXN_9540_p2': 5,
#  'RXN_9540_p1': 5,
#  'Ferredoxin_Plastoquinone_Reductase_p1': 5,
#  'DIHYDROPICRED_RXN_NADP_p2': 5,
#  'DIHYDROPICRED_RXN_NADP_p1': 5,
#  'PRO_v_dielTransfer': 2,
#  'ARG_PROTON_vc2': 4,
#  'ARG_PROTON_vc1': 4,
#  'SUC_SO4_mc2': 4,
#  'SUC_SO4_mc1': 4,
#  'RXN_9514_p2': 5,
#  'RXN_9514_p1': 5,
#  'RXN_9650_p2': 6,
#  'RXN_9650_p1': 6,
#  'MALSYN_RXN_x2': 6,
#  'ARG_ORNITHINE_mc2': 4,
#  'ARG_ORNITHINE_mc1': 4,
#  '1_PERIOD_1_PERDIOD_1_PERIOD_255_RXN_c2': 5,
#  '1_PERIOD_1_PERDIOD_1_PERIOD_255_RXN_c1': 5,
#  'METHYLENETHFDEHYDROG_NADP_RXN_c2': 4,
#  'RXN0_5330_NADP_mi1': 5,
#  'TYR_pc2': 2,
#  'TYR_pc1': 2,
#  'RXN_9104_c2': 5,
#  'CO2_ec1': 2,
#  'MYO_INOSITOL_OXYGENASE_RXN_c1': 5,
#  'HIS_CITRULLINE_mc1': 4,
#  'PROTON_PPi_rev_vc2': 7,
#  'PROTON_PPi_rev_vc1': 7,
#  'GLU6PDEHYDROG_RXN_c1': 5,
#  'GLU6PDEHYDROG_RXN_c2': 5,
#  'MAL_SO4_mc2': 4,
#  'MAL_SO4_mc1': 4,
#  'RXN_7678_NADP_p2': 5,
#  'RXN_7678_NADP_p1': 5,
#  'CIT_ACONITATE_mc1': 4,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mi1': 6,
#  '1_PERIOD_10_PERIOD_2_PERIOD_2_RXN_mi2': 6,
#  'CIT_ACONITATE_mc2': 4,
#  'RXN_9657_p2': 5,
#  'RXN_9657_p1': 5,
#  'GLT_xc1': 2,
#  'GLT_xc2': 2,
#  'RXN_9654_p2': 6,
#  'RXN_9654_p1': 6,
#  'L_ALPHA_ALANINE_PROTON_rev_vc1': 4,
#  'L_ALPHA_ALANINE_PROTON_rev_vc2': 4,
#  'GAP_3PGA_pc2': 4,
#  'GAP_3PGA_pc1': 4,
#  'MG2_rev_vc1': 4,
#  'CYS_PROTON_rev_vc1': 4,
#  'CYS_PROTON_rev_vc2': 4,
#  'RXN_9663_p1': 5,
#  'SO4_pc1': 2,
#  'SO4_pc2': 2,
#  'RXN_9528_p1': 5,
#  'RXN_9528_p2': 5,
#  'THR_pc1': 2,
#  'THR_pc2': 2,
#  'ALANINE_AMINOTRANSFERASE_RXN_x2': 4,
#  'CELLULOSE_SYNTHASE_UDP_FORMING_RXN_c1': 5,
#  'RXN_9663_p2': 5,
#  'Cellulose_biomass1': 2,
#  'Ca_tx2': 1,
#  'Ca_tx1': 1,
#  'Cellulose_biomass2': 2,
#  'RXN0_5114_p1': 4,
#  'PRAISOM_RXN_p2': 2,
#  'PRAISOM_RXN_p1': 2,
#  'RXN0_5114_p2': 4,
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p1': 9,
#  'unlProtHYPO_c2': 1,
#  'ADENYLOSUCCINATE_SYNTHASE_RXN_p2': 9,
#  'CO2_tx2': 1,
#  'CO2_tx1': 1,
#  'H2O_xc2': 2,
#  'L_ASPARTATE_PROTON_vc2': 4,
#  'L_ASPARTATE_PROTON_vc1': 4,
#  'unlProtHYPO_c1': 1,
#  'O2_tx1': 1,
#  'H2O_xc1': 2,
#  'O2_tx2': 1,
#  'RXN0_5224_c2': 4,
#  'RXN0_5224_c1': 4,
#  'GLUTAMATE_N_ACETYLTRANSFERASE_RXN_p1': 4,
#  'GLUTAMATE_N_ACETYLTRANSFERASE_RXN_p2': 4,
#  'CO2_ec2': 2,
#  'ACETOLACTSYN_RXN_p2': 4,
#  '2TRANSKETO_RXN_p2': 4,
#  'ALANINE_AMINOTRANSFERASE_RXN_x1': 4,
#  'PHE_PROTON_rev_vc2': 4,
#  '1_PERIOD_18_PERIOD_1_PERIOD_2_RXN_p2': 5,
#  '1_PERIOD_18_PERIOD_1_PERIOD_2_RXN_p1': 5,
#  'MAL_CIT_mc1': 6,
#  'RXN_2141_p2': 3,
#  'RXN_2141_p1': 3,
#  'MAL_CIT_mc2': 6,
#  'GLY_PROTON_vc2': 4,
#  'RXN_6883_mc2': 5,
#  'RXN_6883_mc1': 5,
#  'O2_pc1': 2,
#  'O2_pc2': 2,
#  'HOMOSERKIN_RXN_p1': 7,
#  'HOMOSERKIN_RXN_p2': 7,
#  'ACETOOHBUTREDUCTOISOM_RXN_p2': 5,
#  'PHOSPHOGLUCMUT_RXN_p2': 2,
#  'PHOSPHOGLUCMUT_RXN_p1': 2,
#  'ACETOOHBUTREDUCTOISOM_RXN_p1': 5,
#  'GLY3KIN_RXN_p1': 7,
#  'GLY3KIN_RXN_p2': 7,
#  'ACETALD_mc2': 2,
#  'ACETALD_mc1': 2,
#  'MAL_PROTON_rev_vc2': 5,
#  'MAL_PROTON_rev_vc1': 5,
#  'CITSYN_RXN_m1': 6,
#  'CITSYN_RXN_m2': 6,
#  'Nitrate_tx1': 1,
#  'H_ic1': 2,
#  'H_ic2': 2,
#  'Nitrate_tx2': 1,
#  'FUM_PROTON_vc2': 5,
#  'FUM_PROTON_vc1': 5,
#  'NADPHoxc_tx2': 5,
#  'NH3_mc2': 2,
#  'RXN_9660_p2': 5,
#  'NADPHoxc_tx1': 5,
#  'HOMOCYSMETB12_RXN_p1': 4,
#  'HOMOCYSMETB12_RXN_p2': 4,
#  'METHYLENE_THF_mc2': 2,
#  'METHYLENE_THF_mc1': 2,
#  'RXN_8991_p1': 3,
#  'RXN_8991_p2': 3,
#  'PYRUVATE_pc1': 2,
#  'PYRUVATE_pc2': 2,
#  'SHIKIMATE_KINASE_RXN_p2': 7,
#  'NADH_KINASE_RXN_c1': 7,
#  'NADH_KINASE_RXN_c2': 7,
#  'SHIKIMATE_KINASE_RXN_p1': 7,
#  'RXN0_5330_NAD_c1': 5,
#  'RXN0_5330_NAD_c2': 5,
#  'RXN_9652_p2': 6,
#  'MG2_rev_vc2': 4,
#  'ARG_CITRULLINE_mc2': 4,
#  'SO4_ec1': 4,
#  'SO4_ec2': 4,
#  'PSERTRANSAM_RXN_p2': 4,
#  'SUPEROX_DISMUT_RXN_c1': 4,
#  '2TRANSKETO_RXN_p1': 4,
#  'RXN_10745_NAD_c1': 5,
#  'RXN_10745_NAD_c2': 5,
#  'CHORISMATEMUT_RXN_p2': 2,
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p1': 3,
#  'DIHYDROXYISOVALDEHYDRAT_RXN_p2': 3,
#  'pHIS_biomass1': 8,
#  'pHIS_biomass2': 8,
#  'RXN_9660_p1': 5,
#  'ARG_mc2': 2,
#  'Pi_PROTON_mc1': 5,
#  'Pi_PROTON_mc2': 5,
#  'ARG_mc1': 2,
#  'CHORISMATEMUT_RXN_p1': 2,
#  'ASPAMINOTRANS_RXN_m1': 4,
#  'RXN_9520_p1': 3,
#  'RXN_9520_p2': 3,
#  '3_DEHYDROQUINATE_SYNTHASE_RXN_p2': 3,
#  'OAA_Pi_mc2': 6,
#  'OAA_Pi_mc1': 6,
#  'Protein_Translocation_c2': 9,
#  'Protein_Translocation_c1': 9,
#  'GLYOHMETRANS_RXN_m2': 5,
#  'GLYOHMETRANS_RXN_m1': 5,
#  '2PGADEHYDRAT_RXN_p2': 3,
#  'pPHE_biomass2': 8,
#  'pPHE_biomass1': 8,
#  '2PGADEHYDRAT_RXN_p1': 3,
#  'pALA_biomass1': 8,
#  'pALA_biomass2': 8,
#  'LYS_v_dielTransfer': 2,
#  'THRESYN_RXN_p2': 4,
#  'RXN_9533_p1': 3,
#  'RXN_9533_p2': 3,
#  'GPH_RXN_p1': 4,
#  'TYRAMINOTRANS_RXN_p2': 4,
#  'GLUTAMINESYN_RXN_p1': 9,
#  'THRESYN_RXN_p1': 4,
#  'IMPCYCLOHYDROLASE_RXN_p2': 3,
#  'IMPCYCLOHYDROLASE_RXN_p1': 3,
#  '6PGLUCONDEHYDROG_RXN_p2': 5,
#  '6PGLUCONDEHYDROG_RXN_p1': 5,
#  '3PGAREARR_RXN_p1': 2,
#  '3PGAREARR_RXN_p2': 2,
#  '4_PERIOD_2_PERIOD_1_PERIOD_61_RXN_p2': 3,
#  '4_PERIOD_2_PERIOD_1_PERIOD_61_RXN_p1': 3,
#  'TYR_v_dielTransfer': 2,
#  'PYRUVDEH_RXN_m2': 6,
#  'RXN_7978_p2': 7,
#  'RXN_7978_p1': 7,
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_p2': 4,
#  'BRANCHED_CHAINAMINOTRANSFERVAL_RXN_p1': 4,
#  'SER_v_dielTransfer': 2,
#  'METHENYLTHFCYCLOHYDRO_RXN_c1': 4,
#  'METHENYLTHFCYCLOHYDRO_RXN_c2': 4,
#  'GLN_PROTON_vc1': 4,
#  'GLN_PROTON_vc2': 4,
#  'GLYC3PDEHYDROGBIOSYN_RXN_c2': 5,
#  '2_KETOGLUTARATE_xc1': 2,
#  '2_KETOGLUTARATE_xc2': 2,
#  'GLYC3PDEHYDROGBIOSYN_RXN_c1': 5,
#  'X5P_Pi_pc1': 6,
#  'sGLN_biomass1': 2,
#  'sGLN_biomass2': 2,
#  'X5P_Pi_pc2': 6,
#  'THF_pc1': 2,
#  'THF_pc2': 2,
#  'RXN0_5224_p2': 4,
#  'RXN0_5224_p1': 4,
#  'NITRITE_pc1': 4,
#  'NITRITE_pc2': 4,
#  'PREPHENATE_TRANSAMINE_RXN_p1': 4,
#  'PRO_mc2': 2,
#  'PRO_mc1': 2,
#  'PREPHENATE_TRANSAMINE_RXN_p2': 4,
#  'ACET_mc2': 2,
#  'MALIC_NADP_RXN_p2': 5,
#  'MALIC_NADP_RXN_p1': 5,
#  'ACET_mc1': 2,
#  'H2O_mc2': 2,
#  'H2O_mc1': 2,
#  'L_ASPARTATE_GLU_mc1': 4,
#  'L_ASPARTATE_GLU_mc2': 4,
#  'RXN_9532_p2': 5,
#  'SEDOBISALDOL_RXN_p1': 3,
#  'GLYCERATE_GLYCOLLATE_pc1': 4,
#  'RXN_9532_p1': 5,
#  'RXN_9536_p2': 5,
#  'HIS_pc2': 2,
#  'HIS_pc1': 2,
#  'RXN_9536_p1': 5,
#  'HISTIDPHOS_RXN_p2': 4,
#  'HISTIDPHOS_RXN_p1': 4,
#  'L_ASCORBATE_PEROXIDASE_RXN_p2': 4,
#  'L_ASCORBATE_PEROXIDASE_RXN_p1': 4,
#  'PGLUCISOM_RXN_p2': 2,
#  '3PGA_Pi_pc2': 6,
#  'PGLUCISOM_RXN_p1': 2,
#  '3PGA_Pi_pc1': 6,
#  'ADENYL_KIN_RXN_c2': 6,
#  'SUC_FUM_mc2': 4,
#  'DHAP_3PGA_pc2': 4,
#  'DHAP_3PGA_pc1': 4,
#  'SUCROSE_SYNTHASE_RXN_c1': 6,
#  'SUCROSE_SYNTHASE_RXN_c2': 6,
#  '6PFRUCTPHOS_RXN_c2': 7,
#  '6PFRUCTPHOS_RXN_c1': 7,
#  'GLN_PROTON_rev_vc2': 4,
#  'RXN490_3650_p2': 5,
#  'RXN490_3650_p1': 5,
#  'GLN_PROTON_rev_vc1': 4,
#  'RXN_14351_pc1': 2,
#  'ISOCITRATE_DEHYDROGENASE_NAD_RXN_m1': 5,
#  'RXN_14351_pc2': 2,
#  'ASPARAGINE_TRNA_LIGASE_RXN_c1': 9,
#  'sGABA_biomass2': 2,
#  'sGABA_biomass1': 2,
#  'CIT_xc2': 2,
#  'CIT_xc1': 2,
#  'GLUTAMATE_SYNTHASE_NADH_RXN_p2': 6,
#  'GLUTAMATE_SYNTHASE_NADH_RXN_p1': 6,
#  'THREONINE_TRNA_LIGASE_RXN_c2': 9,
#  'THREONINE_TRNA_LIGASE_RXN_c1': 9,
#  '1_PERIOD_5_PERIOD_1_PERIOD_20_RXN_c1': 5,
#  '1_PERIOD_5_PERIOD_1_PERIOD_20_RXN_c2': 5,
#  'L_ASPARTATE_pc2': 2,
#  'L_ASPARTATE_pc1': 2,
#  'sGLU_biomass1': 2,
#  'sGLU_biomass2': 2,
#  'ASN_v_dielTransfer': 2,
#  '1_PERIOD_8_PERIOD_4_PERIOD_9_RXN_p1': 7,
#  '1_PERIOD_8_PERIOD_4_PERIOD_9_RXN_p2': 7,
#  'DIHYDROPICRED_RXN_NAD_p1': 5,
#  'DIHYDROPICRED_RXN_NAD_p2': 5,
#  'SEDOBISALDOL_RXN_p2': 3,
#  'ACETOOHBUTSYN_RXN_p2': 5,
#  'K_ec2': 4,
#  'K_ec1': 4,
#  'ACETOOHBUTSYN_RXN_p1': 5,
#  'SUPEROX_DISMUT_RXN_p2': 4,
#  'SUPEROX_DISMUT_RXN_p1': 4,
#  'PHE_pc2': 2,
#  'PHE_pc1': 2,
#  'L_ASPARTATE_PROTON_rev_vc1': 4,
#  'L_ASPARTATE_PROTON_rev_vc2': 4,
#  'RXN_8001_p2': 6,
#  'RXN_8001_p1': 6,
#  'H_tx1': 1,
#  'H_tx2': 1,
#  'SPONTPRO_RXN_m1': 4,
#  'SPONTPRO_RXN_m2': 4,
#  'GLT_PROTON_vc2': 4,
#  'GLT_PROTON_vc1': 4,
#  'RXN66_3_m1': 6,
#  'RXN66_3_m2': 6,
#  'sSUCROSE_biomass1': 2,
#  'sSUCROSE_biomass2': 2,
#  'MAL_ISOCITRATE_mc1': 6,
#  'ACET_xc2': 2,
#  'ACET_xc1': 2,
#  'MAL_ISOCITRATE_mc2': 6,
#  'LEU_pc1': 2,
#  'LEU_pc2': 2,
#  '4_AMINO_BUTYRATE_PROTON_rev_vc2': 4,
#  'ACONITATEDEHYDR_RXN_m2': 3,
#  'ACONITATEDEHYDR_RXN_m1': 3,
#  '4_AMINO_BUTYRATE_PROTON_rev_vc1': 4,
#  'MANNITOL_1_PHOSPHATE_RXN_c2': 6,
#  'MANNITOL_1_PHOSPHATE_RXN_c1': 6,
#  'GLC_vc1': 2,
#  'GLC_vc2': 2,
#  'RXN_6883_mi1': 5,
#  'RXN_6883_mi2': 5,
#  'ASPARTATEKIN_RXN_p1': 7,
#  'ASPARTATEKIN_RXN_p2': 7,
#  'RXN_7677_p2': 7,
#  'RXN_7677_p1': 7,
#  'CITSYN_RXN_x2': 6,
#  'CITSYN_RXN_x1': 6,
#  'CYS_v_dielTransfer': 2,
#  'F16BDEPHOS_RXN_c1': 6,
#  'F16BDEPHOS_RXN_c2': 6,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mi2': 4,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mi1': 4,
#  'GABATRANSAM_RXN_m2': 4,
#  'RXN0_5260_m1': 4,
#  'RXN0_5260_m2': 4,
#  'GABATRANSAM_RXN_m1': 4,
#  'Sucrose_tx1': 1,
#  'Sucrose_tx2': 1,
#  'F16ALDOLASE_RXN_p1': 3,
#  'F16ALDOLASE_RXN_p2': 3,
#  'GLYCINE_AMINOTRANSFERASE_RXN_x2': 4,
#  'GLYCINE_AMINOTRANSFERASE_RXN_x1': 4,
#  'RXN_7676_p1': 7,
#  'RXN_7676_p2': 7,
#  'sMAL_biomass1': 2,
#  'sMAL_biomass2': 2,
#  'ASPAMINOTRANS_RXN_m2': 4,
#  'pGLY_biomass2': 8,
#  'GLUTKIN_RXN_c2': 7,
#  'GLUTKIN_RXN_c1': 7,
#  'pGLY_biomass1': 8,
#  'RXN_7674_p2': 7,
#  'RXN_7674_p1': 7,
#  'NADPH_Dehydrogenase_p2': 6,
#  'NADPH_Dehydrogenase_p1': 6,
#  'GLUTAMINESYN_RXN_c2': 10,
#  '4_AMINO_BUTYRATE_PROTON_vc1': 4,
#  '4_AMINO_BUTYRATE_PROTON_vc2': 4,
#  'sSUC_biomass2': 2,
#  'ILE_pc2': 2,
#  'ILE_pc1': 2,
#  'sSUC_biomass1': 2,
#  'GLUTAMATE_DEHYDROGENASE_RXN_m1': 7,
#  'GLUTAMATE_DEHYDROGENASE_RXN_m2': 7,
#  'PHE_v_dielTransfer': 2,
#  'O2_ec1': 2,
#  'O2_ec2': 2,
#  'RXN_7985_p2': 5,
#  'SERINE_TRNA_LIGASE_RXN_c1': 9,
#  'SERINE_TRNA_LIGASE_RXN_c2': 9,
#  'RXN_7985_p1': 5,
#  'GDPKIN_RXN_p1': 9,
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c1': 4,
#  'sCIT_biomass2': 2,
#  'sCIT_biomass1': 2,
#  'UDP_GLUCURONATE_DECARBOXYLASE_RXN_c2': 4,
#  'CYS_PROTON_vc2': 4,
#  'RXN_7679_p1': 6,
#  'RXN_7679_p2': 6,
#  'GLUTAMINESYN_RXN_c1': 10,
#  'SUCROSE_v_dielTransfer': 2,
#  'NADH_DEHYDROG_A_RXN_mc1': 6,
#  'NADH_DEHYDROG_A_RXN_mc2': 6,
#  'GLURS_RXN_c1': 9,
#  'GLURS_RXN_c2': 9,
#  'SER_PROTON_rev_vc2': 4,
#  'SER_PROTON_rev_vc1': 4,
#  'Pi_xc2': 6,
#  'Pi_xc1': 6,
#  'MALSYN_RXN_x1': 6,
#  'OAA_SUC_mc1': 4,
#  'OAA_SUC_mc2': 4,
#  'RXN0_5330_NADP_mi2': 5,
#  'GLN_GLU_pc1': 4,
#  'ACETOLACTSYN_RXN_p1': 4,
#  'GLN_GLU_pc2': 4,
#  'Mg_ec2': 4,
#  'Mg_ec1': 4,
#  'ALCOHOL_DEHYDROG_RXN_c2': 5,
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c1': 6,
#  'GDPKIN_RXN_m2': 9,
#  'GDPKIN_RXN_m1': 9,
#  'SUCROSE_PHOSPHATE_SYNTHASE_RXN_c2': 6,
#  'GLT_MAL_pc2': 4,
#  'GLT_MAL_pc1': 4,
#  '6_PERIOD_3_PERIOD_4_PERIOD_16_RXN_p1': 10,
#  'GLY_xc2': 2,
#  '6_PERIOD_3_PERIOD_4_PERIOD_16_RXN_p2': 10,
#  'GLUTAMINESYN_RXN_m1': 9,
#  'GLUTAMINESYN_RXN_m2': 9,
#  'TRANSALDOL_RXN_p2': 4,
#  'TRANSALDOL_RXN_p1': 4,
#  'VAL_pc2': 2,
#  'VAL_pc1': 2,
#  'FUM_pc2': 2,
#  'FUM_pc1': 2,
#  'HISTPRATPHYD_RXN_p1': 6,
#  'HISTPRATPHYD_RXN_p2': 6,
#  'RXN0_2382_p2': 4,
#  'SUC_FUM_mc1': 4,
#  'GLY_v_dielTransfer': 2,
#  'NITRATE_vc2': 2,
#  'NITRATE_vc1': 2,
#  'ADENYL_KIN_RXN_p2': 6,
#  'ADENYL_KIN_RXN_p1': 6,
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p2': 6,
#  'MET_v_dielTransfer': 2,
#  'FERREDOXIN_NITRITE_REDUCTASE_RXN_p1': 6,
#  'NITRATE_v_dielTransfer': 2,
#  'MALATE_DEH_RXN_c1': 5,
#  'MALATE_DEH_RXN_c2': 5,
#  'RXN66_3_c2': 6,
#  'RXN66_3_c1': 6,
#  'CIT_ISOCITRATE_mc2': 4,
#  'L_CITRULLINE_pc2': 2,
#  'MALATE_DEH_RXN_m2': 5,
#  'GLC_pc2': 2,
#  'GLC_pc1': 2,
#  'MALATE_DEH_RXN_m1': 5,
#  '2_PERIOD_7_PERIOD_7_PERIOD_13_RXN_c2': 7,
#  'TYR_PROTON_vc1': 4,
#  'TYR_PROTON_vc2': 4,
#  '2_PERIOD_7_PERIOD_7_PERIOD_13_RXN_c1': 7,
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m1': 4,
#  'ORNITHINE_GLU_AMINOTRANSFORASE_RXN_m2': 4,
#  'RXN_1461_c1': 4,
#  'RXN_1461_c2': 4,
#  'RXN_12541_c1': 4,
#  'UDPKIN_RXN_c2': 9,
#  'UDPKIN_RXN_c1': 9,
#  'PGLYCDEHYDROG_RXN_p1': 5,
#  'GLUTDECARBOX_RXN_c1': 4,
#  'RXN66_1_c2': 4,
#  'NH3_pc2': 2,
#  'NH3_pc1': 2,
#  'HISTAMINOTRANS_RXN_p1': 4,
#  'HISTAMINOTRANS_RXN_p2': 4,
#  'GPH_RXN_p2': 4,
#  'H2O_pc2': 2,
#  'H2O_pc1': 2,
#  'DIHYDROXYMETVALDEHYDRAT_RXN_p1': 3,
#  'PRIBFAICARPISOM_RXN_p1': 2,
#  'FRU_PROTON_rev_vc2': 4,
#  'RXN0_5184_c2': 5,
#  'H2O_ec1': 2,
#  'CO2_pc2': 2,
#  'CO2_pc1': 2,
#  'H_im2': 2,
#  'H_im1': 2,
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p1': 6,
#  'GLUTAMATE_SYNTHASE_FERREDOXIN_RXN_p2': 6,
#  'PHE_PROTON_vc1': 4,
#  'PHE_PROTON_vc2': 4,
#  'NADPHoxm_tx1': 5,
#  'NADPHoxm_tx2': 5,
#  '2_PERIOD_3_PERIOD_1_PERIOD_180_RXN_p1': 6,
#  'ORNITHINE_CITRULLINE_mc2': 4,
#  'ORNITHINE_CITRULLINE_mc1': 4,
#  '2_PERIOD_3_PERIOD_1_PERIOD_180_RXN_p2': 6,
#  'CYSTAGLY_RXN_p2': 5,
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p2': 4,
#  '1_PERIOD_2_PERIOD_1_PERIOD_2_RXN_p1': 4,
#  'Plastoquinol_Oxidase_p1': 4,
#  'ANTHRANSYN_RXN_p2': 6,
#  'ANTHRANSYN_RXN_p1': 6,
#  'Plastoquinol_Oxidase_p2': 4,
#  'VAL_PROTON_vc1': 4,
#  'VAL_PROTON_vc2': 4,
#  'NH4_tx1': 1,
#  'NH4_tx2': 1,
#  'GLUTAMINESYN_RXN_p2': 9,
#  'GLT_PROTON_rev_vc1': 4,
#  'GLT_PROTON_rev_vc2': 4,
#  'GLUC1PURIDYLTRANS_RXN_c1': 7,
#  'GLUC1PURIDYLTRANS_RXN_c2': 7,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc1': 4,
#  'SUCCINATE_DEHYDROGENASE_UBIQUINONE_RXN_mc2': 4,
#  'ASN_PROTON_vc1': 4,
#  'TRP_PROTON_rev_vc2': 4,
#  'TRP_PROTON_rev_vc1': 4,
#  'ASN_PROTON_vc2': 4,
#  'GAPOXNPHOSPHN_RXN_c1': 7,
#  'GAPOXNPHOSPHN_RXN_c2': 7,
#  'FRU_PROTON_rev_vc1': 4,
#  'SERINE_O_ACETTRAN_RXN_c2': 4,
#  'GLYCINE_TRNA_LIGASE_RXN_c1': 9,
#  'GLYCINE_TRNA_LIGASE_RXN_c2': 9,
#  'SERINE_O_ACETTRAN_RXN_c1': 4,
#  'PREPHENATE_DEHYDROGENASE_NADP_RXN_p1': 5,
#  'PREPHENATE_DEHYDROGENASE_NADP_RXN_p2': 5,
#  'PGLYCDEHYDROG_RXN_p2': 5,
#  'ARG_LYS_mc2': 4,
#  'ARG_LYS_mc1': 4,
#  'MALTODEXGLUCOSID_RXN_p2': 3,
#  'MALTODEXGLUCOSID_RXN_p1': 3,
#  'RXN_961_p1': 5,
#  'RXN_961_p2': 5,
#  'MAL_ACONITATE_mc2': 6,
#  'MAL_ACONITATE_mc1': 6,
#  'RIBULP3EPIM_RXN_c1': 2,
#  'RIBULP3EPIM_RXN_c2': 2,
#  'sASP_biomass2': 2,
#  'sASP_biomass1': 2,
#  'ARGININE_TRNA_LIGASE_RXN_c1': 9,
#  'ARGININE_TRNA_LIGASE_RXN_c2': 9,
#  'MET_PROTON_vc1': 4,
#  'MET_PROTON_vc2': 4,
#  'DIAMINOPIMDECARB_RXN_p2': 4,
#  'DIAMINOPIMDECARB_RXN_p1': 4,
#  'RXN0_2381_p2': 3,
#  '2KG_MAL_mc1': 4,
#  'RXN0_2381_p1': 3,
#  'Xylan_biomass1': 2,
#  'Xylan_biomass2': 2,
#  'ARGSUCCINSYN_RXN_c2': 9,
#  'ARGSUCCINSYN_RXN_c1': 9,
#  '2KG_MAL_mc2': 4,
#  '2_ISOPROPYLMALATESYN_RXN_p2': 6,
#  '2_ISOPROPYLMALATESYN_RXN_p1': 6,
#  'H2O_tx2': 1,
#  'H2O_tx1': 1,
#  'ACONITATEHYDR_RXN_m2': 3,
#  'ACONITATEHYDR_RXN_m1': 3,
#  'L_ASPARTATE_xc2': 2,
#  'G6P_Pi_pc2': 6,
#  'G6P_Pi_pc1': 6,
#  'AMPSYN_RXN_p1': 3,
#  'L_ASPARTATE_xc1': 2,
#  'AMPSYN_RXN_p2': 3,
#  'GDPKIN_RXN_c1': 8,
#  'GDPKIN_RXN_c2': 8,
#  'RXN_3522_p1': 5,
#  'NH3_mc1': 2,
#  'RXN_3522_p2': 5,
#  'GLC_PROTON_rev_vc1': 4,
#  'GLUC1PADENYLTRANS_RXN_p1': 7,
#  'GLUC1PADENYLTRANS_RXN_p2': 7,
#  'GLC_PROTON_rev_vc2': 4,
#  'SER_PROTON_vc1': 4,
#  'SER_PROTON_vc2': 4,
#  '3_DEHYDROQUINATE_DEHYDRATASE_RXN_p2': 4,
#  '3_DEHYDROQUINATE_DEHYDRATASE_RXN_p1': 4,
#  'INORGPYROPHOSPHAT_RXN_c1': 6,
#  '2PGADEHYDRAT_RXN_c1': 3,
#  'INORGPYROPHOSPHAT_RXN_c2': 6,
#  'ARG_HIS_mc2': 4,
#  'ARG_HIS_mc1': 4,
#  'Plastidial_ATP_Synthase_p2': 8,
#  'GLN_GLU_mc1': 4,
#  'GLN_GLU_mc2': 4,
#  'ALCOHOL_DEHYDROG_RXN_c1': 5,
#  'RXN_969_x1': 4,
#  'RXN_969_x2': 4,
#  'Ca_ec2': 4,
#  'Plastidial_ATP_Synthase_p1': 8,
#  '1_PERIOD_2_PERIOD_1_PERIOD_13_RXN_p1': 6,
#  'Biomass_tx2': 20,
#  '1_PERIOD_2_PERIOD_1_PERIOD_13_RXN_p2': 6,
#  'PEP_Pi_pc1': 6,
#  'PEP_Pi_pc2': 6,
#  'CYSTATHIONINE_BETA_LYASE_RXN_p2': 5,
#  'CYSTATHIONINE_BETA_LYASE_RXN_p1': 5,
#  'NITRATE_REDUCTASE_NADH_RXN_c2': 6,
#  'RXN_1826_p1': 3,
#  'RXN_1826_p2': 3,
#  'NITRATE_REDUCTASE_NADH_RXN_c1': 6,
#  'L_ASPARTATE_v_dielTransfer': 2,
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p2': 5,
#  'GLUTATHIONE_REDUCT_NADPH_RXN_p1': 5,
#  'pILE_biomass1': 8,
#  'pILE_biomass2': 8,
#  'DHAP_Pi_pc1': 6,
#  'DHAP_Pi_pc2': 6,
#  'PEPDEPHOS_RXN_c1': 7,
#  ...}

# %%
thefile = enumerate(open(gparentdir + "/scobra/classes/fva.py"))
flist = gaf.get_function_names_easy(thefile)
# Out:
# ['__init__', '__call__', 'Blocked', 'Allowed', 'Variable', 'Fixed', 'Essential', 'Substitutable', 'Unbounded', 'Bounded', 'BothDirections', 'ForwardOnly', 'BackwardOnly', 'AsMtx', 'GetReacs', 'GetReacsMeanFlux', 'MaxDiff', 'FluxRangeDiff', 'FluxDiffDirec', 'FluxRangeOverlap']

# %%
f = fva.fva({'abc': [40,60], 'def': [20,50]})

# %%
flist = ['Blocked', 'Allowed', 'Variable', 'Fixed', 'Essential', 'Substitutable', 'Unbounded',
         'Bounded', 'BothDirections', 'ForwardOnly', 'BackwardOnly', 'AsMtx', 'GetReacs', 'GetReacsMeanFlux',
         'MaxDiff', 'FluxRangeDiff', 'FluxDiffDirec', 'FluxRangeOverlap']

errors = []
for i in flist: 
    try:
        print('executing ' + i)
        exec("f." + i + "()")
    except TypeError: 
        errors.append(i)
#errors = errors +  []
# Out:
# executing Blocked
# executing Allowed
# executing Variable
# executing Fixed
# executing Essential
# executing Substitutable
# executing Unbounded
# executing Bounded
# executing BothDirections
# executing ForwardOnly
# executing BackwardOnly
# executing AsMtx
# executing GetReacs
# executing GetReacsMeanFlux
# executing MaxDiff
# executing FluxRangeDiff
# executing FluxDiffDirec
# executing FluxRangeOverlap

# %%
f.GetReacs(['abc'])
f.GetReacsMeanFlux(['abc'])
f2 = fva.fva({'abc': [20,100], 'jkl': [40,300]})
f.FluxDiffDirec(f2)
f.FluxRangeOverlap(f2)
f.FluxRangeDiff(f2)
# Out:
# {}

# %%
print('Test Completed')
